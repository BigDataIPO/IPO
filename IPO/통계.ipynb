# %%
import pandas as pd
import numpy as np
import os

# %%
path_dir = 'Result/랜덤포레스트/모델 평가' 
file_list = os.listdir(path_dir)
file_list = file_list[:-2]
file_list
# Out:
# ['0_1_모델 평가.csv',
#  '0_3_모델 평가.csv',
#  '0_6_모델 평가.csv',
#  '1_3_모델 평가.csv',
#  '3_6_모델 평가.csv',
#  'end_1_모델 평가.csv',
#  'end_3_모델 평가.csv',
#  'end_6_모델 평가.csv']

# %%
def sign(pval):
    if(pval <= 0.01):
        return "***"
    elif(pval <= 0.05):
        return "**"
    elif(pval<= 0.1):
        return "*"
    else:
        return ""
for i in range(4):
    Total_Stat = np.array([])
    for left in file_list:
        for right in file_list:   
            left_df = pd.read_csv(path_dir + "//" + left, encoding = 'cp949',index_col = 0)
            right_df = pd.read_csv(path_dir + "//" + right, encoding = 'cp949',index_col = 0)
            left_value = left_df.iloc[i+4,:]
            right_value = right_df.iloc[i+4,:]
            stat, pval = Ttest(left_value,right_value,leftstr = left , rightstr = right)

            left_mean = np.mean(left_value)
            right_mean = np.mean(right_value)

            star = sign(pval)

            Statstr = str(np.round(left_mean - right_mean,3)) + "(" + str(np.round(stat,3)) + star +  ")"
            Total_Stat = np.append(Total_Stat, Statstr)



    Total_df = pd.DataFrame(Total_Stat.reshape(8,8), index = file_list, columns = file_list)

    Total_df.to_csv(path_dir+ '//' + str(i) + 'Total.csv', encoding = 'euc-kr')
# Out:
# 0	0_1_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_1_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_1_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.723424, p-value : 0.398296
#
# True
# 0_1_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 1 , pvalue : 0.1962117
#
# 0	0_1_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.116493, p-value : 0.734024
#
# True
# 0_1_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 1 , pvalue : 0.2810581
#
# 0	0_1_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.343074, p-value : 0.250937
#
# True
# 0_1_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0013789
#
# 0	0_1_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 3.652660, p-value : 0.060605
#
# True
# 0_1_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0115023
#
# 0	0_1_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.786953, p-value : 0.378451
#
# True
# 0_1_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 0 , pvalue : 0.8867284
#
# 0	0_1_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.158037, p-value : 0.286043
#
# True
# 0_1_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.5727929
#
# 0	0_1_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.027554, p-value : 0.868701
#
# True
# 0_1_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.5163276
#
# 0	0_3_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.723424, p-value : 0.398296
#
# True
# 0_3_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : -1 , pvalue : 0.1962117
#
# 0	0_3_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_3_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_3_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.225117, p-value : 0.636836
#
# True
# 0_3_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.8759767
#
# 0	0_3_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 3.543616, p-value : 0.064470
#
# True
# 0_3_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -4 , pvalue : 0.0000187
#
# 0	0_3_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 6.977200, p-value : 0.010435
#
# False
# 0_3_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0004919
#
# 0	0_3_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.013955, p-value : 0.906347
#
# True
# 0_3_모델 평가.csv end_1_모델 평가.csv
#
# statistic : -1 , pvalue : 0.2213818
#
# 0	0_3_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.093226, p-value : 0.761138
#
# True
# 0_3_모델 평가.csv end_3_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0434084
#
# 0	0_3_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.009226, p-value : 0.318993
#
# True
# 0_3_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0470323
#
# 0	0_6_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.116493, p-value : 0.734024
#
# True
# 0_6_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : -1 , pvalue : 0.2810581
#
# 0	0_6_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.225117, p-value : 0.636836
#
# True
# 0_6_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.8759767
#
# 0	0_6_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_6_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_6_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 2.045998, p-value : 0.157628
#
# True
# 0_6_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -4 , pvalue : 0.0000560
#
# 0	0_6_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 4.715289, p-value : 0.033731
#
# False
# 0_6_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0009741
#
# 0	0_6_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.294160, p-value : 0.589511
#
# True
# 0_6_모델 평가.csv end_1_모델 평가.csv
#
# statistic : -1 , pvalue : 0.3196432
#
# 0	0_6_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.521493, p-value : 0.472921
#
# True
# 0_6_모델 평가.csv end_3_모델 평가.csv
#
# statistic : -1 , pvalue : 0.0825551
#
# 0	0_6_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.247969, p-value : 0.620271
#
# True
# 0_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -1 , pvalue : 0.0827755
#
# 0	1_3_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.343074, p-value : 0.250937
#
# True
# 1_3_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0013789
#
# 0	1_3_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 3.543616, p-value : 0.064470
#
# True
# 1_3_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 4 , pvalue : 0.0000187
#
# 0	1_3_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 2.045998, p-value : 0.157628
#
# True
# 1_3_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 4 , pvalue : 0.0000560
#
# 0	1_3_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 1_3_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	1_3_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.476129, p-value : 0.492756
#
# True
# 1_3_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.6505794
#
# 0	1_3_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 3.496901, p-value : 0.066207
#
# True
# 1_3_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0006356
#
# 0	1_3_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 4.126355, p-value : 0.046513
#
# False
# 1_3_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0033984
#
# 0	1_3_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.010170, p-value : 0.318769
#
# True
# 1_3_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0066127
#
# 0	3_6_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 3.652660, p-value : 0.060605
#
# True
# 3_6_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0115023
#
# 0	3_6_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 6.977200, p-value : 0.010435
#
# False
# 3_6_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0004919
#
# 0	3_6_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 4.715289, p-value : 0.033731
#
# False
# 3_6_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0009741
#
# 0	3_6_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.476129, p-value : 0.492756
#
# True
# 3_6_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.6505794
#
# 0	3_6_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 3_6_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	3_6_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 6.743812, p-value : 0.011734
#
# False
# 3_6_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0071956
#
# 0	3_6_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 7.625390, p-value : 0.007562
#
# False
# 3_6_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0259605
#
# 0	3_6_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 3.068936, p-value : 0.084747
#
# True
# 3_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0398024
#
# 0	end_1_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.786953, p-value : 0.378451
#
# True
# end_1_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 0 , pvalue : 0.8867284
#
# 0	end_1_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.013955, p-value : 0.906347
#
# True
# end_1_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 1 , pvalue : 0.2213818
#
# 0	end_1_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.294160, p-value : 0.589511
#
# True
# end_1_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 1 , pvalue : 0.3196432
#
# 0	end_1_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 3.496901, p-value : 0.066207
#
# True
# end_1_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0006356
#
# 0	end_1_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 6.743812, p-value : 0.011734
#
# False
# end_1_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0071956
#
# 0	end_1_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_1_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	end_1_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.027934, p-value : 0.867807
#
# True
# end_1_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.4502011
#
# 0	end_1_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.061024, p-value : 0.306983
#
# True
# end_1_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.4081186
#
# 0	end_3_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.158037, p-value : 0.286043
#
# True
# end_3_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 0 , pvalue : 0.5727929
#
# 0	end_3_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.093226, p-value : 0.761138
#
# True
# end_3_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0434084
#
# 0	end_3_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.521493, p-value : 0.472921
#
# True
# end_3_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 1 , pvalue : 0.0825551
#
# 0	end_3_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 4.126355, p-value : 0.046513
#
# False
# end_3_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0033984
#
# 0	end_3_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 7.625390, p-value : 0.007562
#
# False
# end_3_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0259605
#
# 0	end_3_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.027934, p-value : 0.867807
#
# True
# end_3_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 0 , pvalue : 0.4502011
#
# 0	end_3_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_3_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
# 0	end_3_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.480099, p-value : 0.228370
#
# True
# end_3_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.8925046
#
# 0	end_6_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.027554, p-value : 0.868701
#
# True
# end_6_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 0 , pvalue : 0.5163276
#
# 0	end_6_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.009226, p-value : 0.318993
#
# True
# end_6_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0470323
#
# 0	end_6_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.247969, p-value : 0.620271
#
# True
# end_6_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 1 , pvalue : 0.0827755
#
# 0	end_6_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.010170, p-value : 0.318769
#
# True
# end_6_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0066127
#
# 0	end_6_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 3.068936, p-value : 0.084747
#
# True
# end_6_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0398024
#
# 0	end_6_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.061024, p-value : 0.306983
#
# True
# end_6_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 0 , pvalue : 0.4081186
#
# 0	end_6_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.480099, p-value : 0.228370
#
# True
# end_6_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.8925046
#
# 0	end_6_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_1_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_1_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_1_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.036689, p-value : 0.848725
#
# True
# 0_1_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 1 , pvalue : 0.2204755
#
# 0	0_1_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.197098, p-value : 0.658620
#
# True
# 0_1_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.8339946
#
# 0	0_1_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.802239, p-value : 0.184337
#
# True
# 0_1_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : 7 , pvalue : 0.0000000
#
# 0	0_1_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 4.326323, p-value : 0.041668
#
# False
# 0_1_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : 6 , pvalue : 0.0000001
#
# 0	0_1_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 9.650735, p-value : 0.002854
#
# False
# 0_1_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 10 , pvalue : 0.0000000
#
# 0	0_1_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 4.664904, p-value : 0.034660
#
# False
# 0_1_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 7 , pvalue : 0.0000000
#
# 0	0_1_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.864210, p-value : 0.177073
#
# True
# 0_1_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 6 , pvalue : 0.0000000
#
# 0	0_3_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.036689, p-value : 0.848725
#
# True
# 0_3_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : -1 , pvalue : 0.2204755
#
# 0	0_3_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_3_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_3_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.065746, p-value : 0.798483
#
# True
# 0_3_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : -1 , pvalue : 0.2688396
#
# 0	0_3_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.416335, p-value : 0.238545
#
# True
# 0_3_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : 6 , pvalue : 0.0000000
#
# 0	0_3_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 3.832972, p-value : 0.054758
#
# True
# 0_3_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : 5 , pvalue : 0.0000043
#
# 0	0_3_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 9.294769, p-value : 0.003377
#
# False
# 0_3_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 9 , pvalue : 0.0000000
#
# 0	0_3_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 4.166780, p-value : 0.045486
#
# False
# 0_3_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 6 , pvalue : 0.0000000
#
# 0	0_3_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.460857, p-value : 0.231383
#
# True
# 0_3_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 5 , pvalue : 0.0000006
#
# 0	0_6_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.197098, p-value : 0.658620
#
# True
# 0_6_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 0 , pvalue : 0.8339946
#
# 0	0_6_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.065746, p-value : 0.798483
#
# True
# 0_6_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 1 , pvalue : 0.2688396
#
# 0	0_6_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_6_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_6_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.930792, p-value : 0.338405
#
# True
# 0_6_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : 8 , pvalue : 0.0000000
#
# 0	0_6_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 3.080062, p-value : 0.084198
#
# True
# 0_6_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : 6 , pvalue : 0.0000000
#
# 0	0_6_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 8.383000, p-value : 0.005224
#
# False
# 0_6_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 11 , pvalue : 0.0000000
#
# 0	0_6_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 3.385567, p-value : 0.070557
#
# True
# 0_6_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 8 , pvalue : 0.0000000
#
# 0	0_6_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.946643, p-value : 0.334356
#
# True
# 0_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 7 , pvalue : 0.0000000
#
# 0	1_3_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.802239, p-value : 0.184337
#
# True
# 1_3_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : -7 , pvalue : 0.0000000
#
# 0	1_3_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.416335, p-value : 0.238545
#
# True
# 1_3_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : -6 , pvalue : 0.0000000
#
# 0	1_3_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.930792, p-value : 0.338405
#
# True
# 1_3_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : -8 , pvalue : 0.0000000
#
# 0	1_3_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 1_3_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	1_3_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.554476, p-value : 0.459308
#
# True
# 1_3_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0481375
#
# 0	1_3_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 3.094755, p-value : 0.083479
#
# True
# 1_3_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0393505
#
# 0	1_3_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.657575, p-value : 0.420519
#
# True
# 1_3_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.5925955
#
# 0	1_3_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.002964, p-value : 0.956755
#
# True
# 1_3_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -1 , pvalue : 0.2818228
#
# 0	3_6_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 4.326323, p-value : 0.041668
#
# False
# 3_6_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : -6 , pvalue : 0.0000001
#
# 0	3_6_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 3.832972, p-value : 0.054758
#
# True
# 3_6_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : -5 , pvalue : 0.0000043
#
# 0	3_6_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 3.080062, p-value : 0.084198
#
# True
# 3_6_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : -6 , pvalue : 0.0000000
#
# 0	3_6_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.554476, p-value : 0.459308
#
# True
# 3_6_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0481375
#
# 0	3_6_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 3_6_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	3_6_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.982336, p-value : 0.325475
#
# True
# 3_6_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 4 , pvalue : 0.0000073
#
# 0	3_6_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.002940, p-value : 0.956936
#
# True
# 3_6_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 1 , pvalue : 0.1038645
#
# 0	3_6_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.743156, p-value : 0.391974
#
# True
# 3_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.3722203
#
# 0	end_1_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 9.650735, p-value : 0.002854
#
# False
# end_1_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : -10 , pvalue : 0.0000000
#
# 0	end_1_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 9.294769, p-value : 0.003377
#
# False
# end_1_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : -9 , pvalue : 0.0000000
# 0	end_1_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 8.383000, p-value : 0.005224
#
# False
# end_1_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : -11 , pvalue : 0.0000000
#
# 0	end_1_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 3.094755, p-value : 0.083479
#
# True
# end_1_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0393505
#
# 0	end_1_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.982336, p-value : 0.325475
#
# True
# end_1_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -4 , pvalue : 0.0000073
#
# 0	end_1_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_1_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	end_1_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.929071, p-value : 0.338849
#
# True
# end_1_모델 평가.csv end_3_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0029300
#
# 0	end_1_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 4.135173, p-value : 0.046287
#
# False
# end_1_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0009240
#
# 0	end_3_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 4.664904, p-value : 0.034660
#
# False
# end_3_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : -7 , pvalue : 0.0000000
#
# 0	end_3_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 4.166780, p-value : 0.045486
#
# False
# end_3_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : -6 , pvalue : 0.0000000
#
# 0	end_3_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 3.385567, p-value : 0.070557
#
# True
# end_3_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : -8 , pvalue : 0.0000000
#
# 0	end_3_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.657575, p-value : 0.420519
#
# True
# end_3_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.5925955
#
# 0	end_3_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.002940, p-value : 0.956936
#
# True
# end_3_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -1 , pvalue : 0.1038645
#
# 0	end_3_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.929071, p-value : 0.338849
#
# True
# end_3_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0029300
#
# 0	end_3_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_3_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	end_3_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.880399, p-value : 0.351733
#
# True
# end_3_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.5251307
#
# 0	end_6_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.864210, p-value : 0.177073
#
# True
# end_6_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : -6 , pvalue : 0.0000000
#
# 0	end_6_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.460857, p-value : 0.231383
#
# True
# end_6_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : -5 , pvalue : 0.0000006
#
# 0	end_6_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.946643, p-value : 0.334356
#
# True
# end_6_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : -7 , pvalue : 0.0000000
#
# 0	end_6_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.002964, p-value : 0.956755
#
# True
# end_6_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : 1 , pvalue : 0.2818228
#
# 0	end_6_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.743156, p-value : 0.391974
#
# True
# end_6_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.3722203
#
# 0	end_6_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 4.135173, p-value : 0.046287
#
# False
# end_6_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0009240
#
# 0	end_6_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.880399, p-value : 0.351733
#
# True
# end_6_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.5251307
#
# 0	end_6_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_1_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_1_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_1_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.012666, p-value : 0.910755
#
# True
# 0_1_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.8323819
#
# 0	0_1_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.330507, p-value : 0.567441
#
# True
# 0_1_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : -1 , pvalue : 0.2459906
#
# 0	0_1_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.231717, p-value : 0.631949
#
# True
# 0_1_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0021088
#
# 0	0_1_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.056533, p-value : 0.812846
#
# True
# 0_1_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.3318455
#
# 0	0_1_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.202063, p-value : 0.654629
#
# True
# 0_1_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0006561
#
# 0	0_1_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.188710, p-value : 0.665501
#
# True
# 0_1_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0087150
#
# 0	0_1_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.459524, p-value : 0.500368
#
# True
# 0_1_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0462298
#
# 0	0_3_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.012666, p-value : 0.910755
#
# True
# 0_3_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 0 , pvalue : 0.8323819
#
# 0	0_3_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_3_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_3_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.472230, p-value : 0.494526
#
# True
# 0_3_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.3550486
#
# 0	0_3_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.146733, p-value : 0.702988
#
# True
# 0_3_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0012841
#
# 0	0_3_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.017402, p-value : 0.895478
#
# True
# 0_3_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : 1 , pvalue : 0.2456125
#
# 0	0_3_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.124560, p-value : 0.725337
#
# True
# 0_3_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0003929
#
# 0	0_3_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.301033, p-value : 0.585206
#
# True
# 0_3_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0051924
#
# 0	0_3_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.316476, p-value : 0.575762
#
# True
# 0_3_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0305077
#
# 0	0_6_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.330507, p-value : 0.567441
#
# True
# 0_6_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 1 , pvalue : 0.2459906
#
# 0	0_6_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.472230, p-value : 0.494526
#
# True
# 0_6_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.3550486
#
# 0	0_6_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_6_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_6_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.948932, p-value : 0.333777
#
# True
# 0_6_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : 4 , pvalue : 0.0000394
#
# 0	0_6_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.597930, p-value : 0.442307
#
# True
# 0_6_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0354132
#
# 0	0_6_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.869895, p-value : 0.354602
#
# True
# 0_6_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 4 , pvalue : 0.0000098
#
# 0	0_6_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.023093, p-value : 0.879709
#
# True
# 0_6_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 4 , pvalue : 0.0001147
#
# 0	0_6_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.606990, p-value : 0.209656
#
# True
# 0_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0019459
#
# 0	1_3_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.231717, p-value : 0.631949
#
# True
# 1_3_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0021088
#
# 0	1_3_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.146733, p-value : 0.702988
#
# True
# 1_3_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0012841
#
# 0	1_3_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.948932, p-value : 0.333777
#
# True
# 1_3_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : -4 , pvalue : 0.0000394
# 0	1_3_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 1_3_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	1_3_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.062102, p-value : 0.804027
#
# True
# 1_3_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0314892
#
# 0	1_3_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000475, p-value : 0.982688
#
# True
# 1_3_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 0 , pvalue : 0.7129553
#
# 0	1_3_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.738305, p-value : 0.393515
#
# True
# 1_3_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.3840455
#
# 0	1_3_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.011214, p-value : 0.916005
#
# True
# 1_3_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -1 , pvalue : 0.2450826
#
# 0	3_6_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.056533, p-value : 0.812846
#
# True
# 3_6_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 0 , pvalue : 0.3318455
#
# 0	3_6_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.017402, p-value : 0.895478
#
# True
# 3_6_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : -1 , pvalue : 0.2456125
#
# 0	3_6_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.597930, p-value : 0.442307
#
# True
# 3_6_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0354132
#
# 0	3_6_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.062102, p-value : 0.804027
#
# True
# 3_6_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0314892
#
# 0	3_6_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 3_6_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	3_6_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.049554, p-value : 0.824573
#
# True
# 3_6_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0124647
#
# 0	3_6_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.416991, p-value : 0.520825
#
# True
# 3_6_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 1 , pvalue : 0.1212154
#
# 0	3_6_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.157377, p-value : 0.692945
#
# True
# 3_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 1 , pvalue : 0.3041311
#
# 0	end_1_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.202063, p-value : 0.654629
#
# True
# end_1_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0006561
#
# 0	end_1_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.124560, p-value : 0.725337
#
# True
# end_1_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0003929
#
# 0	end_1_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.869895, p-value : 0.354602
#
# True
# end_1_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : -4 , pvalue : 0.0000098
#
# 0	end_1_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000475, p-value : 0.982688
#
# True
# end_1_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.7129553
#
# 0	end_1_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.049554, p-value : 0.824573
#
# True
# end_1_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0124647
#
# 0	end_1_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_1_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	end_1_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.671725, p-value : 0.415590
#
# True
# end_1_모델 평가.csv end_3_모델 평가.csv
#
# statistic : -1 , pvalue : 0.2034994
#
# 0	end_1_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.016513, p-value : 0.898166
#
# True
# end_1_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -1 , pvalue : 0.1271349
#
# 0	end_3_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.188710, p-value : 0.665501
#
# True
# end_3_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0087150
#
# 0	end_3_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.301033, p-value : 0.585206
#
# True
# end_3_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0051924
#
# 0	end_3_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.023093, p-value : 0.879709
#
# True
# end_3_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : -4 , pvalue : 0.0001147
#
# 0	end_3_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.738305, p-value : 0.393515
#
# True
# end_3_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.3840455
#
# 0	end_3_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.416991, p-value : 0.520825
#
# True
# end_3_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -1 , pvalue : 0.1212154
#
# 0	end_3_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.671725, p-value : 0.415590
#
# True
# end_3_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 1 , pvalue : 0.2034994
#
# 0	end_3_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_3_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	end_3_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.286723, p-value : 0.261019
#
# True
# end_3_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.6761221
#
# 0	end_6_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.459524, p-value : 0.500368
#
# True
# end_6_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0462298
#
# 0	end_6_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.316476, p-value : 0.575762
#
# True
# end_6_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0305077
#
# 0	end_6_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.606990, p-value : 0.209656
#
# True
# end_6_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0019459
#
# 0	end_6_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.011214, p-value : 0.916005
#
# True
# end_6_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : 1 , pvalue : 0.2450826
#
# 0	end_6_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.157377, p-value : 0.692945
#
# True
# end_6_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -1 , pvalue : 0.3041311
#
# 0	end_6_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.016513, p-value : 0.898166
#
# True
# end_6_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 1 , pvalue : 0.1271349
#
# 0	end_6_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.286723, p-value : 0.261019
#
# True
# end_6_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.6761221
#
# 0	end_6_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_1_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_1_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_1_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.078003, p-value : 0.780951
#
# True
# 0_1_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 1 , pvalue : 0.2027754
#
# 0	0_1_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.011560, p-value : 0.914727
#
# True
# 0_1_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 1 , pvalue : 0.2247752
#
# 0	0_1_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.488820, p-value : 0.227020
#
# True
# 0_1_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -5 , pvalue : 0.0000004
#
# 0	0_1_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 2.064723, p-value : 0.155770
#
# True
# 0_1_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -4 , pvalue : 0.0000169
#
# 0	0_1_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.860583, p-value : 0.357173
#
# True
# 0_1_모델 평가.csv end_1_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0288271
#
# 0	0_1_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.671515, p-value : 0.415663
#
# True
# 0_1_모델 평가.csv end_3_모델 평가.csv
#
# statistic : -1 , pvalue : 0.0644265
#
# 0	0_1_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.397074, p-value : 0.530920
#
# True
# 0_1_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -1 , pvalue : 0.1037411
#
# 0	0_3_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.078003, p-value : 0.780951
#
# True
# 0_3_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : -1 , pvalue : 0.2027754
#
# 0	0_3_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_3_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_3_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.157332, p-value : 0.692987
#
# True
# 0_3_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.9739144
# 0	0_3_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 2.053827, p-value : 0.156848
#
# True
# 0_3_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -6 , pvalue : 0.0000000
#
# 0	0_3_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 2.786544, p-value : 0.100101
#
# True
# 0_3_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -5 , pvalue : 0.0000002
#
# 0	0_3_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.408707, p-value : 0.524982
#
# True
# 0_3_모델 평가.csv end_1_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0004868
#
# 0	0_3_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.283503, p-value : 0.596317
#
# True
# 0_3_모델 평가.csv end_3_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0016023
#
# 0	0_3_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.791950, p-value : 0.376951
#
# True
# 0_3_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0051360
#
# 0	0_6_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.011560, p-value : 0.914727
#
# True
# 0_6_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : -1 , pvalue : 0.2247752
#
# 0	0_6_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.157332, p-value : 0.692987
#
# True
# 0_6_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.9739144
#
# 0	0_6_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_6_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_6_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.354050, p-value : 0.249030
#
# True
# 0_6_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -6 , pvalue : 0.0000000
#
# 0	0_6_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.911512, p-value : 0.171755
#
# True
# 0_6_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -5 , pvalue : 0.0000004
#
# 0	0_6_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.153652, p-value : 0.286948
#
# True
# 0_6_모델 평가.csv end_1_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0007357
#
# 0	0_6_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.923269, p-value : 0.340351
#
# True
# 0_6_모델 평가.csv end_3_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0022790
#
# 0	0_6_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.302027, p-value : 0.584589
#
# True
# 0_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0065747
#
# 0	1_3_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.488820, p-value : 0.227020
#
# True
# 1_3_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 5 , pvalue : 0.0000004
#
# 0	1_3_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 2.053827, p-value : 0.156848
#
# True
# 1_3_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 6 , pvalue : 0.0000000
#
# 0	1_3_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.354050, p-value : 0.249030
#
# True
# 1_3_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 6 , pvalue : 0.0000000
#
# 0	1_3_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 1_3_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	1_3_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.007573, p-value : 0.930932
#
# True
# 1_3_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : 1 , pvalue : 0.3178633
#
# 0	1_3_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 3.762421, p-value : 0.056969
#
# True
# 1_3_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 4 , pvalue : 0.0000992
#
# 0	1_3_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 3.446345, p-value : 0.068145
#
# True
# 1_3_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 4 , pvalue : 0.0000440
#
# 0	1_3_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.453746, p-value : 0.503065
#
# True
# 1_3_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 4 , pvalue : 0.0001178
#
# 0	3_6_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 2.064723, p-value : 0.155770
#
# True
# 3_6_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 4 , pvalue : 0.0000169
#
# 0	3_6_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 2.786544, p-value : 0.100101
#
# True
# 3_6_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 5 , pvalue : 0.0000002
#
# 0	3_6_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.911512, p-value : 0.171755
#
# True
# 3_6_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 5 , pvalue : 0.0000004
#
# 0	3_6_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.007573, p-value : 0.930932
#
# True
# 3_6_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -1 , pvalue : 0.3178633
#
# 0	3_6_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 3_6_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	3_6_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 4.982296, p-value : 0.029231
#
# False
# 3_6_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0034562
#
# 0	3_6_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 4.577263, p-value : 0.036343
#
# False
# 3_6_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0016698
#
# 0	3_6_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.688588, p-value : 0.409829
#
# True
# 3_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0029847
#
# 0	end_1_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.860583, p-value : 0.357173
#
# True
# end_1_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0288271
#
# 0	end_1_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.408707, p-value : 0.524982
#
# True
# end_1_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0004868
#
# 0	end_1_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.153652, p-value : 0.286948
#
# True
# end_1_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0007357
#
# 0	end_1_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 3.762421, p-value : 0.056969
#
# True
# end_1_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -4 , pvalue : 0.0000992
#
# 0	end_1_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 4.982296, p-value : 0.029231
#
# False
# end_1_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0034562
#
# 0	end_1_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_1_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	end_1_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.011539, p-value : 0.914803
#
# True
# end_1_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.7216381
#
# 0	end_1_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 2.269355, p-value : 0.137033
#
# True
# end_1_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.7292724
#
# 0	end_3_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.671515, p-value : 0.415663
#
# True
# end_3_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 1 , pvalue : 0.0644265
#
# 0	end_3_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.283503, p-value : 0.596317
#
# True
# end_3_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0016023
#
# 0	end_3_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.923269, p-value : 0.340351
#
# True
# end_3_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0022790
#
# 0	end_3_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 3.446345, p-value : 0.068145
#
# True
# end_3_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -4 , pvalue : 0.0000440
#
# 0	end_3_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 4.577263, p-value : 0.036343
#
# False
# end_3_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0016698
#
# 0	end_3_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.011539, p-value : 0.914803
#
# True
# end_3_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 0 , pvalue : 0.7216381
#
# 0	end_3_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_3_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	end_3_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.971762, p-value : 0.165251
#
# True
# end_3_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.9739891
#
# 0	end_6_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.397074, p-value : 0.530920
#
# True
# end_6_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 1 , pvalue : 0.1037411
#
# 0	end_6_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.791950, p-value : 0.376951
#
# True
# end_6_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0051360
#
# 0	end_6_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.302027, p-value : 0.584589
#
# True
# end_6_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0065747
#
# 0	end_6_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.453746, p-value : 0.503065
#
# True
# end_6_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -4 , pvalue : 0.0001178
#
# 0	end_6_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.688588, p-value : 0.409829
#
# True
# end_6_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0029847
#
# 0	end_6_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 2.269355, p-value : 0.137033
#
# True
# end_6_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 0 , pvalue : 0.7292724
#
# 0	end_6_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.971762, p-value : 0.165251
#
# True
# end_6_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.9739891
#
# 0	end_6_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000

# %%
path_dir = 'Result/랜덤포레스트/종속변수 수익률' 
file_list = os.listdir(path_dir)
file_list = file_list[:-1]
file_list
# Out:
# ['0_1_수익률.csv',
#  '0_3_수익률.csv',
#  '0_6_수익률.csv',
#  '1_3_수익률.csv',
#  '3_6_수익률.csv',
#  'end_1_수익률.csv',
#  'end_3_수익률.csv',
#  'end_6_수익률.csv']

# %%
def sign(pval):
    if(pval <= 0.01):
        return "***"
    elif(pval <= 0.05):
        return "**"
    elif(pval<= 0.1):
        return "*"
    else:
        return ""

# %%
path_dir = 'Result/랜덤포레스트/종속변수 수익률' 
file_list = os.listdir(path_dir)
file_list = file_list[:-1]
file_list
# Out:
# ['0_1_수익률.csv',
#  '0_3_수익률.csv',
#  '0_6_수익률.csv',
#  '1_3_수익률.csv',
#  '3_6_수익률.csv',
#  'end_1_수익률.csv',
#  'end_3_수익률.csv',
#  'end_6_수익률.csv']

# %%
indexes = ['buy_sell수익률','buy수익률']
Total_Stat = np.array([])
Mean_Stat = np.array([])
for file in file_list:
    for index in indexes:
        
        df = pd.read_csv(path_dir + "//" + file, encoding = 'cp949',index_col = 0)
        left_value = df.loc[index,:].drop('mean').fillna(0)
        right_value = df.loc['all수익률',:].drop('mean').fillna(0)
        
        
        stat, pval = Ttest(left_value,right_value)

        left_mean = np.mean(left_value)
        right_mean = np.mean(right_value)

        star = sign(pval)

        Statstr = str(np.round(left_mean - right_mean,3)) + "(" + str(np.round(stat,3)) + star +  ")"
        
        Total_Stat = np.append(Total_Stat, Statstr)
    Mean_Stat = np.append(Mean_Stat, df.loc[:,'mean'])
        

Mean_df = pd.DataFrame(Mean_Stat.reshape(8,3), columns = indexes + ['All_Buy'], index = file_list)
Diff_df = pd.DataFrame(Total_Stat.reshape(8,2), columns = indexes, index = file_list)
Total_df = pd.concat([Mean_df,Diff_df], axis = 1)
print(Total_df)
Total_df.to_csv(path_dir+ '//' + 'Ret.csv', encoding = 'euc-kr')
# Out:
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.605240, p-value : 0.439545
#
# True
#
# statistic : -2 , pvalue : 0.9884908
#
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.013551, p-value : 0.907704
#
# True
#
# statistic : 0 , pvalue : 0.2919757
#
# 0	 & 	Measure :
#
# LeveneResult -- stat : 2.701696, p-value : 0.105304
#
# True
#
# statistic : -3 , pvalue : 0.9993792
#
# 0	 & 	Measure :
#
# LeveneResult -- stat : 1.111213, p-value : 0.295909
#
# True
#
# statistic : 0 , pvalue : 0.5986674
#
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.001773, p-value : 0.966545
#
# True
#
# statistic : -2 , pvalue : 0.9920192
#
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.056566, p-value : 0.812793
#
# True
#
# statistic : 0 , pvalue : 0.6286448
#
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.405114, p-value : 0.526803
#
# True
#
# statistic : -1 , pvalue : 0.9316755
#
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.009576, p-value : 0.922362
#
# True
#
# statistic : 0 , pvalue : 0.5638137
#
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.001177, p-value : 0.972739
#
# True
#
# statistic : -1 , pvalue : 0.8623617
#
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.435819, p-value : 0.511593
#
# True
#
# statistic : 0 , pvalue : 0.4561282
#
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.315137, p-value : 0.576568
#
# True
#
# statistic : 0 , pvalue : 0.6099980
#
# 0	 & 	Measure :
#
# LeveneResult -- stat : 1.183953, p-value : 0.280764
#
# True
#
# statistic : -1 , pvalue : 0.8934760
#
# 0	 & 	Measure :
#
# LeveneResult -- stat : 1.262211, p-value : 0.265564
#
# True
#
# statistic : 0 , pvalue : 0.4251404
#
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.000156, p-value : 0.990089
#
# True
#
# statistic : 0 , pvalue : 0.6815515
#
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.873955, p-value : 0.353490
#
# True
#
# statistic : -1 , pvalue : 0.9002885
#
# 0	 & 	Measure :
#
# LeveneResult -- stat : 1.164863, p-value : 0.284640
#
# True
#
# statistic : 0 , pvalue : 0.5315287
#
#               buy_sell수익률    buy수익률   All_Buy     buy_sell수익률          buy수익률
# 0_1_수익률.csv      0.209068  0.349550  0.324157  -0.115(-2.331)    0.025(0.551)
# 0_3_수익률.csv      0.179638  0.323587  0.334694  -0.155(-3.384)  -0.011(-0.251)
# 0_6_수익률.csv      0.261980  0.398976  0.419719  -0.158(-2.478)   -0.021(-0.33)
# 1_3_수익률.csv      0.010167  0.029925  0.032461  -0.022(-1.508)  -0.003(-0.161)
# 3_6_수익률.csv      0.053516  0.079581  0.071989  -0.022(-1.101)    0.003(0.111)
# end_1_수익률.csv   -0.017119 -0.038540 -0.011650  -0.005(-0.281)  -0.027(-1.258)
# end_3_수익률.csv    0.020764  0.002828  0.016261     0.005(0.19)  -0.013(-0.474)
# end_6_수익률.csv    0.040113  0.085683  0.086911  -0.047(-1.297)  -0.004(-0.079)

# %%
pd.DataFrame(Total_Stat.reshape(8,8))
# Out:
#                                             0  \
# 0                                    0.0(0.0)
# 1    0.010791006569172978(1.2307739411138343)
# 2    0.009636617085292287(0.9886032508940178)
# 3  0.08740641545178351(10.673787529438743***)
# 4   0.07812182827731029(7.963908622840538***)
# 5     0.043181035123114(4.507254772107314***)
# 6   0.019623804476501583(2.149010723209109**)
# 7    0.009243238396958398(1.0121738120414685)
#
#                                               1  \
# 0    -0.010791006569172978(-1.2307739411138343)
# 1                                      0.0(0.0)
# 2  -0.0011543894838806912(-0.14032345663910045)
# 3    0.07661540888261054(12.156968845267894***)
# 4     0.06733082170813731(8.112405983114682***)
# 5     0.03239002855394102(4.034827004389541***)
# 6      0.008832797907328604(1.1798594071764854)
# 7  -0.0015477681722145809(-0.20672905884918047)
#
#                                                2  \
# 0     -0.009636617085292287(-0.9886032508940178)
# 1     0.0011543894838806912(0.14032345663910045)
# 2                                       0.0(0.0)
# 3     0.07776979836649123(10.223715670741734***)
# 4        0.068485211192018(7.341052601698767***)
# 5     0.03354441803782171(3.6911384352553793***)
# 6       0.009987187391209296(1.1594924587268494)
# 7  -0.00039337868833388967(-0.04566759046834486)
#
#                                               3  \
# 0  -0.08740641545178351(-10.673787529438743***)
# 1  -0.07661540888261054(-12.156968845267894***)
# 2  -0.07776979836649123(-10.223715670741734***)
# 3                                      0.0(0.0)
# 4     -0.009284587174473224(-1.208017634982015)
# 5   -0.04422538032866952(-5.983588827655985***)
# 6   -0.06778261097528193(-9.969014221960535***)
# 7  -0.07816317705482512(-11.494552279659166***)
#
#                                               4  \
# 0   -0.07812182827731029(-7.963908622840538***)
# 1   -0.06733082170813731(-8.112405983114682***)
# 2     -0.068485211192018(-7.341052601698767***)
# 3       0.009284587174473224(1.208017634982015)
# 4                                      0.0(0.0)
# 5  -0.03494079315419629(-3.8169753690540396***)
# 6  -0.05849802380080871(-6.7368732605803014***)
# 7  -0.06887858988035189(-7.9318484890559136***)
#
#                                                5  \
# 0      -0.043181035123114(-4.507254772107314***)
# 1    -0.03239002855394102(-4.034827004389541***)
# 2   -0.03354441803782171(-3.6911384352553793***)
# 3      0.04422538032866952(5.983588827655985***)
# 4     0.03494079315419629(3.8169753690540396***)
# 5                                       0.0(0.0)
# 6  -0.023557230646612415(-2.7965962085031517***)
# 7     -0.0339377967261556(-4.028658575140418***)
#
#                                              6  \
# 0  -0.019623804476501583(-2.149010723209109**)
# 1   -0.008832797907328604(-1.1798594071764854)
# 2   -0.009987187391209296(-1.1594924587268494)
# 3    0.06778261097528193(9.969014221960535***)
# 4   0.05849802380080871(6.7368732605803014***)
# 5  0.023557230646612415(2.7965962085031517***)
# 6                                     0.0(0.0)
# 7   -0.010380566079543185(-1.3123389021500662)
#
#                                              7
# 0   -0.009243238396958398(-1.0121738120414685)
# 1   0.0015477681722145809(0.20672905884918047)
# 2  0.00039337868833388967(0.04566759046834486)
# 3   0.07816317705482512(11.494552279659166***)
# 4   0.06887858988035189(7.9318484890559136***)
# 5     0.0339377967261556(4.028658575140418***)
# 6     0.010380566079543185(1.3123389021500662)
# 7                                     0.0(0.0)

# %%
from scipy import stats
def Ttest(x,y, Number = 0 , leftstr = "", rightstr= "", Measure = ""):
    print(str(Number)+"\t"+leftstr + " & " + rightstr + "\tMeasure : " + Measure + "\n")
    _stat,_pvalue = stats.levene(x,y)
    print("LeveneResult -- stat : %3f, p-value : %3f \n" %(_stat, _pvalue))
    if _pvalue < 0.05:
        equal_Var = False
    else :
        equal_Var = True
    print(equal_Var)
    statistic , pvalue = stats.ttest_ind(x,y, equal_var= equal_Var,alternative='greater')
    print("\nstatistic : %d , pvalue : %.7f\n" % (statistic, pvalue))
    return (statistic, pvalue)

# %%
Trading = ['3개월 평균 거래량회전율','3개월 평균 일중변동률','3개월 시가총액회전율',
           '1개월 평균 거래량회전율','1개월 평균 일중변동률','1개월 시가총액회전율', '개인거래비중']
Market = ['3달 후 시장 회전율','3달 후 시장수익률','3달 후 고객예탁금 증감률',
          '1달 후 시장 회전율','1달 후 시장수익률','1달 후 고객예탁금 증감률',
          '1년전 대비 시장 회전율','1년 전 대비 시장수익률','1년 전 대비 고객예탁금 증감률','상장일 기준 국고3년시장금리']
Value = ['3개월 후 EV/EBITDA', '3개월 후 PBR', '3개월 후 PER'
         ,'1개월 후 EV/EBITDA', '1개월 후 PBR', '1개월 후 PER'
        ,'종가_EV/EBITDA', '종가_PBR', '종가_PER','IPO_EV/EBITDA', 'IPO_PBR', 'IPO_PER']
Finance = ['매출액증가율', '부채비율','유동비율','매출총이익률']
Indexes = [Trading, Market, Value, Finance]

# %%
path_dir = 'Result/랜덤포레스트/feature 값' 
file_list = os.listdir(path_dir)
print(file_list)
# Out:
# ['0_1_feature별 값.csv', '0_3_feature별 값.csv', '0_6_feature별 값.csv', '1_3_feature별 값.csv', '3_6_feature별 값.csv', 'end_1_feature별 값.csv', 'end_3_feature별 값.csv', 'end_6_feature별 값.csv']

# %%
for i in range(4):
    Total_Stat = np.array([])
    for left in file_list:
        for right in file_list:   
            left_df = pd.read_csv(path_dir + "//" + left, encoding = 'cp949',index_col = 0)
            right_df = pd.read_csv(path_dir + "//" + right, encoding = 'cp949',index_col = 0)
            left_value = left_df.iloc[i,:]
            right_value = right_df.iloc[i,:]
            stat, pval = Ttest(left_value,right_value,leftstr = left , rightstr = right)

            left_mean = np.mean(left_value)
            right_mean = np.mean(right_value)

            star = sign(pval)

            Statstr = str(np.round(left_mean - right_mean,2)) + "(" + str(np.round(stat,2)) + star +  ")"
            Total_Stat = np.append(Total_Stat, Statstr)
            statistics = np.append(statistics, stat)
            pvalues = np.append(pvalues, pval)


    Total_df = pd.DataFrame(Total_Stat.reshape(8,8), index = file_list, columns = file_list)

    Total_df.to_csv(path_dir+ '//' + str(i) + '.csv', encoding = 'euc-kr')

# %%
df_0_1 = pd.read_csv("Result/랜덤포레스트/feature 값/0_1_feature별 값.csv",index_col = 0,encoding = 'cp949')
df_0_3 = pd.read_csv("Result/랜덤포레스트/feature 값/0_3_feature별 값.csv",index_col = 0,encoding = 'cp949')
df_0_6 = pd.read_csv("Result/랜덤포레스트/feature 값/0_6_feature별 값.csv",index_col = 0,encoding = 'cp949')
df_1_3 = pd.read_csv("Result/랜덤포레스트/feature 값/1_3_feature별 값.csv",index_col = 0,encoding = 'cp949')
df_3_6 = pd.read_csv("Result/랜덤포레스트/feature 값/3_6_feature별 값.csv",index_col = 0,encoding = 'cp949')
df_end_1 = pd.read_csv("Result/랜덤포레스트/feature 값/end_1_feature별 값.csv",index_col = 0,encoding = 'cp949')
df_end_3 = pd.read_csv("Result/랜덤포레스트/feature 값/end_3_feature별 값.csv",index_col = 0,encoding = 'cp949')
df_end_6 = pd.read_csv("Result/랜덤포레스트/feature 값/end_6_feature별 값.csv",index_col = 0,encoding = 'cp949')

# %%
df_0_1["mean"] = df_0_1.mean(axis=1)

# %%
a = df_1["Market":"Finance"]['mean']

# %%
df_1_3["mean"] = df_1_3.mean(axis=1)

# %%
b = df_1_3["Trading":"Finance"]['mean']

# %%
pd.concat([a,b],axis = 1)
# Out:
#              mean      mean
# Market   0.087553  0.057841
# Value    0.105933  0.060601
# Finance  0.082997  0.068125
# Trading       NaN  0.078583

# %%
df_0_1 = pd.read_csv("Result/랜덤포레스트/모델 평가/0_1_모델 평가.csv",index_col = 0,encoding = 'cp949')

# %%
path_dir = 'Result/랜덤포레스트/모델 평가' 
file_list = os.listdir(path_dir)
file_list = file_list[1:]
file_list
# Out:
# ['0_3_모델 평가.csv',
#  '0_6_모델 평가.csv',
#  '1_3_모델 평가.csv',
#  '3_6_모델 평가.csv',
#  'end_1_모델 평가.csv',
#  'end_3_모델 평가.csv',
#  'end_6_모델 평가.csv']

# %%
file_list

# %%
df_0_1['mean'] = df_0_1.mean(axis =1)

# %%
first = df_0_1['mean']
first
# Out:
# 정확도              0.702678
# 정밀도              0.726528
# 재현율              0.805926
# f1_score         0.709760
# 정확도_test         0.322484
# 정밀도_test         0.476976
# 재현율_test         0.558717
# f1_score_test    0.304779
# Name: mean, dtype: float64

# %%
for file in file_list:
    df = pd.read_csv(path_dir + "//" + file, encoding = 'cp949',index_col = 0)
    df["mean"] = df.mean(axis=1)
    mean = df['mean']
    

    first = pd.concat([first,mean],axis = 1)

# %%
name = ['공모가 대비 1개월']+ ['공모가 대비 3개월']+ ['공모가 대비 6개월'] + ['1개월 대비 3개월']  + ["3개월 대비 6개월"]+ ["종가 대비 1개월"] +["종가 대비 3개월"] + ["종가 대비 6개월"]

# %%
first.columns = name

# %%
first = first.fillna(0)

# %%
first.to_csv("model_mean.csv",encoding = 'euc-kr')

# %%
first
# Out:
#                공모가 대비 1개월  공모가 대비 3개월  공모가 대비 6개월  1개월 대비 3개월  3개월 대비 6개월  \
# 정확도              0.702678    0.711681    0.708799    0.751788    0.758222
# 정밀도              0.726528    0.760678    0.756261    0.533136    0.566963
# 재현율              0.805926    0.820408    0.809581    0.885461    0.890525
# f1_score         0.709760    0.716601    0.711858    0.769210    0.770614
# 정확도_test         0.322484    0.295076    0.298267    0.412636    0.397942
# 정밀도_test         0.476976    0.423040    0.468236    0.173254    0.238313
# 재현율_test         0.558717    0.571723    0.625746    0.347425    0.497204
# f1_score_test    0.304779    0.278729    0.279393    0.450419    0.421061
#
#                종가 대비 1개월  종가 대비 3개월  종가 대비 6개월
# 정확도             0.686400   0.714670   0.703720
# 정밀도             0.454040   0.568566   0.586102
# 재현율             0.910203   0.876989   0.869709
# f1_score        0.701613   0.723993   0.710874
# 정확도_test        0.319387   0.334460   0.337308
# 정밀도_test        0.112824   0.190362   0.210109
# 재현율_test        0.321138   0.402798   0.428510
# f1_score_test   0.348128   0.341637   0.340955

# %%
index = ["Market","Value","Finance","Trading"]

# %%
Total_Stat = np.array([])
for left in index:
    for right in index:
        left_value = first.loc[left]
        right_value = first.loc[right]
        
        stat,pval = Ttest(left_value,right_value)
        left_mean = left_value.mean()
        right_mean = right_value.mean()
        star = sign(pval)

        Statstr = str(np.round(left_mean - right_mean,3)) + "(" + str(np.round(stat,3)) + star +  ")"
        Total_Stat = np.append(Total_Stat,Statstr)
        
Total_df = pd.DataFrame(Total_Stat.reshape(4,4), columns = index, index = index)

Total_df.to_csv(path_dir+ '//' + 'feature.csv', encoding = 'euc-kr')
# Out:
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# Market Market
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.113516, p-value : 0.741174
#
# True
# Market Value
#
# statistic : 0 , pvalue : 0.7132597
#
# 0	 & 	Measure :
#
# LeveneResult -- stat : 1.286523, p-value : 0.275738
#
# True
# Market Finance
#
# statistic : 2 , pvalue : 0.0505630
#
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.414622, p-value : 0.530041
#
# True
# Market Trading
#
# statistic : 4 , pvalue : 0.0007718
#
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.113516, p-value : 0.741174
#
# True
# Value Market
#
# statistic : 0 , pvalue : 0.7132597
#
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# Value Value
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	 & 	Measure :
#
# LeveneResult -- stat : 1.387477, p-value : 0.258467
#
# True
# Value Finance
#
# statistic : 2 , pvalue : 0.0535617
#
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.181950, p-value : 0.676189
#
# True
# Value Trading
#
# statistic : 4 , pvalue : 0.0007870
#
# 0	 & 	Measure :
#
# LeveneResult -- stat : 1.286523, p-value : 0.275738
#
# True
# Finance Market
#
# statistic : -2 , pvalue : 0.0505630
#
# 0	 & 	Measure :
#
# LeveneResult -- stat : 1.387477, p-value : 0.258467
#
# True
# Finance Value
#
# statistic : -2 , pvalue : 0.0535617
#
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# Finance Finance
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	 & 	Measure :
#
# LeveneResult -- stat : 1.160277, p-value : 0.299620
#
# True
# Finance Trading
#
# statistic : 3 , pvalue : 0.0032808
#
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.414622, p-value : 0.530041
#
# True
# Trading Market
#
# statistic : -4 , pvalue : 0.0007718
#
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.181950, p-value : 0.676189
#
# True
# Trading Value
#
# statistic : -4 , pvalue : 0.0007870
#
# 0	 & 	Measure :
#
# LeveneResult -- stat : 1.160277, p-value : 0.299620
#
# True
# Trading Finance
#
# statistic : -3 , pvalue : 0.0032808
#
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# Trading Trading
#
# statistic : 0 , pvalue : 1.0000000

# %%
df = pd.read_csv("Resut")

# %%
path_dir = 'Result/랜덤포레스트/feature 값' 
file_list = os.listdir(path_dir)
print(file_list)
# Out:
# ['0_1_feature 값.csv', '0_3_feature 값.csv', '0_6_feature 값.csv', '1_3_feature 값.csv', '3_6_feature 값.csv', 'end_1_feature 값.csv', 'end_3_feature 값.csv', 'end_6_feature 값.csv', 'feature.csv', 'feature_mean.csv']

# %%
path_dir = 'Result/랜덤포레스트/feature 값' 
file_list = os.listdir(path_dir)
file_list = file_list[:-2]
file_list
# Out:
# ['0_1_feature 값.csv',
#  '0_3_feature 값.csv',
#  '0_6_feature 값.csv',
#  '1_3_feature 값.csv',
#  '3_6_feature 값.csv',
#  'end_1_feature 값.csv',
#  'end_3_feature 값.csv',
#  'end_6_feature 값.csv']

# %%
df_0_1 = pd.read_csv("Result/랜덤포레스트/feature 값/0_1_feature 값.csv",index_col = 0,encoding = 'cp949')
df_0_3 = pd.read_csv("Result/랜덤포레스트/feature 값/0_3_feature 값.csv",index_col = 0,encoding = 'cp949')
df_0_6 = pd.read_csv("Result/랜덤포레스트/feature 값/0_6_feature 값.csv",index_col = 0,encoding = 'cp949')
df_1_3 = pd.read_csv("Result/랜덤포레스트/feature 값/1_3_feature 값.csv",index_col = 0,encoding = 'cp949')
df_3_6 = pd.read_csv("Result/랜덤포레스트/feature 값/3_6_feature 값.csv",index_col = 0,encoding = 'cp949')
df_end_1 = pd.read_csv("Result/랜덤포레스트/feature 값/end_1_feature 값.csv",index_col = 0,encoding = 'cp949')
df_end_3 = pd.read_csv("Result/랜덤포레스트/feature 값/end_3_feature 값.csv",index_col = 0,encoding = 'cp949')
df_end_6 = pd.read_csv("Result/랜덤포레스트/feature 값/end_6_feature 값.csv",index_col = 0,encoding = 'cp949')

# %%
for file in file_list:
    F_Is = pd.read_csv(path_dir+'//'+file, encoding = 'cp949')
    F_Is.set_index('Unnamed: 0', inplace = True)
    F_Is.index.name = 'index'
    
    DataFrame = []
    
    for col in range(F_Is.shape[1]):
        Means = []
        Used_Indexes = []
        for index in Indexes:
            Values = []
            for indicator in index:
                F_I = F_Is.iloc[:,col]
                try:
                    value = F_I.loc[indicator]
                    Values.append(value)
                except:
                    continue
                    
            if (len(Values) == 0):
                continue
            else :
                Used_Indexes.append(str(index))
                Feature_Importance_mean = np.mean(Values)
                Means.append(Feature_Importance_mean)
        
        DataFrame.append(Means)
    Mean_df = pd.DataFrame(DataFrame).T
    if (Mean_df.shape[0] == 3 ):
        Mean_df.index = ['Market','Value','Finance']
        Mean_df.columns = F_Is.columns
    elif (Mean_df.shape[0] == 4 ):
        Mean_df.index = ['Trading','Market','Value','Finance']
        Mean_df.columns = F_Is.columns
    Total_df = pd.concat([F_Is,Mean_df])
    Total_df.to_csv(path_dir+ '//' +file, encoding = 'euc-kr')

# %%
path_dir = 'Result/랜덤포레스트/feature 값' 
file_list = os.listdir(path_dir)
print(file_list)
# Out:
# ['0_1_feature 값.csv', '0_3_feature 값.csv', '0_6_feature 값.csv', '1_3_feature 값.csv', '3_6_feature 값.csv', 'end_1_feature 값.csv', 'end_3_feature 값.csv', 'end_6_feature 값.csv']

# %%
index_2 = ["Market","Value","Finance","Trading"]
index_1 = ["Market","Value","Finance"]

# %%
file_list_1 = ['0_1_feature 값.csv', '0_3_feature 값.csv','0_6_feature 값.csv','end_1_feature 값.csv', 'end_3_feature 값.csv', 'end_6_feature 값.csv']

# %%
for file in file_list_1:
    Total_Stat = np.array([])
    for index in index_1:
        for idx in index_1:
            
            left_value = df.loc[index,:]
            right_value = df.loc[idx,:]
            print(left_value)
            print(right_value)

            stat, pval = Ttest(left_value,right_value)

            left_mean = np.mean(left_value)
            right_mean = np.mean(right_value)

            star = sign(pval)

            Statstr = str(np.round(left_mean - right_mean,3)) + "(" + str(np.round(stat,3)) + star +  ")"
            Total_Stat = np.append(Total_Stat, Statstr)
            print(Total_Stat)

        Total_df = pd.DataFrame(Total_Stat.reshape(3,3), columns = indexes, index = file_list)
# Out:
# model_set_0     0.110856
# model_set_1     0.061340
# model_set_2     0.110395
# model_set_3     0.094073
# model_set_4     0.103271
# model_set_5     0.093130
# model_set_6     0.076498
# model_set_7     0.113900
# model_set_8     0.094577
# model_set_9     0.077697
# model_set_10    0.065470
# model_set_11    0.071332
# model_set_12    0.075622
# model_set_13    0.067577
# model_set_14    0.088432
# model_set_15    0.081763
# model_set_16    0.091216
# model_set_17    0.061038
# model_set_18    0.099845
# model_set_19    0.088660
# model_set_20    0.103828
# model_set_21    0.100540
# model_set_22    0.108222
# model_set_23    0.122941
# model_set_24    0.116627
# model_set_25    0.064850
# model_set_26    0.073707
# model_set_27    0.088068
# model_set_28    0.070094
# model_set_29    0.088676
# model_set_30    0.097252
# model_set_31    0.108722
# Name: Market, dtype: float64
# model_set_0     0.110856
# model_set_1     0.061340
# model_set_2     0.110395
# model_set_3     0.094073
# model_set_4     0.103271
# model_set_5     0.093130
# model_set_6     0.076498
# model_set_7     0.113900
# model_set_8     0.094577
# model_set_9     0.077697
# model_set_10    0.065470
# model_set_11    0.071332
# model_set_12    0.075622
# model_set_13    0.067577
# model_set_14    0.088432
# model_set_15    0.081763
# model_set_16    0.091216
# model_set_17    0.061038
# model_set_18    0.099845
# model_set_19    0.088660
# model_set_20    0.103828
# model_set_21    0.100540
# model_set_22    0.108222
# model_set_23    0.122941
# model_set_24    0.116627
# model_set_25    0.064850
# model_set_26    0.073707
# model_set_27    0.088068
# model_set_28    0.070094
# model_set_29    0.088676
# model_set_30    0.097252
# model_set_31    0.108722
# Name: Market, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# ['0.0(0.0)']
# model_set_0     0.110856
# model_set_1     0.061340
# model_set_2     0.110395
# model_set_3     0.094073
# model_set_4     0.103271
# model_set_5     0.093130
# model_set_6     0.076498
# model_set_7     0.113900
# model_set_8     0.094577
# model_set_9     0.077697
# model_set_10    0.065470
# model_set_11    0.071332
# model_set_12    0.075622
# model_set_13    0.067577
# model_set_14    0.088432
# model_set_15    0.081763
# model_set_16    0.091216
# model_set_17    0.061038
# model_set_18    0.099845
# model_set_19    0.088660
# model_set_20    0.103828
# model_set_21    0.100540
# model_set_22    0.108222
# model_set_23    0.122941
# model_set_24    0.116627
# model_set_25    0.064850
# model_set_26    0.073707
# model_set_27    0.088068
# model_set_28    0.070094
# model_set_29    0.088676
# model_set_30    0.097252
# model_set_31    0.108722
# Name: Market, dtype: float64
# model_set_0     0.093302
# model_set_1     0.096880
# model_set_2     0.093601
# model_set_3     0.110484
# model_set_4     0.091915
# model_set_5     0.109910
# model_set_6     0.131220
# model_set_7     0.116077
# model_set_8     0.134529
# model_set_9     0.152087
# model_set_10    0.150468
# model_set_11    0.120793
# model_set_12    0.147148
# model_set_13    0.125215
# model_set_14    0.132153
# model_set_15    0.139921
# model_set_16    0.134091
# model_set_17    0.157742
# model_set_18    0.129563
# model_set_19    0.128261
# model_set_20    0.124977
# model_set_21    0.116675
# model_set_22    0.128376
# model_set_23    0.114574
# model_set_24    0.115582
# model_set_25    0.152000
# model_set_26    0.141729
# model_set_27    0.139813
# model_set_28    0.162521
# model_set_29    0.150424
# model_set_30    0.117538
# model_set_31    0.106605
# Name: Value, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.157577, p-value : 0.692760
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -8 , pvalue : 0.0000000
#
# ['0.0(0.0)' '-0.037(-8.067***)']
# model_set_0     0.110856
# model_set_1     0.061340
# model_set_2     0.110395
# model_set_3     0.094073
# model_set_4     0.103271
# model_set_5     0.093130
# model_set_6     0.076498
# model_set_7     0.113900
# model_set_8     0.094577
# model_set_9     0.077697
# model_set_10    0.065470
# model_set_11    0.071332
# model_set_12    0.075622
# model_set_13    0.067577
# model_set_14    0.088432
# model_set_15    0.081763
# model_set_16    0.091216
# model_set_17    0.061038
# model_set_18    0.099845
# model_set_19    0.088660
# model_set_20    0.103828
# model_set_21    0.100540
# model_set_22    0.108222
# model_set_23    0.122941
# model_set_24    0.116627
# model_set_25    0.064850
# model_set_26    0.073707
# model_set_27    0.088068
# model_set_28    0.070094
# model_set_29    0.088676
# model_set_30    0.097252
# model_set_31    0.108722
# Name: Market, dtype: float64
# model_set_0     0.096881
# model_set_1     0.131335
# model_set_2     0.097003
# model_set_3     0.096582
# model_set_4     0.103610
# model_set_5     0.097719
# model_set_6     0.094211
# model_set_7     0.077517
# model_set_8     0.078170
# model_set_9     0.077662
# model_set_10    0.088047
# model_set_11    0.105906
# model_set_12    0.082922
# model_set_13    0.105406
# model_set_14    0.084561
# model_set_15    0.083737
# model_set_16    0.081019
# model_set_17    0.085915
# model_set_18    0.077944
# model_set_19    0.087309
# model_set_20    0.078396
# model_set_21    0.087089
# model_set_22    0.072551
# model_set_23    0.071863
# model_set_24    0.075844
# model_set_25    0.087362
# model_set_26    0.088423
# model_set_27    0.079089
# model_set_28    0.075539
# model_set_29    0.070675
# model_set_30    0.088907
# model_set_31    0.088505
# Name: Finance, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 6.088129, p-value : 0.016384
#
# False
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.5557192
#
# ['0.0(0.0)' '-0.037(-8.067***)' '0.002(0.593)']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-245-e2325f0f43f5> in <module>
#      20             print(Total_Stat)
#      21
# ---> 22         Total_df = pd.DataFrame(Total_Stat.reshape(3,3), columns = indexes, index = file_list)
#      23
#      24         Total_df.to_csv(path_dir+ '//' + 'feature.csv', encoding = 'euc-kr')
#
# ValueError: cannot reshape array of size 3 into shape (3,3)

# %%
file_list_1 = ['0_1_feature 값.csv', '0_3_feature 값.csv','0_6_feature 값.csv','end_1_feature 값.csv', 'end_3_feature 값.csv', 'end_6_feature 값.csv']

# %%
for file in file_list_1:
    Total_Stat = np.array([])
    for index in index_1:
        for idx in index_1:
            df = pd.read_csv(path_dir + "//" + file, encoding = 'cp949',index_col = 0)
            left_value = df.loc[index,:]
            right_value = df.loc[idx,:]
            print(left_value)
            print(right_value)

            stat, pval = Ttest(left_value,right_value)

            left_mean = np.mean(left_value)
            right_mean = np.mean(right_value)

            star = sign(pval)

            Statstr = str(np.round(left_mean - right_mean,3)) + "(" + str(np.round(stat,3)) + star +  ")"
            Total_Stat = np.append(Total_Stat, Statstr)
            print(Total_Stat)
    Total_df = pd.DataFrame(Total_Stat.reshape(3,3), columns = index_1, index = index_1)
    Total_df.to_csv(path_dir+ '//' + str(file[:4]) + '_mean.csv', encoding = 'euc-kr')
# Out:
# model_set_0     0.110856
# model_set_1     0.061340
# model_set_2     0.110395
# model_set_3     0.094073
# model_set_4     0.103271
# model_set_5     0.093130
# model_set_6     0.076498
# model_set_7     0.113900
# model_set_8     0.094577
# model_set_9     0.077697
# model_set_10    0.065470
# model_set_11    0.071332
# model_set_12    0.075622
# model_set_13    0.067577
# model_set_14    0.088432
# model_set_15    0.081763
# model_set_16    0.091216
# model_set_17    0.061038
# model_set_18    0.099845
# model_set_19    0.088660
# model_set_20    0.103828
# model_set_21    0.100540
# model_set_22    0.108222
# model_set_23    0.122941
# model_set_24    0.116627
# model_set_25    0.064850
# model_set_26    0.073707
# model_set_27    0.088068
# model_set_28    0.070094
# model_set_29    0.088676
# model_set_30    0.097252
# model_set_31    0.108722
# Name: Market, dtype: float64
# model_set_0     0.110856
# model_set_1     0.061340
# model_set_2     0.110395
# model_set_3     0.094073
# model_set_4     0.103271
# model_set_5     0.093130
# model_set_6     0.076498
# model_set_7     0.113900
# model_set_8     0.094577
# model_set_9     0.077697
# model_set_10    0.065470
# model_set_11    0.071332
# model_set_12    0.075622
# model_set_13    0.067577
# model_set_14    0.088432
# model_set_15    0.081763
# model_set_16    0.091216
# model_set_17    0.061038
# model_set_18    0.099845
# model_set_19    0.088660
# model_set_20    0.103828
# model_set_21    0.100540
# model_set_22    0.108222
# model_set_23    0.122941
# model_set_24    0.116627
# model_set_25    0.064850
# model_set_26    0.073707
# model_set_27    0.088068
# model_set_28    0.070094
# model_set_29    0.088676
# model_set_30    0.097252
# model_set_31    0.108722
# Name: Market, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# ['0.0(0.0)']
# model_set_0     0.110856
# model_set_1     0.061340
# model_set_2     0.110395
# model_set_3     0.094073
# model_set_4     0.103271
# model_set_5     0.093130
# model_set_6     0.076498
# model_set_7     0.113900
# model_set_8     0.094577
# model_set_9     0.077697
# model_set_10    0.065470
# model_set_11    0.071332
# model_set_12    0.075622
# model_set_13    0.067577
# model_set_14    0.088432
# model_set_15    0.081763
# model_set_16    0.091216
# model_set_17    0.061038
# model_set_18    0.099845
# model_set_19    0.088660
# model_set_20    0.103828
# model_set_21    0.100540
# model_set_22    0.108222
# model_set_23    0.122941
# model_set_24    0.116627
# model_set_25    0.064850
# model_set_26    0.073707
# model_set_27    0.088068
# model_set_28    0.070094
# model_set_29    0.088676
# model_set_30    0.097252
# model_set_31    0.108722
# Name: Market, dtype: float64
# model_set_0     0.093302
# model_set_1     0.096880
# model_set_2     0.093601
# model_set_3     0.110484
# model_set_4     0.091915
# model_set_5     0.109910
# model_set_6     0.131220
# model_set_7     0.116077
# model_set_8     0.134529
# model_set_9     0.152087
# model_set_10    0.150468
# model_set_11    0.120793
# model_set_12    0.147148
# model_set_13    0.125215
# model_set_14    0.132153
# model_set_15    0.139921
# model_set_16    0.134091
# model_set_17    0.157742
# model_set_18    0.129563
# model_set_19    0.128261
# model_set_20    0.124977
# model_set_21    0.116675
# model_set_22    0.128376
# model_set_23    0.114574
# model_set_24    0.115582
# model_set_25    0.152000
# model_set_26    0.141729
# model_set_27    0.139813
# model_set_28    0.162521
# model_set_29    0.150424
# model_set_30    0.117538
# model_set_31    0.106605
# Name: Value, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.157577, p-value : 0.692760
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -8 , pvalue : 0.0000000
#
# ['0.0(0.0)' '-0.037(-8.067***)']
# model_set_0     0.110856
# model_set_1     0.061340
# model_set_2     0.110395
# model_set_3     0.094073
# model_set_4     0.103271
# model_set_5     0.093130
# model_set_6     0.076498
# model_set_7     0.113900
# model_set_8     0.094577
# model_set_9     0.077697
# model_set_10    0.065470
# model_set_11    0.071332
# model_set_12    0.075622
# model_set_13    0.067577
# model_set_14    0.088432
# model_set_15    0.081763
# model_set_16    0.091216
# model_set_17    0.061038
# model_set_18    0.099845
# model_set_19    0.088660
# model_set_20    0.103828
# model_set_21    0.100540
# model_set_22    0.108222
# model_set_23    0.122941
# model_set_24    0.116627
# model_set_25    0.064850
# model_set_26    0.073707
# model_set_27    0.088068
# model_set_28    0.070094
# model_set_29    0.088676
# model_set_30    0.097252
# model_set_31    0.108722
# Name: Market, dtype: float64
# model_set_0     0.096881
# model_set_1     0.131335
# model_set_2     0.097003
# model_set_3     0.096582
# model_set_4     0.103610
# model_set_5     0.097719
# model_set_6     0.094211
# model_set_7     0.077517
# model_set_8     0.078170
# model_set_9     0.077662
# model_set_10    0.088047
# model_set_11    0.105906
# model_set_12    0.082922
# model_set_13    0.105406
# model_set_14    0.084561
# model_set_15    0.083737
# model_set_16    0.081019
# model_set_17    0.085915
# model_set_18    0.077944
# model_set_19    0.087309
# model_set_20    0.078396
# model_set_21    0.087089
# model_set_22    0.072551
# model_set_23    0.071863
# model_set_24    0.075844
# model_set_25    0.087362
# model_set_26    0.088423
# model_set_27    0.079089
# model_set_28    0.075539
# model_set_29    0.070675
# model_set_30    0.088907
# model_set_31    0.088505
# Name: Finance, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 6.088129, p-value : 0.016384
#
# False
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.5557192
#
# ['0.0(0.0)' '-0.037(-8.067***)' '0.002(0.593)']
# model_set_0     0.093302
# model_set_1     0.096880
# model_set_2     0.093601
# model_set_3     0.110484
# model_set_4     0.091915
# model_set_5     0.109910
# model_set_6     0.131220
# model_set_7     0.116077
# model_set_8     0.134529
# model_set_9     0.152087
# model_set_10    0.150468
# model_set_11    0.120793
# model_set_12    0.147148
# model_set_13    0.125215
# model_set_14    0.132153
# model_set_15    0.139921
# model_set_16    0.134091
# model_set_17    0.157742
# model_set_18    0.129563
# model_set_19    0.128261
# model_set_20    0.124977
# model_set_21    0.116675
# model_set_22    0.128376
# model_set_23    0.114574
# model_set_24    0.115582
# model_set_25    0.152000
# model_set_26    0.141729
# model_set_27    0.139813
# model_set_28    0.162521
# model_set_29    0.150424
# model_set_30    0.117538
# model_set_31    0.106605
# Name: Value, dtype: float64
# model_set_0     0.110856
# model_set_1     0.061340
# model_set_2     0.110395
# model_set_3     0.094073
# model_set_4     0.103271
# model_set_5     0.093130
# model_set_6     0.076498
# model_set_7     0.113900
# model_set_8     0.094577
# model_set_9     0.077697
# model_set_10    0.065470
# model_set_11    0.071332
# model_set_12    0.075622
# model_set_13    0.067577
# model_set_14    0.088432
# model_set_15    0.081763
# model_set_16    0.091216
# model_set_17    0.061038
# model_set_18    0.099845
# model_set_19    0.088660
# model_set_20    0.103828
# model_set_21    0.100540
# model_set_22    0.108222
# model_set_23    0.122941
# model_set_24    0.116627
# model_set_25    0.064850
# model_set_26    0.073707
# model_set_27    0.088068
# model_set_28    0.070094
# model_set_29    0.088676
# model_set_30    0.097252
# model_set_31    0.108722
# Name: Market, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.157577, p-value : 0.692760
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 8 , pvalue : 0.0000000
#
# ['0.0(0.0)' '-0.037(-8.067***)' '0.002(0.593)' '0.037(8.067***)']
# model_set_0     0.093302
# model_set_1     0.096880
# model_set_2     0.093601
# model_set_3     0.110484
# model_set_4     0.091915
# model_set_5     0.109910
# model_set_6     0.131220
# model_set_7     0.116077
# model_set_8     0.134529
# model_set_9     0.152087
# model_set_10    0.150468
# model_set_11    0.120793
# model_set_12    0.147148
# model_set_13    0.125215
# model_set_14    0.132153
# model_set_15    0.139921
# model_set_16    0.134091
# model_set_17    0.157742
# model_set_18    0.129563
# model_set_19    0.128261
# model_set_20    0.124977
# model_set_21    0.116675
# model_set_22    0.128376
# model_set_23    0.114574
# model_set_24    0.115582
# model_set_25    0.152000
# model_set_26    0.141729
# model_set_27    0.139813
# model_set_28    0.162521
# model_set_29    0.150424
# model_set_30    0.117538
# model_set_31    0.106605
# Name: Value, dtype: float64
# model_set_0     0.093302
# model_set_1     0.096880
# model_set_2     0.093601
# model_set_3     0.110484
# model_set_4     0.091915
# model_set_5     0.109910
# model_set_6     0.131220
# model_set_7     0.116077
# model_set_8     0.134529
# model_set_9     0.152087
# model_set_10    0.150468
# model_set_11    0.120793
# model_set_12    0.147148
# model_set_13    0.125215
# model_set_14    0.132153
# model_set_15    0.139921
# model_set_16    0.134091
# model_set_17    0.157742
# model_set_18    0.129563
# model_set_19    0.128261
# model_set_20    0.124977
# model_set_21    0.116675
# model_set_22    0.128376
# model_set_23    0.114574
# model_set_24    0.115582
# model_set_25    0.152000
# model_set_26    0.141729
# model_set_27    0.139813
# model_set_28    0.162521
# model_set_29    0.150424
# model_set_30    0.117538
# model_set_31    0.106605
# Name: Value, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# ['0.0(0.0)' '-0.037(-8.067***)' '0.002(0.593)' '0.037(8.067***)'
#  '0.0(0.0)']
# model_set_0     0.093302
# model_set_1     0.096880
# model_set_2     0.093601
# model_set_3     0.110484
# model_set_4     0.091915
# model_set_5     0.109910
# model_set_6     0.131220
# model_set_7     0.116077
# model_set_8     0.134529
# model_set_9     0.152087
# model_set_10    0.150468
# model_set_11    0.120793
# model_set_12    0.147148
# model_set_13    0.125215
# model_set_14    0.132153
# model_set_15    0.139921
# model_set_16    0.134091
# model_set_17    0.157742
# model_set_18    0.129563
# model_set_19    0.128261
# model_set_20    0.124977
# model_set_21    0.116675
# model_set_22    0.128376
# model_set_23    0.114574
# model_set_24    0.115582
# model_set_25    0.152000
# model_set_26    0.141729
# model_set_27    0.139813
# model_set_28    0.162521
# model_set_29    0.150424
# model_set_30    0.117538
# model_set_31    0.106605
# Name: Value, dtype: float64
# model_set_0     0.096881
# model_set_1     0.131335
# model_set_2     0.097003
# model_set_3     0.096582
# model_set_4     0.103610
# model_set_5     0.097719
# model_set_6     0.094211
# model_set_7     0.077517
# model_set_8     0.078170
# model_set_9     0.077662
# model_set_10    0.088047
# model_set_11    0.105906
# model_set_12    0.082922
# model_set_13    0.105406
# model_set_14    0.084561
# model_set_15    0.083737
# model_set_16    0.081019
# model_set_17    0.085915
# model_set_18    0.077944
# model_set_19    0.087309
# model_set_20    0.078396
# model_set_21    0.087089
# model_set_22    0.072551
# model_set_23    0.071863
# model_set_24    0.075844
# model_set_25    0.087362
# model_set_26    0.088423
# model_set_27    0.079089
# model_set_28    0.075539
# model_set_29    0.070675
# model_set_30    0.088907
# model_set_31    0.088505
# Name: Finance, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 6.957067, p-value : 0.010540
#
# False
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 9 , pvalue : 0.0000000
#
# ['0.0(0.0)' '-0.037(-8.067***)' '0.002(0.593)' '0.037(8.067***)'
#  '0.0(0.0)' '0.04(9.692***)']
# model_set_0     0.096881
# model_set_1     0.131335
# model_set_2     0.097003
# model_set_3     0.096582
# model_set_4     0.103610
# model_set_5     0.097719
# model_set_6     0.094211
# model_set_7     0.077517
# model_set_8     0.078170
# model_set_9     0.077662
# model_set_10    0.088047
# model_set_11    0.105906
# model_set_12    0.082922
# model_set_13    0.105406
# model_set_14    0.084561
# model_set_15    0.083737
# model_set_16    0.081019
# model_set_17    0.085915
# model_set_18    0.077944
# model_set_19    0.087309
# model_set_20    0.078396
# model_set_21    0.087089
# model_set_22    0.072551
# model_set_23    0.071863
# model_set_24    0.075844
# model_set_25    0.087362
# model_set_26    0.088423
# model_set_27    0.079089
# model_set_28    0.075539
# model_set_29    0.070675
# model_set_30    0.088907
# model_set_31    0.088505
# Name: Finance, dtype: float64
# model_set_0     0.110856
# model_set_1     0.061340
# model_set_2     0.110395
# model_set_3     0.094073
# model_set_4     0.103271
# model_set_5     0.093130
# model_set_6     0.076498
# model_set_7     0.113900
# model_set_8     0.094577
# model_set_9     0.077697
# model_set_10    0.065470
# model_set_11    0.071332
# model_set_12    0.075622
# model_set_13    0.067577
# model_set_14    0.088432
# model_set_15    0.081763
# model_set_16    0.091216
# model_set_17    0.061038
# model_set_18    0.099845
# model_set_19    0.088660
# model_set_20    0.103828
# model_set_21    0.100540
# model_set_22    0.108222
# model_set_23    0.122941
# model_set_24    0.116627
# model_set_25    0.064850
# model_set_26    0.073707
# model_set_27    0.088068
# model_set_28    0.070094
# model_set_29    0.088676
# model_set_30    0.097252
# model_set_31    0.108722
# Name: Market, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 6.088129, p-value : 0.016384
#
# False
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.5557192
#
# ['0.0(0.0)' '-0.037(-8.067***)' '0.002(0.593)' '0.037(8.067***)'
#  '0.0(0.0)' '0.04(9.692***)' '-0.002(-0.593)']
# model_set_0     0.096881
# model_set_1     0.131335
# model_set_2     0.097003
# model_set_3     0.096582
# model_set_4     0.103610
# model_set_5     0.097719
# model_set_6     0.094211
# model_set_7     0.077517
# model_set_8     0.078170
# model_set_9     0.077662
# model_set_10    0.088047
# model_set_11    0.105906
# model_set_12    0.082922
# model_set_13    0.105406
# model_set_14    0.084561
# model_set_15    0.083737
# model_set_16    0.081019
# model_set_17    0.085915
# model_set_18    0.077944
# model_set_19    0.087309
# model_set_20    0.078396
# model_set_21    0.087089
# model_set_22    0.072551
# model_set_23    0.071863
# model_set_24    0.075844
# model_set_25    0.087362
# model_set_26    0.088423
# model_set_27    0.079089
# model_set_28    0.075539
# model_set_29    0.070675
# model_set_30    0.088907
# model_set_31    0.088505
# Name: Finance, dtype: float64
# model_set_0     0.093302
# model_set_1     0.096880
# model_set_2     0.093601
# model_set_3     0.110484
# model_set_4     0.091915
# model_set_5     0.109910
# model_set_6     0.131220
# model_set_7     0.116077
# model_set_8     0.134529
# model_set_9     0.152087
# model_set_10    0.150468
# model_set_11    0.120793
# model_set_12    0.147148
# model_set_13    0.125215
# model_set_14    0.132153
# model_set_15    0.139921
# model_set_16    0.134091
# model_set_17    0.157742
# model_set_18    0.129563
# model_set_19    0.128261
# model_set_20    0.124977
# model_set_21    0.116675
# model_set_22    0.128376
# model_set_23    0.114574
# model_set_24    0.115582
# model_set_25    0.152000
# model_set_26    0.141729
# model_set_27    0.139813
# model_set_28    0.162521
# model_set_29    0.150424
# model_set_30    0.117538
# model_set_31    0.106605
# Name: Value, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 6.957067, p-value : 0.010540
#
# False
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -9 , pvalue : 0.0000000
#
# ['0.0(0.0)' '-0.037(-8.067***)' '0.002(0.593)' '0.037(8.067***)'
#  '0.0(0.0)' '0.04(9.692***)' '-0.002(-0.593)' '-0.04(-9.692***)']
# model_set_0     0.096881
# model_set_1     0.131335
# model_set_2     0.097003
# model_set_3     0.096582
# model_set_4     0.103610
# model_set_5     0.097719
# model_set_6     0.094211
# model_set_7     0.077517
# model_set_8     0.078170
# model_set_9     0.077662
# model_set_10    0.088047
# model_set_11    0.105906
# model_set_12    0.082922
# model_set_13    0.105406
# model_set_14    0.084561
# model_set_15    0.083737
# model_set_16    0.081019
# model_set_17    0.085915
# model_set_18    0.077944
# model_set_19    0.087309
# model_set_20    0.078396
# model_set_21    0.087089
# model_set_22    0.072551
# model_set_23    0.071863
# model_set_24    0.075844
# model_set_25    0.087362
# model_set_26    0.088423
# model_set_27    0.079089
# model_set_28    0.075539
# model_set_29    0.070675
# model_set_30    0.088907
# model_set_31    0.088505
# Name: Finance, dtype: float64
# model_set_0     0.096881
# model_set_1     0.131335
# model_set_2     0.097003
# model_set_3     0.096582
# model_set_4     0.103610
# model_set_5     0.097719
# model_set_6     0.094211
# model_set_7     0.077517
# model_set_8     0.078170
# model_set_9     0.077662
# model_set_10    0.088047
# model_set_11    0.105906
# model_set_12    0.082922
# model_set_13    0.105406
# model_set_14    0.084561
# model_set_15    0.083737
# model_set_16    0.081019
# model_set_17    0.085915
# model_set_18    0.077944
# model_set_19    0.087309
# model_set_20    0.078396
# model_set_21    0.087089
# model_set_22    0.072551
# model_set_23    0.071863
# model_set_24    0.075844
# model_set_25    0.087362
# model_set_26    0.088423
# model_set_27    0.079089
# model_set_28    0.075539
# model_set_29    0.070675
# model_set_30    0.088907
# model_set_31    0.088505
# Name: Finance, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# ['0.0(0.0)' '-0.037(-8.067***)' '0.002(0.593)' '0.037(8.067***)'
#  '0.0(0.0)' '0.04(9.692***)' '-0.002(-0.593)' '-0.04(-9.692***)'
#  '0.0(0.0)']
# model_set_0     0.123197
# model_set_1     0.122509
# model_set_2     0.098607
# model_set_3     0.091723
# model_set_4     0.116210
# model_set_5     0.106556
# model_set_6     0.087489
# model_set_7     0.079762
# model_set_8     0.110562
# model_set_9     0.125079
# model_set_10    0.102651
# model_set_11    0.097424
# model_set_12    0.098798
# model_set_13    0.111254
# model_set_14    0.106860
# model_set_15    0.124080
# model_set_16    0.110425
# model_set_17    0.103884
# model_set_18    0.108727
# model_set_19    0.086646
# model_set_20    0.101579
# model_set_21    0.099889
# model_set_22    0.115573
# model_set_23    0.075042
# model_set_24    0.075652
# model_set_25    0.045251
# model_set_26    0.064476
# model_set_27    0.090445
# model_set_28    0.068950
# model_set_29    0.059275
# model_set_30    0.092679
# model_set_31    0.100087
# Name: Market, dtype: float64
# model_set_0     0.123197
# model_set_1     0.122509
# model_set_2     0.098607
# model_set_3     0.091723
# model_set_4     0.116210
# model_set_5     0.106556
# model_set_6     0.087489
# model_set_7     0.079762
# model_set_8     0.110562
# model_set_9     0.125079
# model_set_10    0.102651
# model_set_11    0.097424
# model_set_12    0.098798
# model_set_13    0.111254
# model_set_14    0.106860
# model_set_15    0.124080
# model_set_16    0.110425
# model_set_17    0.103884
# model_set_18    0.108727
# model_set_19    0.086646
# model_set_20    0.101579
# model_set_21    0.099889
# model_set_22    0.115573
# model_set_23    0.075042
# model_set_24    0.075652
# model_set_25    0.045251
# model_set_26    0.064476
# model_set_27    0.090445
# model_set_28    0.068950
# model_set_29    0.059275
# model_set_30    0.092679
# model_set_31    0.100087
# Name: Market, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# ['0.0(0.0)']
# model_set_0     0.123197
# model_set_1     0.122509
# model_set_2     0.098607
# model_set_3     0.091723
# model_set_4     0.116210
# model_set_5     0.106556
# model_set_6     0.087489
# model_set_7     0.079762
# model_set_8     0.110562
# model_set_9     0.125079
# model_set_10    0.102651
# model_set_11    0.097424
# model_set_12    0.098798
# model_set_13    0.111254
# model_set_14    0.106860
# model_set_15    0.124080
# model_set_16    0.110425
# model_set_17    0.103884
# model_set_18    0.108727
# model_set_19    0.086646
# model_set_20    0.101579
# model_set_21    0.099889
# model_set_22    0.115573
# model_set_23    0.075042
# model_set_24    0.075652
# model_set_25    0.045251
# model_set_26    0.064476
# model_set_27    0.090445
# model_set_28    0.068950
# model_set_29    0.059275
# model_set_30    0.092679
# model_set_31    0.100087
# Name: Market, dtype: float64
# model_set_0     0.097807
# model_set_1     0.109414
# model_set_2     0.113670
# model_set_3     0.078070
# model_set_4     0.095122
# model_set_5     0.090222
# model_set_6     0.093947
# model_set_7     0.141900
# model_set_8     0.143741
# model_set_9     0.143262
# model_set_10    0.150340
# model_set_11    0.148084
# model_set_12    0.140343
# model_set_13    0.144294
# model_set_14    0.131324
# model_set_15    0.122563
# model_set_16    0.120577
# model_set_17    0.142096
# model_set_18    0.132769
# model_set_19    0.137481
# model_set_20    0.123022
# model_set_21    0.119404
# model_set_22    0.105886
# model_set_23    0.108362
# model_set_24    0.105212
# model_set_25    0.130432
# model_set_26    0.142184
# model_set_27    0.126411
# model_set_28    0.126701
# model_set_29    0.133323
# model_set_30    0.126208
# model_set_31    0.104943
# Name: Value, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.056089, p-value : 0.813568
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -5 , pvalue : 0.0000015
#
# ['0.0(0.0)' '-0.026(-5.317***)']
# model_set_0     0.123197
# model_set_1     0.122509
# model_set_2     0.098607
# model_set_3     0.091723
# model_set_4     0.116210
# model_set_5     0.106556
# model_set_6     0.087489
# model_set_7     0.079762
# model_set_8     0.110562
# model_set_9     0.125079
# model_set_10    0.102651
# model_set_11    0.097424
# model_set_12    0.098798
# model_set_13    0.111254
# model_set_14    0.106860
# model_set_15    0.124080
# model_set_16    0.110425
# model_set_17    0.103884
# model_set_18    0.108727
# model_set_19    0.086646
# model_set_20    0.101579
# model_set_21    0.099889
# model_set_22    0.115573
# model_set_23    0.075042
# model_set_24    0.075652
# model_set_25    0.045251
# model_set_26    0.064476
# model_set_27    0.090445
# model_set_28    0.068950
# model_set_29    0.059275
# model_set_30    0.092679
# model_set_31    0.100087
# Name: Market, dtype: float64
# model_set_0     0.084247
# model_set_1     0.076058
# model_set_2     0.090792
# model_set_3     0.122655
# model_set_4     0.091501
# model_set_5     0.102416
# model_set_6     0.113923
# model_set_7     0.083754
# model_set_8     0.059273
# model_set_9     0.048744
# model_set_10    0.060256
# model_set_11    0.065869
# model_set_12    0.070644
# model_set_13    0.058339
# model_set_14    0.071362
# model_set_15    0.065018
# model_set_16    0.076749
# model_set_17    0.065515
# model_set_18    0.068878
# model_set_19    0.081905
# model_set_20    0.081549
# model_set_21    0.085530
# model_set_22    0.083906
# model_set_23    0.112446
# model_set_24    0.114352
# model_set_25    0.118238
# model_set_26    0.095005
# model_set_27    0.087358
# model_set_28    0.103262
# model_set_29    0.105551
# model_set_30    0.085835
# model_set_31    0.096228
# Name: Finance, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.021478, p-value : 0.883959
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0197072
#
# ['0.0(0.0)' '-0.026(-5.317***)' '0.012(2.394**)']
# model_set_0     0.097807
# model_set_1     0.109414
# model_set_2     0.113670
# model_set_3     0.078070
# model_set_4     0.095122
# model_set_5     0.090222
# model_set_6     0.093947
# model_set_7     0.141900
# model_set_8     0.143741
# model_set_9     0.143262
# model_set_10    0.150340
# model_set_11    0.148084
# model_set_12    0.140343
# model_set_13    0.144294
# model_set_14    0.131324
# model_set_15    0.122563
# model_set_16    0.120577
# model_set_17    0.142096
# model_set_18    0.132769
# model_set_19    0.137481
# model_set_20    0.123022
# model_set_21    0.119404
# model_set_22    0.105886
# model_set_23    0.108362
# model_set_24    0.105212
# model_set_25    0.130432
# model_set_26    0.142184
# model_set_27    0.126411
# model_set_28    0.126701
# model_set_29    0.133323
# model_set_30    0.126208
# model_set_31    0.104943
# Name: Value, dtype: float64
# model_set_0     0.123197
# model_set_1     0.122509
# model_set_2     0.098607
# model_set_3     0.091723
# model_set_4     0.116210
# model_set_5     0.106556
# model_set_6     0.087489
# model_set_7     0.079762
# model_set_8     0.110562
# model_set_9     0.125079
# model_set_10    0.102651
# model_set_11    0.097424
# model_set_12    0.098798
# model_set_13    0.111254
# model_set_14    0.106860
# model_set_15    0.124080
# model_set_16    0.110425
# model_set_17    0.103884
# model_set_18    0.108727
# model_set_19    0.086646
# model_set_20    0.101579
# model_set_21    0.099889
# model_set_22    0.115573
# model_set_23    0.075042
# model_set_24    0.075652
# model_set_25    0.045251
# model_set_26    0.064476
# model_set_27    0.090445
# model_set_28    0.068950
# model_set_29    0.059275
# model_set_30    0.092679
# model_set_31    0.100087
# Name: Market, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.056089, p-value : 0.813568
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 5 , pvalue : 0.0000015
#
# ['0.0(0.0)' '-0.026(-5.317***)' '0.012(2.394**)' '0.026(5.317***)']
# model_set_0     0.097807
# model_set_1     0.109414
# model_set_2     0.113670
# model_set_3     0.078070
# model_set_4     0.095122
# model_set_5     0.090222
# model_set_6     0.093947
# model_set_7     0.141900
# model_set_8     0.143741
# model_set_9     0.143262
# model_set_10    0.150340
# model_set_11    0.148084
# model_set_12    0.140343
# model_set_13    0.144294
# model_set_14    0.131324
# model_set_15    0.122563
# model_set_16    0.120577
# model_set_17    0.142096
# model_set_18    0.132769
# model_set_19    0.137481
# model_set_20    0.123022
# model_set_21    0.119404
# model_set_22    0.105886
# model_set_23    0.108362
# model_set_24    0.105212
# model_set_25    0.130432
# model_set_26    0.142184
# model_set_27    0.126411
# model_set_28    0.126701
# model_set_29    0.133323
# model_set_30    0.126208
# model_set_31    0.104943
# Name: Value, dtype: float64
# model_set_0     0.097807
# model_set_1     0.109414
# model_set_2     0.113670
# model_set_3     0.078070
# model_set_4     0.095122
# model_set_5     0.090222
# model_set_6     0.093947
# model_set_7     0.141900
# model_set_8     0.143741
# model_set_9     0.143262
# model_set_10    0.150340
# model_set_11    0.148084
# model_set_12    0.140343
# model_set_13    0.144294
# model_set_14    0.131324
# model_set_15    0.122563
# model_set_16    0.120577
# model_set_17    0.142096
# model_set_18    0.132769
# model_set_19    0.137481
# model_set_20    0.123022
# model_set_21    0.119404
# model_set_22    0.105886
# model_set_23    0.108362
# model_set_24    0.105212
# model_set_25    0.130432
# model_set_26    0.142184
# model_set_27    0.126411
# model_set_28    0.126701
# model_set_29    0.133323
# model_set_30    0.126208
# model_set_31    0.104943
# Name: Value, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# ['0.0(0.0)' '-0.026(-5.317***)' '0.012(2.394**)' '0.026(5.317***)'
#  '0.0(0.0)']
# model_set_0     0.097807
# model_set_1     0.109414
# model_set_2     0.113670
# model_set_3     0.078070
# model_set_4     0.095122
# model_set_5     0.090222
# model_set_6     0.093947
# model_set_7     0.141900
# model_set_8     0.143741
# model_set_9     0.143262
# model_set_10    0.150340
# model_set_11    0.148084
# model_set_12    0.140343
# model_set_13    0.144294
# model_set_14    0.131324
# model_set_15    0.122563
# model_set_16    0.120577
# model_set_17    0.142096
# model_set_18    0.132769
# model_set_19    0.137481
# model_set_20    0.123022
# model_set_21    0.119404
# model_set_22    0.105886
# model_set_23    0.108362
# model_set_24    0.105212
# model_set_25    0.130432
# model_set_26    0.142184
# model_set_27    0.126411
# model_set_28    0.126701
# model_set_29    0.133323
# model_set_30    0.126208
# model_set_31    0.104943
# Name: Value, dtype: float64
# model_set_0     0.084247
# model_set_1     0.076058
# model_set_2     0.090792
# model_set_3     0.122655
# model_set_4     0.091501
# model_set_5     0.102416
# model_set_6     0.113923
# model_set_7     0.083754
# model_set_8     0.059273
# model_set_9     0.048744
# model_set_10    0.060256
# model_set_11    0.065869
# model_set_12    0.070644
# model_set_13    0.058339
# model_set_14    0.071362
# model_set_15    0.065018
# model_set_16    0.076749
# model_set_17    0.065515
# model_set_18    0.068878
# model_set_19    0.081905
# model_set_20    0.081549
# model_set_21    0.085530
# model_set_22    0.083906
# model_set_23    0.112446
# model_set_24    0.114352
# model_set_25    0.118238
# model_set_26    0.095005
# model_set_27    0.087358
# model_set_28    0.103262
# model_set_29    0.105551
# model_set_30    0.085835
# model_set_31    0.096228
# Name: Finance, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.009133, p-value : 0.924172
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 7 , pvalue : 0.0000000
#
# ['0.0(0.0)' '-0.026(-5.317***)' '0.012(2.394**)' '0.026(5.317***)'
#  '0.0(0.0)' '0.038(7.795***)']
# model_set_0     0.084247
# model_set_1     0.076058
# model_set_2     0.090792
# model_set_3     0.122655
# model_set_4     0.091501
# model_set_5     0.102416
# model_set_6     0.113923
# model_set_7     0.083754
# model_set_8     0.059273
# model_set_9     0.048744
# model_set_10    0.060256
# model_set_11    0.065869
# model_set_12    0.070644
# model_set_13    0.058339
# model_set_14    0.071362
# model_set_15    0.065018
# model_set_16    0.076749
# model_set_17    0.065515
# model_set_18    0.068878
# model_set_19    0.081905
# model_set_20    0.081549
# model_set_21    0.085530
# model_set_22    0.083906
# model_set_23    0.112446
# model_set_24    0.114352
# model_set_25    0.118238
# model_set_26    0.095005
# model_set_27    0.087358
# model_set_28    0.103262
# model_set_29    0.105551
# model_set_30    0.085835
# model_set_31    0.096228
# Name: Finance, dtype: float64
# model_set_0     0.123197
# model_set_1     0.122509
# model_set_2     0.098607
# model_set_3     0.091723
# model_set_4     0.116210
# model_set_5     0.106556
# model_set_6     0.087489
# model_set_7     0.079762
# model_set_8     0.110562
# model_set_9     0.125079
# model_set_10    0.102651
# model_set_11    0.097424
# model_set_12    0.098798
# model_set_13    0.111254
# model_set_14    0.106860
# model_set_15    0.124080
# model_set_16    0.110425
# model_set_17    0.103884
# model_set_18    0.108727
# model_set_19    0.086646
# model_set_20    0.101579
# model_set_21    0.099889
# model_set_22    0.115573
# model_set_23    0.075042
# model_set_24    0.075652
# model_set_25    0.045251
# model_set_26    0.064476
# model_set_27    0.090445
# model_set_28    0.068950
# model_set_29    0.059275
# model_set_30    0.092679
# model_set_31    0.100087
# Name: Market, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.021478, p-value : 0.883959
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0197072
#
# ['0.0(0.0)' '-0.026(-5.317***)' '0.012(2.394**)' '0.026(5.317***)'
#  '0.0(0.0)' '0.038(7.795***)' '-0.012(-2.394**)']
# model_set_0     0.084247
# model_set_1     0.076058
# model_set_2     0.090792
# model_set_3     0.122655
# model_set_4     0.091501
# model_set_5     0.102416
# model_set_6     0.113923
# model_set_7     0.083754
# model_set_8     0.059273
# model_set_9     0.048744
# model_set_10    0.060256
# model_set_11    0.065869
# model_set_12    0.070644
# model_set_13    0.058339
# model_set_14    0.071362
# model_set_15    0.065018
# model_set_16    0.076749
# model_set_17    0.065515
# model_set_18    0.068878
# model_set_19    0.081905
# model_set_20    0.081549
# model_set_21    0.085530
# model_set_22    0.083906
# model_set_23    0.112446
# model_set_24    0.114352
# model_set_25    0.118238
# model_set_26    0.095005
# model_set_27    0.087358
# model_set_28    0.103262
# model_set_29    0.105551
# model_set_30    0.085835
# model_set_31    0.096228
# Name: Finance, dtype: float64
# model_set_0     0.097807
# model_set_1     0.109414
# model_set_2     0.113670
# model_set_3     0.078070
# model_set_4     0.095122
# model_set_5     0.090222
# model_set_6     0.093947
# model_set_7     0.141900
# model_set_8     0.143741
# model_set_9     0.143262
# model_set_10    0.150340
# model_set_11    0.148084
# model_set_12    0.140343
# model_set_13    0.144294
# model_set_14    0.131324
# model_set_15    0.122563
# model_set_16    0.120577
# model_set_17    0.142096
# model_set_18    0.132769
# model_set_19    0.137481
# model_set_20    0.123022
# model_set_21    0.119404
# model_set_22    0.105886
# model_set_23    0.108362
# model_set_24    0.105212
# model_set_25    0.130432
# model_set_26    0.142184
# model_set_27    0.126411
# model_set_28    0.126701
# model_set_29    0.133323
# model_set_30    0.126208
# model_set_31    0.104943
# Name: Value, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.009133, p-value : 0.924172
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -7 , pvalue : 0.0000000
#
# ['0.0(0.0)' '-0.026(-5.317***)' '0.012(2.394**)' '0.026(5.317***)'
#  '0.0(0.0)' '0.038(7.795***)' '-0.012(-2.394**)' '-0.038(-7.795***)']
# model_set_0     0.084247
# model_set_1     0.076058
# model_set_2     0.090792
# model_set_3     0.122655
# model_set_4     0.091501
# model_set_5     0.102416
# model_set_6     0.113923
# model_set_7     0.083754
# model_set_8     0.059273
# model_set_9     0.048744
# model_set_10    0.060256
# model_set_11    0.065869
# model_set_12    0.070644
# model_set_13    0.058339
# model_set_14    0.071362
# model_set_15    0.065018
# model_set_16    0.076749
# model_set_17    0.065515
# model_set_18    0.068878
# model_set_19    0.081905
# model_set_20    0.081549
# model_set_21    0.085530
# model_set_22    0.083906
# model_set_23    0.112446
# model_set_24    0.114352
# model_set_25    0.118238
# model_set_26    0.095005
# model_set_27    0.087358
# model_set_28    0.103262
# model_set_29    0.105551
# model_set_30    0.085835
# model_set_31    0.096228
# Name: Finance, dtype: float64
# model_set_0     0.084247
# model_set_1     0.076058
# model_set_2     0.090792
# model_set_3     0.122655
# model_set_4     0.091501
# model_set_5     0.102416
# model_set_6     0.113923
# model_set_7     0.083754
# model_set_8     0.059273
# model_set_9     0.048744
# model_set_10    0.060256
# model_set_11    0.065869
# model_set_12    0.070644
# model_set_13    0.058339
# model_set_14    0.071362
# model_set_15    0.065018
# model_set_16    0.076749
# model_set_17    0.065515
# model_set_18    0.068878
# model_set_19    0.081905
# model_set_20    0.081549
# model_set_21    0.085530
# model_set_22    0.083906
# model_set_23    0.112446
# model_set_24    0.114352
# model_set_25    0.118238
# model_set_26    0.095005
# model_set_27    0.087358
# model_set_28    0.103262
# model_set_29    0.105551
# model_set_30    0.085835
# model_set_31    0.096228
# Name: Finance, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# ['0.0(0.0)' '-0.026(-5.317***)' '0.012(2.394**)' '0.026(5.317***)'
#  '0.0(0.0)' '0.038(7.795***)' '-0.012(-2.394**)' '-0.038(-7.795***)'
#  '0.0(0.0)']
# model_set_0     0.108050
# model_set_1     0.131171
# model_set_2     0.097218
# model_set_3     0.134291
# model_set_4     0.086738
# model_set_5     0.088827
# model_set_6     0.076188
# model_set_7     0.093922
# model_set_8     0.107097
# model_set_9     0.101051
# model_set_10    0.101142
# model_set_11    0.089819
# model_set_12    0.083853
# model_set_13    0.107258
# model_set_14    0.095161
# model_set_15    0.107134
# model_set_16    0.100266
# model_set_17    0.116414
# model_set_18    0.106788
# model_set_19    0.108878
# model_set_20    0.092893
# model_set_21    0.100527
# model_set_22    0.093831
# model_set_23    0.078207
# model_set_24    0.064893
# model_set_25    0.097433
# model_set_26    0.057965
# model_set_27    0.099115
# model_set_28    0.099753
# model_set_29    0.059932
# model_set_30    0.090954
# model_set_31    0.093501
# Name: Market, dtype: float64
# model_set_0     0.108050
# model_set_1     0.131171
# model_set_2     0.097218
# model_set_3     0.134291
# model_set_4     0.086738
# model_set_5     0.088827
# model_set_6     0.076188
# model_set_7     0.093922
# model_set_8     0.107097
# model_set_9     0.101051
# model_set_10    0.101142
# model_set_11    0.089819
# model_set_12    0.083853
# model_set_13    0.107258
# model_set_14    0.095161
# model_set_15    0.107134
# model_set_16    0.100266
# model_set_17    0.116414
# model_set_18    0.106788
# model_set_19    0.108878
# model_set_20    0.092893
# model_set_21    0.100527
# model_set_22    0.093831
# model_set_23    0.078207
# model_set_24    0.064893
# model_set_25    0.097433
# model_set_26    0.057965
# model_set_27    0.099115
# model_set_28    0.099753
# model_set_29    0.059932
# model_set_30    0.090954
# model_set_31    0.093501
# Name: Market, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# ['0.0(0.0)']
# model_set_0     0.108050
# model_set_1     0.131171
# model_set_2     0.097218
# model_set_3     0.134291
# model_set_4     0.086738
# model_set_5     0.088827
# model_set_6     0.076188
# model_set_7     0.093922
# model_set_8     0.107097
# model_set_9     0.101051
# model_set_10    0.101142
# model_set_11    0.089819
# model_set_12    0.083853
# model_set_13    0.107258
# model_set_14    0.095161
# model_set_15    0.107134
# model_set_16    0.100266
# model_set_17    0.116414
# model_set_18    0.106788
# model_set_19    0.108878
# model_set_20    0.092893
# model_set_21    0.100527
# model_set_22    0.093831
# model_set_23    0.078207
# model_set_24    0.064893
# model_set_25    0.097433
# model_set_26    0.057965
# model_set_27    0.099115
# model_set_28    0.099753
# model_set_29    0.059932
# model_set_30    0.090954
# model_set_31    0.093501
# Name: Market, dtype: float64
# model_set_0     0.091927
# model_set_1     0.106133
# model_set_2     0.085785
# model_set_3     0.072556
# model_set_4     0.090318
# model_set_5     0.100213
# model_set_6     0.131058
# model_set_7     0.108462
# model_set_8     0.143080
# model_set_9     0.132962
# model_set_10    0.122158
# model_set_11    0.130698
# model_set_12    0.131668
# model_set_13    0.110202
# model_set_14    0.117280
# model_set_15    0.088465
# model_set_16    0.123365
# model_set_17    0.091442
# model_set_18    0.083830
# model_set_19    0.131252
# model_set_20    0.135798
# model_set_21    0.133065
# model_set_22    0.113163
# model_set_23    0.131337
# model_set_24    0.151686
# model_set_25    0.135847
# model_set_26    0.166465
# model_set_27    0.137781
# model_set_28    0.127948
# model_set_29    0.143175
# model_set_30    0.119185
# model_set_31    0.128492
# Name: Value, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 3.087236, p-value : 0.083846
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -4 , pvalue : 0.0000131
#
# ['0.0(0.0)' '-0.023(-4.737***)']
# model_set_0     0.108050
# model_set_1     0.131171
# model_set_2     0.097218
# model_set_3     0.134291
# model_set_4     0.086738
# model_set_5     0.088827
# model_set_6     0.076188
# model_set_7     0.093922
# model_set_8     0.107097
# model_set_9     0.101051
# model_set_10    0.101142
# model_set_11    0.089819
# model_set_12    0.083853
# model_set_13    0.107258
# model_set_14    0.095161
# model_set_15    0.107134
# model_set_16    0.100266
# model_set_17    0.116414
# model_set_18    0.106788
# model_set_19    0.108878
# model_set_20    0.092893
# model_set_21    0.100527
# model_set_22    0.093831
# model_set_23    0.078207
# model_set_24    0.064893
# model_set_25    0.097433
# model_set_26    0.057965
# model_set_27    0.099115
# model_set_28    0.099753
# model_set_29    0.059932
# model_set_30    0.090954
# model_set_31    0.093501
# Name: Market, dtype: float64
# model_set_0     0.100018
# model_set_1     0.072022
# model_set_2     0.112747
# model_set_3     0.094864
# model_set_4     0.117208
# model_set_5     0.108219
# model_set_6     0.094566
# model_set_7     0.098212
# model_set_8     0.062367
# model_set_9     0.074490
# model_set_10    0.082524
# model_set_11    0.084612
# model_set_12    0.088359
# model_set_13    0.086905
# model_set_14    0.090669
# model_set_15    0.103301
# model_set_16    0.082277
# model_set_17    0.094108
# model_set_18    0.107037
# model_set_19    0.069902
# model_set_20    0.078482
# model_set_21    0.074806
# model_set_22    0.094755
# model_set_23    0.092842
# model_set_24    0.087566
# model_set_25    0.075040
# model_set_26    0.081677
# model_set_27    0.072328
# model_set_28    0.079225
# model_set_29    0.097670
# model_set_30    0.092396
# model_set_31    0.083505
# Name: Finance, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.297579, p-value : 0.587361
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 1 , pvalue : 0.0560270
#
# ['0.0(0.0)' '-0.023(-4.737***)' '0.007(1.947*)']
# model_set_0     0.091927
# model_set_1     0.106133
# model_set_2     0.085785
# model_set_3     0.072556
# model_set_4     0.090318
# model_set_5     0.100213
# model_set_6     0.131058
# model_set_7     0.108462
# model_set_8     0.143080
# model_set_9     0.132962
# model_set_10    0.122158
# model_set_11    0.130698
# model_set_12    0.131668
# model_set_13    0.110202
# model_set_14    0.117280
# model_set_15    0.088465
# model_set_16    0.123365
# model_set_17    0.091442
# model_set_18    0.083830
# model_set_19    0.131252
# model_set_20    0.135798
# model_set_21    0.133065
# model_set_22    0.113163
# model_set_23    0.131337
# model_set_24    0.151686
# model_set_25    0.135847
# model_set_26    0.166465
# model_set_27    0.137781
# model_set_28    0.127948
# model_set_29    0.143175
# model_set_30    0.119185
# model_set_31    0.128492
# Name: Value, dtype: float64
# model_set_0     0.108050
# model_set_1     0.131171
# model_set_2     0.097218
# model_set_3     0.134291
# model_set_4     0.086738
# model_set_5     0.088827
# model_set_6     0.076188
# model_set_7     0.093922
# model_set_8     0.107097
# model_set_9     0.101051
# model_set_10    0.101142
# model_set_11    0.089819
# model_set_12    0.083853
# model_set_13    0.107258
# model_set_14    0.095161
# model_set_15    0.107134
# model_set_16    0.100266
# model_set_17    0.116414
# model_set_18    0.106788
# model_set_19    0.108878
# model_set_20    0.092893
# model_set_21    0.100527
# model_set_22    0.093831
# model_set_23    0.078207
# model_set_24    0.064893
# model_set_25    0.097433
# model_set_26    0.057965
# model_set_27    0.099115
# model_set_28    0.099753
# model_set_29    0.059932
# model_set_30    0.090954
# model_set_31    0.093501
# Name: Market, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 3.087236, p-value : 0.083846
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 4 , pvalue : 0.0000131
#
# ['0.0(0.0)' '-0.023(-4.737***)' '0.007(1.947*)' '0.023(4.737***)']
# model_set_0     0.091927
# model_set_1     0.106133
# model_set_2     0.085785
# model_set_3     0.072556
# model_set_4     0.090318
# model_set_5     0.100213
# model_set_6     0.131058
# model_set_7     0.108462
# model_set_8     0.143080
# model_set_9     0.132962
# model_set_10    0.122158
# model_set_11    0.130698
# model_set_12    0.131668
# model_set_13    0.110202
# model_set_14    0.117280
# model_set_15    0.088465
# model_set_16    0.123365
# model_set_17    0.091442
# model_set_18    0.083830
# model_set_19    0.131252
# model_set_20    0.135798
# model_set_21    0.133065
# model_set_22    0.113163
# model_set_23    0.131337
# model_set_24    0.151686
# model_set_25    0.135847
# model_set_26    0.166465
# model_set_27    0.137781
# model_set_28    0.127948
# model_set_29    0.143175
# model_set_30    0.119185
# model_set_31    0.128492
# Name: Value, dtype: float64
# model_set_0     0.091927
# model_set_1     0.106133
# model_set_2     0.085785
# model_set_3     0.072556
# model_set_4     0.090318
# model_set_5     0.100213
# model_set_6     0.131058
# model_set_7     0.108462
# model_set_8     0.143080
# model_set_9     0.132962
# model_set_10    0.122158
# model_set_11    0.130698
# model_set_12    0.131668
# model_set_13    0.110202
# model_set_14    0.117280
# model_set_15    0.088465
# model_set_16    0.123365
# model_set_17    0.091442
# model_set_18    0.083830
# model_set_19    0.131252
# model_set_20    0.135798
# model_set_21    0.133065
# model_set_22    0.113163
# model_set_23    0.131337
# model_set_24    0.151686
# model_set_25    0.135847
# model_set_26    0.166465
# model_set_27    0.137781
# model_set_28    0.127948
# model_set_29    0.143175
# model_set_30    0.119185
# model_set_31    0.128492
# Name: Value, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# ['0.0(0.0)' '-0.023(-4.737***)' '0.007(1.947*)' '0.023(4.737***)'
#  '0.0(0.0)']
# model_set_0     0.091927
# model_set_1     0.106133
# model_set_2     0.085785
# model_set_3     0.072556
# model_set_4     0.090318
# model_set_5     0.100213
# model_set_6     0.131058
# model_set_7     0.108462
# model_set_8     0.143080
# model_set_9     0.132962
# model_set_10    0.122158
# model_set_11    0.130698
# model_set_12    0.131668
# model_set_13    0.110202
# model_set_14    0.117280
# model_set_15    0.088465
# model_set_16    0.123365
# model_set_17    0.091442
# model_set_18    0.083830
# model_set_19    0.131252
# model_set_20    0.135798
# model_set_21    0.133065
# model_set_22    0.113163
# model_set_23    0.131337
# model_set_24    0.151686
# model_set_25    0.135847
# model_set_26    0.166465
# model_set_27    0.137781
# model_set_28    0.127948
# model_set_29    0.143175
# model_set_30    0.119185
# model_set_31    0.128492
# Name: Value, dtype: float64
# model_set_0     0.100018
# model_set_1     0.072022
# model_set_2     0.112747
# model_set_3     0.094864
# model_set_4     0.117208
# model_set_5     0.108219
# model_set_6     0.094566
# model_set_7     0.098212
# model_set_8     0.062367
# model_set_9     0.074490
# model_set_10    0.082524
# model_set_11    0.084612
# model_set_12    0.088359
# model_set_13    0.086905
# model_set_14    0.090669
# model_set_15    0.103301
# model_set_16    0.082277
# model_set_17    0.094108
# model_set_18    0.107037
# model_set_19    0.069902
# model_set_20    0.078482
# model_set_21    0.074806
# model_set_22    0.094755
# model_set_23    0.092842
# model_set_24    0.087566
# model_set_25    0.075040
# model_set_26    0.081677
# model_set_27    0.072328
# model_set_28    0.079225
# model_set_29    0.097670
# model_set_30    0.092396
# model_set_31    0.083505
# Name: Finance, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 6.166020, p-value : 0.015742
#
# False
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 6 , pvalue : 0.0000000
#
# ['0.0(0.0)' '-0.023(-4.737***)' '0.007(1.947*)' '0.023(4.737***)'
#  '0.0(0.0)' '0.031(6.74***)']
# model_set_0     0.100018
# model_set_1     0.072022
# model_set_2     0.112747
# model_set_3     0.094864
# model_set_4     0.117208
# model_set_5     0.108219
# model_set_6     0.094566
# model_set_7     0.098212
# model_set_8     0.062367
# model_set_9     0.074490
# model_set_10    0.082524
# model_set_11    0.084612
# model_set_12    0.088359
# model_set_13    0.086905
# model_set_14    0.090669
# model_set_15    0.103301
# model_set_16    0.082277
# model_set_17    0.094108
# model_set_18    0.107037
# model_set_19    0.069902
# model_set_20    0.078482
# model_set_21    0.074806
# model_set_22    0.094755
# model_set_23    0.092842
# model_set_24    0.087566
# model_set_25    0.075040
# model_set_26    0.081677
# model_set_27    0.072328
# model_set_28    0.079225
# model_set_29    0.097670
# model_set_30    0.092396
# model_set_31    0.083505
# Name: Finance, dtype: float64
# model_set_0     0.108050
# model_set_1     0.131171
# model_set_2     0.097218
# model_set_3     0.134291
# model_set_4     0.086738
# model_set_5     0.088827
# model_set_6     0.076188
# model_set_7     0.093922
# model_set_8     0.107097
# model_set_9     0.101051
# model_set_10    0.101142
# model_set_11    0.089819
# model_set_12    0.083853
# model_set_13    0.107258
# model_set_14    0.095161
# model_set_15    0.107134
# model_set_16    0.100266
# model_set_17    0.116414
# model_set_18    0.106788
# model_set_19    0.108878
# model_set_20    0.092893
# model_set_21    0.100527
# model_set_22    0.093831
# model_set_23    0.078207
# model_set_24    0.064893
# model_set_25    0.097433
# model_set_26    0.057965
# model_set_27    0.099115
# model_set_28    0.099753
# model_set_29    0.059932
# model_set_30    0.090954
# model_set_31    0.093501
# Name: Market, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.297579, p-value : 0.587361
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -1 , pvalue : 0.0560270
#
# ['0.0(0.0)' '-0.023(-4.737***)' '0.007(1.947*)' '0.023(4.737***)'
#  '0.0(0.0)' '0.031(6.74***)' '-0.007(-1.947*)']
# model_set_0     0.100018
# model_set_1     0.072022
# model_set_2     0.112747
# model_set_3     0.094864
# model_set_4     0.117208
# model_set_5     0.108219
# model_set_6     0.094566
# model_set_7     0.098212
# model_set_8     0.062367
# model_set_9     0.074490
# model_set_10    0.082524
# model_set_11    0.084612
# model_set_12    0.088359
# model_set_13    0.086905
# model_set_14    0.090669
# model_set_15    0.103301
# model_set_16    0.082277
# model_set_17    0.094108
# model_set_18    0.107037
# model_set_19    0.069902
# model_set_20    0.078482
# model_set_21    0.074806
# model_set_22    0.094755
# model_set_23    0.092842
# model_set_24    0.087566
# model_set_25    0.075040
# model_set_26    0.081677
# model_set_27    0.072328
# model_set_28    0.079225
# model_set_29    0.097670
# model_set_30    0.092396
# model_set_31    0.083505
# Name: Finance, dtype: float64
# model_set_0     0.091927
# model_set_1     0.106133
# model_set_2     0.085785
# model_set_3     0.072556
# model_set_4     0.090318
# ...
# model_set_5     0.124982
# model_set_6     0.135551
# model_set_7     0.156008
# model_set_8     0.169911
# model_set_9     0.163299
# model_set_10    0.173383
# model_set_11    0.143170
# model_set_12    0.133859
# model_set_13    0.118544
# model_set_14    0.146467
# model_set_15    0.137847
# model_set_16    0.092931
# model_set_17    0.088243
# model_set_18    0.106165
# model_set_19    0.110331
# model_set_20    0.135531
# model_set_21    0.130391
# model_set_22    0.086235
# model_set_23    0.056514
# model_set_24    0.061067
# model_set_25    0.081503
# model_set_26    0.077590
# model_set_27    0.061730
# model_set_28    0.059003
# model_set_29    0.072328
# model_set_30    0.081666
# model_set_31    0.066470
# Name: Market, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# ['0.0(0.0)']
# model_set_0     0.083622
# model_set_1     0.082163
# model_set_2     0.068407
# model_set_3     0.112896
# model_set_4     0.114923
# model_set_5     0.124982
# model_set_6     0.135551
# model_set_7     0.156008
# model_set_8     0.169911
# model_set_9     0.163299
# model_set_10    0.173383
# model_set_11    0.143170
# model_set_12    0.133859
# model_set_13    0.118544
# model_set_14    0.146467
# model_set_15    0.137847
# model_set_16    0.092931
# model_set_17    0.088243
# model_set_18    0.106165
# model_set_19    0.110331
# model_set_20    0.135531
# model_set_21    0.130391
# model_set_22    0.086235
# model_set_23    0.056514
# model_set_24    0.061067
# model_set_25    0.081503
# model_set_26    0.077590
# model_set_27    0.061730
# model_set_28    0.059003
# model_set_29    0.072328
# model_set_30    0.081666
# model_set_31    0.066470
# Name: Market, dtype: float64
# model_set_0     0.112607
# model_set_1     0.112339
# model_set_2     0.115426
# model_set_3     0.120315
# model_set_4     0.104367
# model_set_5     0.098727
# model_set_6     0.080495
# model_set_7     0.074591
# model_set_8     0.061073
# model_set_9     0.076426
# model_set_10    0.059165
# model_set_11    0.097370
# model_set_12    0.088392
# model_set_13    0.112237
# model_set_14    0.083723
# model_set_15    0.094120
# model_set_16    0.113030
# model_set_17    0.118901
# model_set_18    0.106113
# model_set_19    0.120198
# model_set_20    0.100427
# model_set_21    0.094945
# model_set_22    0.111529
# model_set_23    0.151710
# model_set_24    0.152343
# model_set_25    0.135852
# model_set_26    0.123042
# model_set_27    0.162876
# model_set_28    0.156844
# model_set_29    0.136906
# model_set_30    0.128768
# model_set_31    0.114943
# Name: Value, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 6.720756, p-value : 0.011871
#
# False
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.7276577
#
# ['0.0(0.0)' '-0.003(-0.35)']
# model_set_0     0.083622
# model_set_1     0.082163
# model_set_2     0.068407
# model_set_3     0.112896
# model_set_4     0.114923
# model_set_5     0.124982
# model_set_6     0.135551
# model_set_7     0.156008
# model_set_8     0.169911
# model_set_9     0.163299
# model_set_10    0.173383
# model_set_11    0.143170
# model_set_12    0.133859
# model_set_13    0.118544
# model_set_14    0.146467
# model_set_15    0.137847
# model_set_16    0.092931
# model_set_17    0.088243
# model_set_18    0.106165
# model_set_19    0.110331
# model_set_20    0.135531
# model_set_21    0.130391
# model_set_22    0.086235
# model_set_23    0.056514
# model_set_24    0.061067
# model_set_25    0.081503
# model_set_26    0.077590
# model_set_27    0.061730
# model_set_28    0.059003
# model_set_29    0.072328
# model_set_30    0.081666
# model_set_31    0.066470
# Name: Market, dtype: float64
# model_set_0     0.102828
# model_set_1     0.104123
# model_set_2     0.112125
# model_set_3     0.075091
# model_set_4     0.085533
# model_set_5     0.082219
# model_set_6     0.087966
# model_set_7     0.077051
# model_set_8     0.076762
# model_set_9     0.070206
# model_set_10    0.075589
# model_set_11    0.069595
# model_set_12    0.083312
# model_set_13    0.076914
# model_set_14    0.077358
# model_set_15    0.076024
# model_set_16    0.095529
# model_set_17    0.094642
# model_set_18    0.090792
# model_set_19    0.077103
# model_set_20    0.073031
# model_set_21    0.080998
# model_set_22    0.101677
# model_set_23    0.093832
# model_set_24    0.089943
# model_set_25    0.086983
# model_set_26    0.099526
# model_set_27    0.081545
# model_set_28    0.088115
# model_set_29    0.093075
# model_set_30    0.092174
# model_set_31    0.113940
# Name: Finance, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 43.204917, p-value : 0.000000
#
# False
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0040001
#
# ['0.0(0.0)' '-0.003(-0.35)' '0.02(3.065***)']
# model_set_0     0.112607
# model_set_1     0.112339
# model_set_2     0.115426
# model_set_3     0.120315
# model_set_4     0.104367
# model_set_5     0.098727
# model_set_6     0.080495
# model_set_7     0.074591
# model_set_8     0.061073
# model_set_9     0.076426
# model_set_10    0.059165
# model_set_11    0.097370
# model_set_12    0.088392
# model_set_13    0.112237
# model_set_14    0.083723
# model_set_15    0.094120
# model_set_16    0.113030
# model_set_17    0.118901
# model_set_18    0.106113
# model_set_19    0.120198
# model_set_20    0.100427
# model_set_21    0.094945
# model_set_22    0.111529
# model_set_23    0.151710
# model_set_24    0.152343
# model_set_25    0.135852
# model_set_26    0.123042
# model_set_27    0.162876
# model_set_28    0.156844
# model_set_29    0.136906
# model_set_30    0.128768
# model_set_31    0.114943
# Name: Value, dtype: float64
# model_set_0     0.083622
# model_set_1     0.082163
# model_set_2     0.068407
# model_set_3     0.112896
# model_set_4     0.114923
# model_set_5     0.124982
# model_set_6     0.135551
# model_set_7     0.156008
# model_set_8     0.169911
# model_set_9     0.163299
# model_set_10    0.173383
# model_set_11    0.143170
# model_set_12    0.133859
# model_set_13    0.118544
# model_set_14    0.146467
# model_set_15    0.137847
# model_set_16    0.092931
# model_set_17    0.088243
# model_set_18    0.106165
# model_set_19    0.110331
# model_set_20    0.135531
# model_set_21    0.130391
# model_set_22    0.086235
# model_set_23    0.056514
# model_set_24    0.061067
# model_set_25    0.081503
# model_set_26    0.077590
# model_set_27    0.061730
# model_set_28    0.059003
# model_set_29    0.072328
# model_set_30    0.081666
# model_set_31    0.066470
# Name: Market, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 6.720756, p-value : 0.011871
#
# False
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.7276577
#
# ['0.0(0.0)' '-0.003(-0.35)' '0.02(3.065***)' '0.003(0.35)']
# model_set_0     0.112607
# model_set_1     0.112339
# model_set_2     0.115426
# model_set_3     0.120315
# model_set_4     0.104367
# model_set_5     0.098727
# model_set_6     0.080495
# model_set_7     0.074591
# model_set_8     0.061073
# model_set_9     0.076426
# model_set_10    0.059165
# model_set_11    0.097370
# model_set_12    0.088392
# model_set_13    0.112237
# model_set_14    0.083723
# model_set_15    0.094120
# model_set_16    0.113030
# model_set_17    0.118901
# model_set_18    0.106113
# model_set_19    0.120198
# model_set_20    0.100427
# model_set_21    0.094945
# model_set_22    0.111529
# model_set_23    0.151710
# model_set_24    0.152343
# model_set_25    0.135852
# model_set_26    0.123042
# model_set_27    0.162876
# model_set_28    0.156844
# model_set_29    0.136906
# model_set_30    0.128768
# model_set_31    0.114943
# Name: Value, dtype: float64
# model_set_0     0.112607
# model_set_1     0.112339
# model_set_2     0.115426
# model_set_3     0.120315
# model_set_4     0.104367
# model_set_5     0.098727
# model_set_6     0.080495
# model_set_7     0.074591
# model_set_8     0.061073
# model_set_9     0.076426
# model_set_10    0.059165
# model_set_11    0.097370
# model_set_12    0.088392
# model_set_13    0.112237
# model_set_14    0.083723
# model_set_15    0.094120
# model_set_16    0.113030
# model_set_17    0.118901
# model_set_18    0.106113
# model_set_19    0.120198
# model_set_20    0.100427
# model_set_21    0.094945
# model_set_22    0.111529
# model_set_23    0.151710
# model_set_24    0.152343
# model_set_25    0.135852
# model_set_26    0.123042
# model_set_27    0.162876
# model_set_28    0.156844
# model_set_29    0.136906
# model_set_30    0.128768
# model_set_31    0.114943
# Name: Value, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# ['0.0(0.0)' '-0.003(-0.35)' '0.02(3.065***)' '0.003(0.35)' '0.0(0.0)']
# model_set_0     0.112607
# model_set_1     0.112339
# model_set_2     0.115426
# model_set_3     0.120315
# model_set_4     0.104367
# model_set_5     0.098727
# model_set_6     0.080495
# model_set_7     0.074591
# model_set_8     0.061073
# model_set_9     0.076426
# model_set_10    0.059165
# model_set_11    0.097370
# model_set_12    0.088392
# model_set_13    0.112237
# model_set_14    0.083723
# model_set_15    0.094120
# model_set_16    0.113030
# model_set_17    0.118901
# model_set_18    0.106113
# model_set_19    0.120198
# model_set_20    0.100427
# model_set_21    0.094945
# model_set_22    0.111529
# model_set_23    0.151710
# model_set_24    0.152343
# model_set_25    0.135852
# model_set_26    0.123042
# model_set_27    0.162876
# model_set_28    0.156844
# model_set_29    0.136906
# model_set_30    0.128768
# model_set_31    0.114943
# Name: Value, dtype: float64
# model_set_0     0.102828
# model_set_1     0.104123
# model_set_2     0.112125
# model_set_3     0.075091
# model_set_4     0.085533
# model_set_5     0.082219
# model_set_6     0.087966
# model_set_7     0.077051
# model_set_8     0.076762
# model_set_9     0.070206
# model_set_10    0.075589
# model_set_11    0.069595
# model_set_12    0.083312
# model_set_13    0.076914
# model_set_14    0.077358
# model_set_15    0.076024
# model_set_16    0.095529
# model_set_17    0.094642
# model_set_18    0.090792
# model_set_19    0.077103
# model_set_20    0.073031
# model_set_21    0.080998
# model_set_22    0.101677
# model_set_23    0.093832
# model_set_24    0.089943
# model_set_25    0.086983
# model_set_26    0.099526
# model_set_27    0.081545
# model_set_28    0.088115
# model_set_29    0.093075
# model_set_30    0.092174
# model_set_31    0.113940
# Name: Finance, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 10.014017, p-value : 0.002408
#
# False
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 4 , pvalue : 0.0000457
#
# ['0.0(0.0)' '-0.003(-0.35)' '0.02(3.065***)' '0.003(0.35)' '0.0(0.0)'
#  '0.023(4.533***)']
# model_set_0     0.102828
# model_set_1     0.104123
# model_set_2     0.112125
# model_set_3     0.075091
# model_set_4     0.085533
# model_set_5     0.082219
# model_set_6     0.087966
# model_set_7     0.077051
# model_set_8     0.076762
# model_set_9     0.070206
# model_set_10    0.075589
# model_set_11    0.069595
# model_set_12    0.083312
# model_set_13    0.076914
# model_set_14    0.077358
# model_set_15    0.076024
# model_set_16    0.095529
# model_set_17    0.094642
# model_set_18    0.090792
# model_set_19    0.077103
# model_set_20    0.073031
# model_set_21    0.080998
# model_set_22    0.101677
# model_set_23    0.093832
# model_set_24    0.089943
# model_set_25    0.086983
# model_set_26    0.099526
# model_set_27    0.081545
# model_set_28    0.088115
# model_set_29    0.093075
# model_set_30    0.092174
# model_set_31    0.113940
# Name: Finance, dtype: float64
# model_set_0     0.083622
# model_set_1     0.082163
# model_set_2     0.068407
# model_set_3     0.112896
# model_set_4     0.114923
# model_set_5     0.124982
# model_set_6     0.135551
# model_set_7     0.156008
# model_set_8     0.169911
# model_set_9     0.163299
# model_set_10    0.173383
# model_set_11    0.143170
# model_set_12    0.133859
# model_set_13    0.118544
# model_set_14    0.146467
# model_set_15    0.137847
# model_set_16    0.092931
# model_set_17    0.088243
# model_set_18    0.106165
# model_set_19    0.110331
# model_set_20    0.135531
# model_set_21    0.130391
# model_set_22    0.086235
# model_set_23    0.056514
# model_set_24    0.061067
# model_set_25    0.081503
# model_set_26    0.077590
# model_set_27    0.061730
# model_set_28    0.059003
# model_set_29    0.072328
# model_set_30    0.081666
# model_set_31    0.066470
# Name: Market, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 43.204917, p-value : 0.000000
#
# False
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0040001
#
# ['0.0(0.0)' '-0.003(-0.35)' '0.02(3.065***)' '0.003(0.35)' '0.0(0.0)'
#  '0.023(4.533***)' '-0.02(-3.065***)']
# model_set_0     0.102828
# model_set_1     0.104123
# model_set_2     0.112125
# model_set_3     0.075091
# model_set_4     0.085533
# model_set_5     0.082219
# model_set_6     0.087966
# model_set_7     0.077051
# model_set_8     0.076762
# model_set_9     0.070206
# model_set_10    0.075589
# model_set_11    0.069595
# model_set_12    0.083312
# model_set_13    0.076914
# model_set_14    0.077358
# model_set_15    0.076024
# model_set_16    0.095529
# model_set_17    0.094642
# model_set_18    0.090792
# model_set_19    0.077103
# model_set_20    0.073031
# model_set_21    0.080998
# model_set_22    0.101677
# model_set_23    0.093832
# model_set_24    0.089943
# model_set_25    0.086983
# model_set_26    0.099526
# model_set_27    0.081545
# model_set_28    0.088115
# model_set_29    0.093075
# model_set_30    0.092174
# model_set_31    0.113940
# Name: Finance, dtype: float64
# model_set_0     0.112607
# model_set_1     0.112339
# model_set_2     0.115426
# model_set_3     0.120315
# model_set_4     0.104367
# model_set_5     0.098727
# model_set_6     0.080495
# model_set_7     0.074591
# model_set_8     0.061073
# model_set_9     0.076426
# model_set_10    0.059165
# model_set_11    0.097370
# model_set_12    0.088392
# model_set_13    0.112237
# model_set_14    0.083723
# model_set_15    0.094120
# model_set_16    0.113030
# model_set_17    0.118901
# model_set_18    0.106113
# model_set_19    0.120198
# model_set_20    0.100427
# model_set_21    0.094945
# model_set_22    0.111529
# model_set_23    0.151710
# model_set_24    0.152343
# model_set_25    0.135852
# model_set_26    0.123042
# model_set_27    0.162876
# model_set_28    0.156844
# model_set_29    0.136906
# model_set_30    0.128768
# model_set_31    0.114943
# Name: Value, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 10.014017, p-value : 0.002408
#
# False
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -4 , pvalue : 0.0000457
#
# ['0.0(0.0)' '-0.003(-0.35)' '0.02(3.065***)' '0.003(0.35)' '0.0(0.0)'
#  '0.023(4.533***)' '-0.02(-3.065***)' '-0.023(-4.533***)']
# model_set_0     0.102828
# model_set_1     0.104123
# model_set_2     0.112125
# model_set_3     0.075091
# model_set_4     0.085533
# model_set_5     0.082219
# model_set_6     0.087966
# model_set_7     0.077051
# model_set_8     0.076762
# model_set_9     0.070206
# model_set_10    0.075589
# model_set_11    0.069595
# model_set_12    0.083312
# model_set_13    0.076914
# model_set_14    0.077358
# model_set_15    0.076024
# model_set_16    0.095529
# model_set_17    0.094642
# model_set_18    0.090792
# model_set_19    0.077103
# model_set_20    0.073031
# model_set_21    0.080998
# model_set_22    0.101677
# model_set_23    0.093832
# model_set_24    0.089943
# model_set_25    0.086983
# model_set_26    0.099526
# model_set_27    0.081545
# model_set_28    0.088115
# model_set_29    0.093075
# model_set_30    0.092174
# model_set_31    0.113940
# Name: Finance, dtype: float64
# model_set_0     0.102828
# model_set_1     0.104123
# model_set_2     0.112125
# model_set_3     0.075091
# model_set_4     0.085533
# model_set_5     0.082219
# model_set_6     0.087966
# model_set_7     0.077051
# model_set_8     0.076762
# model_set_9     0.070206
# model_set_10    0.075589
# model_set_11    0.069595
# model_set_12    0.083312
# model_set_13    0.076914
# model_set_14    0.077358
# model_set_15    0.076024
# model_set_16    0.095529
# model_set_17    0.094642
# model_set_18    0.090792
# model_set_19    0.077103
# model_set_20    0.073031
# model_set_21    0.080998
# model_set_22    0.101677
# model_set_23    0.093832
# model_set_24    0.089943
# model_set_25    0.086983
# model_set_26    0.099526
# model_set_27    0.081545
# model_set_28    0.088115
# model_set_29    0.093075
# model_set_30    0.092174
# model_set_31    0.113940
# Name: Finance, dtype: float64
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# ['0.0(0.0)' '-0.003(-0.35)' '0.02(3.065***)' '0.003(0.35)' '0.0(0.0)'
#  '0.023(4.533***)' '-0.02(-3.065***)' '-0.023(-4.533***)' '0.0(0.0)']

# %%
file_list_2 = ['1_3_feature 값.csv','3_6_feature 값.csv']

# %%
for file in file_list_2:
    Total_Stat = np.array([])
    for index in index_2:
        for idx in index_2:
            df = pd.read_csv(path_dir + "//" + file, encoding = 'cp949',index_col = 0)
            left_value = df.loc[index,:]
            right_value = df.loc[idx,:]


            stat, pval = Ttest(left_value,right_value)

            left_mean = np.mean(left_value)
            right_mean = np.mean(right_value)

            star = sign(pval)

            Statstr = str(np.round(left_mean - right_mean,3)) + "(" + str(np.round(stat,3)) + star +  ")"
            Total_Stat = np.append(Total_Stat, Statstr)
            print(Total_Stat)
    Total_df = pd.DataFrame(Total_Stat.reshape(4,4), columns = index_2, index = index_2)
    Total_df.to_csv(path_dir+ '//' + str(file[:5]) + '_mean.csv', encoding = 'euc-kr')
# Out:
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# ['0.0(0.0)']
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.797056, p-value : 0.375427
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -1 , pvalue : 0.0527896
#
# ['0.0(0.0)' '-0.007(-1.974*)']
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.533749, p-value : 0.467787
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -1 , pvalue : 0.0850730
#
# ['0.0(0.0)' '-0.007(-1.974*)' '-0.006(-1.75*)']
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.217908, p-value : 0.642275
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -4 , pvalue : 0.0000395
#
# ['0.0(0.0)' '-0.007(-1.974*)' '-0.006(-1.75*)' '-0.017(-4.427***)']
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.797056, p-value : 0.375427
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 1 , pvalue : 0.0527896
#
# ['0.0(0.0)' '-0.007(-1.974*)' '-0.006(-1.75*)' '-0.017(-4.427***)'
#  '0.007(1.974*)']
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# ['0.0(0.0)' '-0.007(-1.974*)' '-0.006(-1.75*)' '-0.017(-4.427***)'
#  '0.007(1.974*)' '0.0(0.0)']
# 0	 & 	Measure :
#
# LeveneResult -- stat : 3.401950, p-value : 0.069898
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.6836133
#
# ['0.0(0.0)' '-0.007(-1.974*)' '-0.006(-1.75*)' '-0.017(-4.427***)'
#  '0.007(1.974*)' '0.0(0.0)' '0.001(0.409)']
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.173150, p-value : 0.678764
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0198584
#
# ['0.0(0.0)' '-0.007(-1.974*)' '-0.006(-1.75*)' '-0.017(-4.427***)'
#  '0.007(1.974*)' '0.0(0.0)' '0.001(0.409)' '-0.009(-2.391**)']
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.533749, p-value : 0.467787
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 1 , pvalue : 0.0850730
#
# ['0.0(0.0)' '-0.007(-1.974*)' '-0.006(-1.75*)' '-0.017(-4.427***)'
#  '0.007(1.974*)' '0.0(0.0)' '0.001(0.409)' '-0.009(-2.391**)'
#  '0.006(1.75*)']
# 0	 & 	Measure :
#
# LeveneResult -- stat : 3.401950, p-value : 0.069898
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.6836133
#
# ['0.0(0.0)' '-0.007(-1.974*)' '-0.006(-1.75*)' '-0.017(-4.427***)'
#  '0.007(1.974*)' '0.0(0.0)' '0.001(0.409)' '-0.009(-2.391**)'
#  '0.006(1.75*)' '-0.001(-0.409)']
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# ['0.0(0.0)' '-0.007(-1.974*)' '-0.006(-1.75*)' '-0.017(-4.427***)'
#  '0.007(1.974*)' '0.0(0.0)' '0.001(0.409)' '-0.009(-2.391**)'
#  '0.006(1.75*)' '-0.001(-0.409)' '0.0(0.0)']
# 0	 & 	Measure :
#
# LeveneResult -- stat : 1.660379, p-value : 0.202340
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0035701
#
# ['0.0(0.0)' '-0.007(-1.974*)' '-0.006(-1.75*)' '-0.017(-4.427***)'
#  '0.007(1.974*)' '0.0(0.0)' '0.001(0.409)' '-0.009(-2.391**)'
#  '0.006(1.75*)' '-0.001(-0.409)' '0.0(0.0)' '-0.011(-3.029***)']
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.217908, p-value : 0.642275
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 4 , pvalue : 0.0000395
#
# ['0.0(0.0)' '-0.007(-1.974*)' '-0.006(-1.75*)' '-0.017(-4.427***)'
#  '0.007(1.974*)' '0.0(0.0)' '0.001(0.409)' '-0.009(-2.391**)'
#  '0.006(1.75*)' '-0.001(-0.409)' '0.0(0.0)' '-0.011(-3.029***)'
#  '0.017(4.427***)']
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.173150, p-value : 0.678764
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0198584
#
# ['0.0(0.0)' '-0.007(-1.974*)' '-0.006(-1.75*)' '-0.017(-4.427***)'
#  '0.007(1.974*)' '0.0(0.0)' '0.001(0.409)' '-0.009(-2.391**)'
#  '0.006(1.75*)' '-0.001(-0.409)' '0.0(0.0)' '-0.011(-3.029***)'
#  '0.017(4.427***)' '0.009(2.391**)']
# 0	 & 	Measure :
#
# LeveneResult -- stat : 1.660379, p-value : 0.202340
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0035701
#
# ['0.0(0.0)' '-0.007(-1.974*)' '-0.006(-1.75*)' '-0.017(-4.427***)'
#  '0.007(1.974*)' '0.0(0.0)' '0.001(0.409)' '-0.009(-2.391**)'
#  '0.006(1.75*)' '-0.001(-0.409)' '0.0(0.0)' '-0.011(-3.029***)'
#  '0.017(4.427***)' '0.009(2.391**)' '0.011(3.029***)']
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# ['0.0(0.0)' '-0.007(-1.974*)' '-0.006(-1.75*)' '-0.017(-4.427***)'
#  '0.007(1.974*)' '0.0(0.0)' '0.001(0.409)' '-0.009(-2.391**)'
#  '0.006(1.75*)' '-0.001(-0.409)' '0.0(0.0)' '-0.011(-3.029***)'
#  '0.017(4.427***)' '0.009(2.391**)' '0.011(3.029***)' '0.0(0.0)']
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# ['0.0(0.0)']
# 0	 & 	Measure :
#
# LeveneResult -- stat : 9.034617, p-value : 0.003821
#
# False
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 4 , pvalue : 0.0000641
#
# ['0.0(0.0)' '0.019(4.438***)']
# 0	 & 	Measure :
#
# LeveneResult -- stat : 2.122489, p-value : 0.150197
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0031739
#
# ['0.0(0.0)' '0.019(4.438***)' '0.015(3.07***)']
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.005899, p-value : 0.939025
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -4 , pvalue : 0.0000109
#
# ['0.0(0.0)' '0.019(4.438***)' '0.015(3.07***)' '-0.026(-4.788***)']
# 0	 & 	Measure :
#
# LeveneResult -- stat : 9.034617, p-value : 0.003821
#
# False
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -4 , pvalue : 0.0000641
#
# ['0.0(0.0)' '0.019(4.438***)' '0.015(3.07***)' '-0.026(-4.788***)'
#  '-0.019(-4.438***)']
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# ['0.0(0.0)' '0.019(4.438***)' '0.015(3.07***)' '-0.026(-4.788***)'
#  '-0.019(-4.438***)' '0.0(0.0)']
# 0	 & 	Measure :
#
# LeveneResult -- stat : 4.243706, p-value : 0.043600
#
# False
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -1 , pvalue : 0.1672905
#
# ['0.0(0.0)' '0.019(4.438***)' '0.015(3.07***)' '-0.026(-4.788***)'
#  '-0.019(-4.438***)' '0.0(0.0)' '-0.004(-1.4)']
# 0	 & 	Measure :
#
# LeveneResult -- stat : 8.872396, p-value : 0.004128
#
# False
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -11 , pvalue : 0.0000000
#
# ['0.0(0.0)' '0.019(4.438***)' '0.015(3.07***)' '-0.026(-4.788***)'
#  '-0.019(-4.438***)' '0.0(0.0)' '-0.004(-1.4)' '-0.045(-11.008***)']
# 0	 & 	Measure :
#
# LeveneResult -- stat : 2.122489, p-value : 0.150197
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0031739
#
# ['0.0(0.0)' '0.019(4.438***)' '0.015(3.07***)' '-0.026(-4.788***)'
#  '-0.019(-4.438***)' '0.0(0.0)' '-0.004(-1.4)' '-0.045(-11.008***)'
#  '-0.015(-3.07***)']
# 0	 & 	Measure :
#
# LeveneResult -- stat : 4.243706, p-value : 0.043600
#
# False
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 1 , pvalue : 0.1672905
#
# ['0.0(0.0)' '0.019(4.438***)' '0.015(3.07***)' '-0.026(-4.788***)'
#  '-0.019(-4.438***)' '0.0(0.0)' '-0.004(-1.4)' '-0.045(-11.008***)'
#  '-0.015(-3.07***)' '0.004(1.4)']
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# ['0.0(0.0)' '0.019(4.438***)' '0.015(3.07***)' '-0.026(-4.788***)'
#  '-0.019(-4.438***)' '0.0(0.0)' '-0.004(-1.4)' '-0.045(-11.008***)'
#  '-0.015(-3.07***)' '0.004(1.4)' '0.0(0.0)']
# 0	 & 	Measure :
#
# LeveneResult -- stat : 1.943028, p-value : 0.168316
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -8 , pvalue : 0.0000000
#
# ['0.0(0.0)' '0.019(4.438***)' '0.015(3.07***)' '-0.026(-4.788***)'
#  '-0.019(-4.438***)' '0.0(0.0)' '-0.004(-1.4)' '-0.045(-11.008***)'
#  '-0.015(-3.07***)' '0.004(1.4)' '0.0(0.0)' '-0.041(-8.86***)']
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.005899, p-value : 0.939025
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 4 , pvalue : 0.0000109
#
# ['0.0(0.0)' '0.019(4.438***)' '0.015(3.07***)' '-0.026(-4.788***)'
#  '-0.019(-4.438***)' '0.0(0.0)' '-0.004(-1.4)' '-0.045(-11.008***)'
#  '-0.015(-3.07***)' '0.004(1.4)' '0.0(0.0)' '-0.041(-8.86***)'
#  '0.026(4.788***)']
# 0	 & 	Measure :
#
# LeveneResult -- stat : 8.872396, p-value : 0.004128
#
# False
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 11 , pvalue : 0.0000000
#
# ['0.0(0.0)' '0.019(4.438***)' '0.015(3.07***)' '-0.026(-4.788***)'
#  '-0.019(-4.438***)' '0.0(0.0)' '-0.004(-1.4)' '-0.045(-11.008***)'
#  '-0.015(-3.07***)' '0.004(1.4)' '0.0(0.0)' '-0.041(-8.86***)'
#  '0.026(4.788***)' '0.045(11.008***)']
# 0	 & 	Measure :
#
# LeveneResult -- stat : 1.943028, p-value : 0.168316
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 8 , pvalue : 0.0000000
#
# ['0.0(0.0)' '0.019(4.438***)' '0.015(3.07***)' '-0.026(-4.788***)'
#  '-0.019(-4.438***)' '0.0(0.0)' '-0.004(-1.4)' '-0.045(-11.008***)'
#  '-0.015(-3.07***)' '0.004(1.4)' '0.0(0.0)' '-0.041(-8.86***)'
#  '0.026(4.788***)' '0.045(11.008***)' '0.041(8.86***)']
# 0	 & 	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# ['0.0(0.0)' '0.019(4.438***)' '0.015(3.07***)' '-0.026(-4.788***)'
#  '-0.019(-4.438***)' '0.0(0.0)' '-0.004(-1.4)' '-0.045(-11.008***)'
#  '-0.015(-3.07***)' '0.004(1.4)' '0.0(0.0)' '-0.041(-8.86***)'
#  '0.026(4.788***)' '0.045(11.008***)' '0.041(8.86***)' '0.0(0.0)']
