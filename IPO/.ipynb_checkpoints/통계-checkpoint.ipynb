# %%
import pandas as pd
import numpy as np
import os

# %%
df_return = pd.read_csv("Result/8개 정리/수익률정리.csv",index_col = 0)

# %%
df_return
# Out:
#              공모가 대비 1개월  공모가 대비 3개월  공모가 대비 6개월  1개월 대비 3개월  3개월 대비 6개월  \
# buy_sell수익률    0.235342    0.199886    0.267135    0.014614    0.065830
# buy수익률         0.344073    0.346693    0.415803    0.040730    0.096648
# all수익률         0.324157    0.334694    0.419719    0.032461    0.071989
#
#              종가 대비 1개월  종가 대비 3개월  종가 대비 6개월
# buy_sell수익률   0.015881   0.019875   0.064075
# buy수익률       -0.001637  -0.004214   0.117736
# all수익률       -0.011650   0.016261   0.086911

# %%
df_value = pd.read_csv("Result/8개 정리/특이도재현율.csv",index_col = 0,encoding = 'cp949')

# %%
df_value
# Out:
#      model_set_0  model_set_1  model_set_2  model_set_3  model_set_4  \
# 특이도     0.666667     0.571429     0.457143     0.593750     0.526316
# 재현율     0.352941     0.750000     1.000000     0.730769     0.800000
# 특이도     0.833333     0.565217     0.437500     0.682927     0.636364
# 재현율     0.263158     0.764706     0.875000     0.933333     0.965517
# 특이도     0.636364     0.695652     0.527778     0.694444     0.666667
# 재현율     0.318182     0.800000     1.000000     0.781250     1.000000
# 특이도     0.333333     0.285714     0.222222     0.250000     0.200000
# 재현율     0.444444     0.222222     0.181818     0.400000     0.200000
# 특이도     0.285714     0.285714     0.400000     0.400000     0.250000
# 재현율     0.285714     0.285714     0.166667     0.105263     0.052632
# 특이도     0.000000     0.142857     0.125000     0.296296     0.257143
# 재현율     0.000000     0.250000     0.200000     0.666667     0.818182
# 특이도     0.437500     0.375000     0.352941     0.370370     0.444444
# 재현율     0.777778     0.750000     0.600000     0.526316     0.666667
# 특이도     0.470588     0.368421     0.285714     0.357143     0.375000
# 재현율     0.727273     0.700000     0.545455     0.500000     0.300000
#
#      model_set_5  model_set_6  model_set_7  model_set_8  model_set_9  ...  \
# 특이도     0.528302     0.550000     0.450704     0.392857     0.478261  ...
# 재현율     0.933333     0.687500     1.000000     0.666667     0.846154  ...
# 특이도     0.530612     0.818182     0.416667     0.415385     0.432432  ...
# 재현율     0.812500     0.257143     0.806452     0.818182     0.551724  ...
# 특이도     0.565217     0.548387     0.388060     0.424658     0.542857  ...
# 재현율     0.838710     0.500000     0.962963     0.968750     0.633333  ...
# 특이도     0.222222     0.200000     0.133333     0.100000     0.250000  ...
# 재현율     0.400000     0.200000     0.285714     0.250000     0.222222  ...
# 특이도     0.666667     0.333333     0.266667     0.277778     0.225806  ...
# 재현율     0.095238     0.352941     0.727273     0.714286     0.583333  ...
# 특이도     0.242424     0.243902     0.272727     0.200000     0.250000  ...
# 재현율     0.615385     0.714286     0.857143     0.642857     0.769231  ...
# 특이도     0.304348     0.317073     0.205882     0.152174     0.000000  ...
# 재현율     0.388889     0.764706     0.538462     0.500000     0.000000  ...
# 특이도     0.277778     0.583333     0.314286     0.275862     0.000000  ...
# 재현율     0.238095     0.350000     0.647059     0.421053     0.000000  ...
#
#      model_set_23  model_set_24  model_set_25  model_set_26  model_set_27  \
# 특이도      0.500000      0.375000      0.269231      0.464286      0.545455
# 재현율      0.166667      0.600000      0.388889      0.481481      0.333333
# 특이도      0.384615      0.304348      0.388889      0.571429      0.487805
# 재현율      0.294118      0.411765      0.350000      0.592593      0.625000
# 특이도      0.259259      0.243243      0.263158      0.516129      0.641026
# 재현율      0.411765      0.529412      0.500000      0.551724      0.735294
# 특이도      0.266667      0.166667      0.266667      0.363636      0.285714
# 재현율      0.444444      0.142857      0.266667      0.266667      0.400000
# 특이도      0.095238      0.291667      0.275862      0.200000      0.314286
# 재현율      0.200000      0.583333      0.727273      0.636364      0.916667
# 특이도      0.100000      0.120000      0.111111      0.192308      0.105263
# 재현율      0.285714      0.500000      0.333333      0.625000      0.222222
# 특이도      0.200000      0.258065      0.437500      0.260870      0.142857
# 재현율      0.666667      0.666667      0.583333      0.500000      0.083333
# 특이도      0.117647      0.115385      0.200000      0.090909      0.166667
# 재현율      0.250000      0.333333      0.300000      0.111111      0.100000
#
#      model_set_28  model_set_29  model_set_30  model_set_31      mean
# 특이도      0.750000      0.720930      0.757576      0.736842  0.474119
# 재현율      0.437500      0.688889      0.833333      1.000000  0.623600
# 특이도      0.621622      0.571429      0.617647      0.750000  0.470367
# 재현율      0.575000      0.972973      0.875000      0.461538  0.601874
# 특이도      0.589744      0.641026      0.689655      0.722222  0.477573
# 재현율      0.511111      0.595238      0.714286      0.928571  0.656083
# 특이도      0.081633      0.042553      0.000000      0.111111  0.180681
# 재현율      1.000000      0.666667      0.000000      1.000000  0.336740
# 특이도      0.250000      0.243902      0.090909      0.444444  0.285392
# 재현율      0.375000      0.666667      0.090909      0.666667  0.450366
# 특이도      0.133333      0.142857      0.250000      0.000000  0.153036
# 재현율      0.166667      0.166667      0.142857      0.000000  0.382083
# 특이도      0.250000      0.250000      0.000000      0.000000  0.210888
# 재현율      0.375000      0.125000      0.000000      0.000000  0.387154
# 특이도      0.200000      0.272727      0.333333      0.000000  0.232972
# 재현율      0.083333      0.272727      0.111111      0.000000  0.326037
#
# [16 rows x 33 columns]

# %%
df_0_1 = pd.read_csv("Result/랜덤포레스트/feature 값,index_col = 0,encoding = 'cp949')

# %%
path_dir = 'Result/랜덤포레스트/모델 평가' 
file_list = os.listdir(path_dir)
print(file_list)
# Out:
# ['0_1_모델 평가.csv', '0_3_모델 평가.csv', '0_6_모델 평가.csv', '1_3_모델 평가.csv', '3_6_모델 평가.csv', 'end_1_모델 평가.csv', 'end_3_모델 평가.csv', 'end_6_모델 평가.csv']

# %%
def sign(pval):
    if(pval <= 0.01):
        return "***"
    elif(pval <= 0.05):
        return "**"
    elif(pval<= 0.1):
        return "*"
    else:
        return ""
for i in range(4):
    Total_Stat = np.array([])
    for left in file_list:
        for right in file_list:   
            left_df = pd.read_csv(path_dir + "//" + left, encoding = 'cp949',index_col = 0)
            right_df = pd.read_csv(path_dir + "//" + right, encoding = 'cp949',index_col = 0)
            left_value = left_df.iloc[i+4,:]
            right_value = right_df.iloc[i+4,:]
            stat, pval = Ttest(left_value,right_value,leftstr = left , rightstr = right)

            left_mean = np.mean(left_value)
            right_mean = np.mean(right_value)

            star = sign(pval)

            Statstr = str(np.round(left_mean - right_mean,2)) + "(" + str(np.round(stat,2)) + star +  ")"
            Total_Stat = np.append(Total_Stat, Statstr)
            statistics = np.append(statistics, stat)
            pvalues = np.append(pvalues, pval)


    Total_df = pd.DataFrame(Total_Stat.reshape(8,8), index = file_list, columns = file_list)

    Total_df.to_csv(path_dir+ '//' + str(i) + '.csv', encoding = 'euc-kr')
# Out:
# 0	0_1_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_1_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_1_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.643380, p-value : 0.204635
#
# True
# 0_1_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.9749200
#
# 0	0_1_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.123443, p-value : 0.726522
#
# True
# 0_1_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.7052119
#
# 0	0_1_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.334312, p-value : 0.565225
#
# True
# 0_1_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0003611
#
# 0	0_1_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.964514, p-value : 0.166018
#
# True
# 0_1_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0018289
#
# 0	0_1_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.111897, p-value : 0.739123
#
# True
# 0_1_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 0 , pvalue : 0.3975837
#
# 0	0_1_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.727614, p-value : 0.396941
#
# True
# 0_1_모델 평가.csv end_3_모델 평가.csv
#
# statistic : -1 , pvalue : 0.1726240
#
# 0	0_1_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 4.064427, p-value : 0.048134
#
# False
# 0_1_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0015595
#
# 0	0_3_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.643380, p-value : 0.204635
#
# True
# 0_3_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 0 , pvalue : 0.9749200
#
# 0	0_3_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_3_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_3_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.706173, p-value : 0.403946
#
# True
# 0_3_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.6473837
#
# 0	0_3_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 2.745909, p-value : 0.102556
#
# True
# 0_3_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -4 , pvalue : 0.0001235
#
# 0	0_3_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 6.040228, p-value : 0.016793
#
# False
# 0_3_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0010005
#
# 0	0_3_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.073682, p-value : 0.304140
#
# True
# 0_3_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 0 , pvalue : 0.3551923
#
# 0	0_3_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.183204, p-value : 0.670118
#
# True
# 0_3_모델 평가.csv end_3_모델 평가.csv
#
# statistic : -1 , pvalue : 0.1276979
#
# 0	0_3_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.478436, p-value : 0.491714
#
# True
# 0_3_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0002260
#
# 0	0_6_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.123443, p-value : 0.726522
#
# True
# 0_6_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 0 , pvalue : 0.7052119
#
# 0	0_6_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.706173, p-value : 0.403946
#
# True
# 0_6_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.6473837
#
# 0	0_6_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_6_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_6_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.742253, p-value : 0.392260
#
# True
# 0_6_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -4 , pvalue : 0.0000943
#
# 0	0_6_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 2.729849, p-value : 0.103545
#
# True
# 0_6_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0005849
#
# 0	0_6_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.003177, p-value : 0.955230
#
# True
# 0_6_모델 평가.csv end_1_모델 평가.csv
#
# statistic : -1 , pvalue : 0.2087827
#
# 0	0_6_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.199343, p-value : 0.656808
#
# True
# 0_6_모델 평가.csv end_3_모델 평가.csv
#
# statistic : -1 , pvalue : 0.0726076
#
# 0	0_6_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 2.187252, p-value : 0.144220
#
# True
# 0_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0002429
#
# 0	1_3_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.334312, p-value : 0.565225
#
# True
# 1_3_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0003611
#
# 0	1_3_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 2.745909, p-value : 0.102556
#
# True
# 1_3_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 4 , pvalue : 0.0001235
#
# 0	1_3_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.742253, p-value : 0.392260
#
# True
# 1_3_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 4 , pvalue : 0.0000943
#
# 0	1_3_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 1_3_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	1_3_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.583597, p-value : 0.447803
#
# True
# 1_3_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.7758292
#
# 0	1_3_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.779800, p-value : 0.380614
#
# True
# 1_3_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0024195
#
# 0	1_3_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.700726, p-value : 0.197014
#
# True
# 1_3_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0066637
#
# 0	1_3_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 4.948572, p-value : 0.029762
#
# False
# 1_3_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 1 , pvalue : 0.1515384
#
# 0	3_6_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.964514, p-value : 0.166018
#
# True
# 3_6_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0018289
#
# 0	3_6_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 6.040228, p-value : 0.016793
#
# False
# 3_6_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0010005
#
# 0	3_6_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 2.729849, p-value : 0.103545
#
# True
# 3_6_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0005849
#
# 0	3_6_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.583597, p-value : 0.447803
#
# True
# 3_6_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.7758292
#
# 0	3_6_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 3_6_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	3_6_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 2.970928, p-value : 0.089757
#
# True
# 3_6_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0100554
#
# 0	3_6_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 4.460890, p-value : 0.038715
#
# False
# 3_6_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0251609
#
# 0	3_6_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 9.139723, p-value : 0.003634
#
# False
# 3_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 1 , pvalue : 0.3208342
#
# 0	end_1_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.111897, p-value : 0.739123
#
# True
# end_1_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 0 , pvalue : 0.3975837
#
# 0	end_1_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.073682, p-value : 0.304140
#
# True
# end_1_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.3551923
#
# 0	end_1_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.003177, p-value : 0.955230
#
# True
# end_1_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 1 , pvalue : 0.2087827
#
# 0	end_1_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.779800, p-value : 0.380614
#
# True
# end_1_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0024195
#
# 0	end_1_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 2.970928, p-value : 0.089757
#
# True
# end_1_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0100554
#
# 0	end_1_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_1_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	end_1_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.327369, p-value : 0.569281
#
# True
# end_1_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.5996633
#
# 0	end_1_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 3.451967, p-value : 0.067926
#
# True
# end_1_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0136817
#
# 0	end_3_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.727614, p-value : 0.396941
#
# True
# end_3_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 1 , pvalue : 0.1726240
#
# 0	end_3_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.183204, p-value : 0.670118
#
# True
# end_3_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 1 , pvalue : 0.1276979
#
# 0	end_3_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.199343, p-value : 0.656808
#
# True
# end_3_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 1 , pvalue : 0.0726076
#
# 0	end_3_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.700726, p-value : 0.197014
#
# True
# end_3_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0066637
#
# 0	end_3_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 4.460890, p-value : 0.038715
#
# False
# end_3_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0251609
#
# 0	end_3_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.327369, p-value : 0.569281
#
# True
# end_3_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 0 , pvalue : 0.5996633
#
# 0	end_3_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_3_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
# 0	end_3_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.291203, p-value : 0.260200
#
# True
# end_3_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0444596
#
# 0	end_6_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 4.064427, p-value : 0.048134
#
# False
# end_6_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0015595
#
# 0	end_6_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.478436, p-value : 0.491714
#
# True
# end_6_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0002260
#
# 0	end_6_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 2.187252, p-value : 0.144220
#
# True
# end_6_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0002429
#
# 0	end_6_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 4.948572, p-value : 0.029762
#
# False
# end_6_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -1 , pvalue : 0.1515384
#
# 0	end_6_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 9.139723, p-value : 0.003634
#
# False
# end_6_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -1 , pvalue : 0.3208342
#
# 0	end_6_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 3.451967, p-value : 0.067926
#
# True
# end_6_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0136817
#
# 0	end_6_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.291203, p-value : 0.260200
#
# True
# end_6_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0444596
#
# 0	end_6_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_1_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_1_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_1_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 2.342902, p-value : 0.130942
#
# True
# 0_1_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.5873408
#
# 0	0_1_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.667097, p-value : 0.201441
#
# True
# 0_1_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.8598036
#
# 0	0_1_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.271053, p-value : 0.263913
#
# True
# 0_1_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -7 , pvalue : 0.0000000
#
# 0	0_1_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.524751, p-value : 0.471547
#
# True
# 0_1_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -6 , pvalue : 0.0000000
#
# 0	0_1_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.584397, p-value : 0.212848
#
# True
# 0_1_모델 평가.csv end_1_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0002248
#
# 0	0_1_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.176212, p-value : 0.282328
#
# True
# 0_1_모델 평가.csv end_3_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0010189
#
# 0	0_1_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.607765, p-value : 0.438597
#
# True
# 0_1_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0003723
#
# 0	0_3_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 2.342902, p-value : 0.130942
#
# True
# 0_3_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 0 , pvalue : 0.5873408
#
# 0	0_3_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_3_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_3_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.131378, p-value : 0.718240
#
# True
# 0_3_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.6584850
#
# 0	0_3_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.252786, p-value : 0.616902
#
# True
# 0_3_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -8 , pvalue : 0.0000000
#
# 0	0_3_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.677893, p-value : 0.413469
#
# True
# 0_3_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -7 , pvalue : 0.0000000
#
# 0	0_3_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.241466, p-value : 0.624884
#
# True
# 0_3_모델 평가.csv end_1_모델 평가.csv
#
# statistic : -4 , pvalue : 0.0001322
#
# 0	0_3_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.196974, p-value : 0.658720
#
# True
# 0_3_모델 평가.csv end_3_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0009773
#
# 0	0_3_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.725423, p-value : 0.397649
#
# True
# 0_3_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0003015
#
# 0	0_6_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.667097, p-value : 0.201441
#
# True
# 0_6_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 0 , pvalue : 0.8598036
#
# 0	0_6_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.131378, p-value : 0.718240
#
# True
# 0_6_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.6584850
#
# 0	0_6_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_6_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_6_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.026647, p-value : 0.870861
#
# True
# 0_6_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -8 , pvalue : 0.0000000
#
# 0	0_6_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.284672, p-value : 0.595563
#
# True
# 0_6_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -7 , pvalue : 0.0000000
#
# 0	0_6_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.013058, p-value : 0.909391
#
# True
# 0_6_모델 평가.csv end_1_모델 평가.csv
#
# statistic : -4 , pvalue : 0.0000267
#
# 0	0_6_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.016157, p-value : 0.899265
#
# True
# 0_6_모델 평가.csv end_3_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0002493
#
# 0	0_6_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.297739, p-value : 0.587262
#
# True
# 0_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -4 , pvalue : 0.0000729
#
# 0	1_3_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.271053, p-value : 0.263913
#
# True
# 1_3_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 7 , pvalue : 0.0000000
#
# 0	1_3_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.252786, p-value : 0.616902
#
# True
# 1_3_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 8 , pvalue : 0.0000000
#
# 0	1_3_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.026647, p-value : 0.870861
#
# True
# 1_3_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 8 , pvalue : 0.0000000
#
# 0	1_3_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 1_3_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	1_3_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.141351, p-value : 0.708225
#
# True
# 1_3_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.4787026
#
# 0	1_3_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.004244, p-value : 0.948266
#
# True
# 1_3_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 4 , pvalue : 0.0000291
#
# 0	1_3_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000480, p-value : 0.982597
#
# True
# 1_3_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 4 , pvalue : 0.0000292
#
# 0	1_3_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.141305, p-value : 0.708271
#
# True
# 1_3_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 4 , pvalue : 0.0001379
#
# 0	3_6_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.524751, p-value : 0.471547
#
# True
# 3_6_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 6 , pvalue : 0.0000000
#
# 0	3_6_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.677893, p-value : 0.413469
#
# True
# 3_6_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 7 , pvalue : 0.0000000
#
# 0	3_6_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.284672, p-value : 0.595563
#
# True
# 3_6_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 7 , pvalue : 0.0000000
#
# 0	3_6_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.141351, p-value : 0.708225
#
# True
# 3_6_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.4787026
#
# 0	3_6_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 3_6_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	3_6_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.216321, p-value : 0.643487
#
# True
# 3_6_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0009715
#
# 0	3_6_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.138437, p-value : 0.711109
#
# True
# 3_6_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0007511
#
# 0	3_6_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000517, p-value : 0.981929
#
# True
# 3_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0026112
#
# 0	end_1_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.584397, p-value : 0.212848
#
# True
# end_1_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0002248
#
# 0	end_1_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.241466, p-value : 0.624884
#
# True
# end_1_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 4 , pvalue : 0.0001322
#
# 0	end_1_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.013058, p-value : 0.909391
#
# True
# end_1_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 4 , pvalue : 0.0000267
#
# 0	end_1_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.004244, p-value : 0.948266
#
# True
# end_1_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -4 , pvalue : 0.0000291
#
# 0	end_1_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.216321, p-value : 0.643487
#
# True
# end_1_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0009715
# 0	end_1_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_1_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	end_1_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.001243, p-value : 0.971985
#
# True
# end_1_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.7459011
#
# 0	end_1_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.225313, p-value : 0.636689
#
# True
# end_1_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.9270473
#
# 0	end_3_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.176212, p-value : 0.282328
#
# True
# end_3_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0010189
#
# 0	end_3_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.196974, p-value : 0.658720
#
# True
# end_3_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0009773
#
# 0	end_3_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.016157, p-value : 0.899265
#
# True
# end_3_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0002493
#
# 0	end_3_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000480, p-value : 0.982597
#
# True
# end_3_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -4 , pvalue : 0.0000292
#
# 0	end_3_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.138437, p-value : 0.711109
#
# True
# end_3_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0007511
#
# 0	end_3_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.001243, p-value : 0.971985
#
# True
# end_3_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 0 , pvalue : 0.7459011
#
# 0	end_3_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_3_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	end_3_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.137066, p-value : 0.712478
#
# True
# end_3_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.6999635
#
# 0	end_6_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.607765, p-value : 0.438597
#
# True
# end_6_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0003723
#
# 0	end_6_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.725423, p-value : 0.397649
#
# True
# end_6_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0003015
#
# 0	end_6_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.297739, p-value : 0.587262
#
# True
# end_6_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 4 , pvalue : 0.0000729
#
# 0	end_6_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.141305, p-value : 0.708271
#
# True
# end_6_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -4 , pvalue : 0.0001379
#
# 0	end_6_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000517, p-value : 0.981929
#
# True
# end_6_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0026112
#
# 0	end_6_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.225313, p-value : 0.636689
#
# True
# end_6_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 0 , pvalue : 0.9270473
#
# 0	end_6_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.137066, p-value : 0.712478
#
# True
# end_6_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.6999635
#
# 0	end_6_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_1_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_1_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_1_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.643380, p-value : 0.204635
#
# True
# 0_1_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.9749200
#
# 0	0_1_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.123443, p-value : 0.726522
#
# True
# 0_1_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.7052119
#
# 0	0_1_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.334312, p-value : 0.565225
#
# True
# 0_1_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0003611
#
# 0	0_1_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.964514, p-value : 0.166018
#
# True
# 0_1_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0018289
#
# 0	0_1_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.111897, p-value : 0.739123
#
# True
# 0_1_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 0 , pvalue : 0.3975837
#
# 0	0_1_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.727614, p-value : 0.396941
#
# True
# 0_1_모델 평가.csv end_3_모델 평가.csv
#
# statistic : -1 , pvalue : 0.1726240
#
# 0	0_1_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 4.064427, p-value : 0.048134
#
# False
# 0_1_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0015595
#
# 0	0_3_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.643380, p-value : 0.204635
#
# True
# 0_3_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 0 , pvalue : 0.9749200
#
# 0	0_3_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_3_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_3_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.706173, p-value : 0.403946
#
# True
# 0_3_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.6473837
#
# 0	0_3_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 2.745909, p-value : 0.102556
#
# True
# 0_3_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -4 , pvalue : 0.0001235
#
# 0	0_3_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 6.040228, p-value : 0.016793
#
# False
# 0_3_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0010005
#
# 0	0_3_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.073682, p-value : 0.304140
#
# True
# 0_3_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 0 , pvalue : 0.3551923
#
# 0	0_3_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.183204, p-value : 0.670118
#
# True
# 0_3_모델 평가.csv end_3_모델 평가.csv
#
# statistic : -1 , pvalue : 0.1276979
#
# 0	0_3_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.478436, p-value : 0.491714
#
# True
# 0_3_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0002260
#
# 0	0_6_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.123443, p-value : 0.726522
#
# True
# 0_6_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 0 , pvalue : 0.7052119
#
# 0	0_6_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.706173, p-value : 0.403946
#
# True
# 0_6_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.6473837
#
# 0	0_6_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_6_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_6_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.742253, p-value : 0.392260
#
# True
# 0_6_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -4 , pvalue : 0.0000943
#
# 0	0_6_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 2.729849, p-value : 0.103545
#
# True
# 0_6_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0005849
#
# 0	0_6_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.003177, p-value : 0.955230
#
# True
# 0_6_모델 평가.csv end_1_모델 평가.csv
#
# statistic : -1 , pvalue : 0.2087827
#
# 0	0_6_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.199343, p-value : 0.656808
#
# True
# 0_6_모델 평가.csv end_3_모델 평가.csv
#
# statistic : -1 , pvalue : 0.0726076
#
# 0	0_6_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 2.187252, p-value : 0.144220
#
# True
# 0_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0002429
#
# 0	1_3_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.334312, p-value : 0.565225
#
# True
# 1_3_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0003611
#
# 0	1_3_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 2.745909, p-value : 0.102556
#
# True
# 1_3_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 4 , pvalue : 0.0001235
#
# 0	1_3_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.742253, p-value : 0.392260
#
# True
# 1_3_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 4 , pvalue : 0.0000943
#
# 0	1_3_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 1_3_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	1_3_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.583597, p-value : 0.447803
#
# True
# 1_3_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.7758292
#
# 0	1_3_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.779800, p-value : 0.380614
#
# True
# 1_3_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0024195
#
# 0	1_3_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.700726, p-value : 0.197014
#
# True
# 1_3_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0066637
#
# 0	1_3_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 4.948572, p-value : 0.029762
#
# False
# 1_3_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 1 , pvalue : 0.1515384
#
# 0	3_6_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.964514, p-value : 0.166018
#
# True
# 3_6_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0018289
#
# 0	3_6_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 6.040228, p-value : 0.016793
#
# False
# 3_6_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0010005
#
# 0	3_6_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 2.729849, p-value : 0.103545
#
# True
# 3_6_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0005849
# 0	3_6_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.583597, p-value : 0.447803
#
# True
# 3_6_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.7758292
#
# 0	3_6_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 3_6_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	3_6_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 2.970928, p-value : 0.089757
#
# True
# 3_6_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0100554
#
# 0	3_6_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 4.460890, p-value : 0.038715
#
# False
# 3_6_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0251609
#
# 0	3_6_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 9.139723, p-value : 0.003634
#
# False
# 3_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 1 , pvalue : 0.3208342
#
# 0	end_1_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.111897, p-value : 0.739123
#
# True
# end_1_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 0 , pvalue : 0.3975837
#
# 0	end_1_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.073682, p-value : 0.304140
#
# True
# end_1_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.3551923
#
# 0	end_1_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.003177, p-value : 0.955230
#
# True
# end_1_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 1 , pvalue : 0.2087827
#
# 0	end_1_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.779800, p-value : 0.380614
#
# True
# end_1_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0024195
#
# 0	end_1_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 2.970928, p-value : 0.089757
#
# True
# end_1_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0100554
#
# 0	end_1_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_1_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	end_1_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.327369, p-value : 0.569281
#
# True
# end_1_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.5996633
#
# 0	end_1_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 3.451967, p-value : 0.067926
#
# True
# end_1_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0136817
#
# 0	end_3_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.727614, p-value : 0.396941
#
# True
# end_3_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 1 , pvalue : 0.1726240
#
# 0	end_3_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.183204, p-value : 0.670118
#
# True
# end_3_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 1 , pvalue : 0.1276979
#
# 0	end_3_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.199343, p-value : 0.656808
#
# True
# end_3_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 1 , pvalue : 0.0726076
#
# 0	end_3_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.700726, p-value : 0.197014
#
# True
# end_3_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0066637
#
# 0	end_3_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 4.460890, p-value : 0.038715
#
# False
# end_3_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0251609
#
# 0	end_3_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.327369, p-value : 0.569281
#
# True
# end_3_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 0 , pvalue : 0.5996633
#
# 0	end_3_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_3_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	end_3_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.291203, p-value : 0.260200
#
# True
# end_3_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0444596
#
# 0	end_6_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 4.064427, p-value : 0.048134
#
# False
# end_6_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0015595
#
# 0	end_6_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.478436, p-value : 0.491714
#
# True
# end_6_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0002260
#
# 0	end_6_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 2.187252, p-value : 0.144220
#
# True
# end_6_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0002429
#
# 0	end_6_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 4.948572, p-value : 0.029762
#
# False
# end_6_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -1 , pvalue : 0.1515384
#
# 0	end_6_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 9.139723, p-value : 0.003634
#
# False
# end_6_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -1 , pvalue : 0.3208342
#
# 0	end_6_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 3.451967, p-value : 0.067926
#
# True
# end_6_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0136817
#
# 0	end_6_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.291203, p-value : 0.260200
#
# True
# end_6_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0444596
#
# 0	end_6_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_1_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_1_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_1_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.277099, p-value : 0.262792
#
# True
# 0_1_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.8597867
#
# 0	0_1_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.543164, p-value : 0.463904
#
# True
# 0_1_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.8832174
#
# 0	0_1_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.001805, p-value : 0.966250
#
# True
# 0_1_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -5 , pvalue : 0.0000001
#
# 0	0_1_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.621947, p-value : 0.207575
#
# True
# 0_1_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -4 , pvalue : 0.0000076
#
# 0	0_1_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.814549, p-value : 0.182867
#
# True
# 0_1_모델 평가.csv end_1_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0046173
#
# 0	0_1_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.212802, p-value : 0.275035
#
# True
# 0_1_모델 평가.csv end_3_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0066936
#
# 0	0_1_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 5.051032, p-value : 0.028179
#
# False
# 0_1_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -4 , pvalue : 0.0000540
#
# 0	0_3_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.277099, p-value : 0.262792
#
# True
# 0_3_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 0 , pvalue : 0.8597867
#
# 0	0_3_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_3_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_3_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.171915, p-value : 0.679847
#
# True
# 0_3_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.7188672
#
# 0	0_3_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.989891, p-value : 0.323636
#
# True
# 0_3_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -6 , pvalue : 0.0000000
#
# 0	0_3_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 6.115179, p-value : 0.016158
#
# False
# 0_3_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -5 , pvalue : 0.0000036
#
# 0	0_3_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.039039, p-value : 0.844018
#
# True
# 0_3_모델 평가.csv end_1_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0023358
#
# 0	0_3_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.002694, p-value : 0.958771
#
# True
# 0_3_모델 평가.csv end_3_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0037951
#
# 0	0_3_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.343778, p-value : 0.250814
#
# True
# 0_3_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -4 , pvalue : 0.0000055
#
# 0	0_6_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.543164, p-value : 0.463904
#
# True
# 0_6_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 0 , pvalue : 0.8832174
#
# 0	0_6_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.171915, p-value : 0.679847
#
# True
# 0_6_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.7188672
#
# 0	0_6_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_6_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_6_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.446495, p-value : 0.506484
#
# True
# 0_6_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -6 , pvalue : 0.0000000
#
# 0	0_6_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 4.290334, p-value : 0.042498
#
# False
# 0_6_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -5 , pvalue : 0.0000019
#
# 0	0_6_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.392240, p-value : 0.533423
#
# True
# 0_6_모델 평가.csv end_1_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0011587
#
# 0	0_6_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.138216, p-value : 0.711328
#
# True
# 0_6_모델 평가.csv end_3_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0018936
#
# 0	0_6_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 2.534321, p-value : 0.116481
#
# True
# 0_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -5 , pvalue : 0.0000032
#
# 0	1_3_모델 평가.csv & 0_1_모델 평가.csv	Measure :
# LeveneResult -- stat : 0.001805, p-value : 0.966250
#
# True
# 1_3_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 5 , pvalue : 0.0000001
#
# 0	1_3_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.989891, p-value : 0.323636
#
# True
# 1_3_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 6 , pvalue : 0.0000000
#
# 0	1_3_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.446495, p-value : 0.506484
#
# True
# 1_3_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 6 , pvalue : 0.0000000
#
# 0	1_3_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 1_3_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	1_3_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.144937, p-value : 0.288760
#
# True
# 1_3_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : 0 , pvalue : 0.4090411
#
# 0	1_3_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.357367, p-value : 0.248457
#
# True
# 1_3_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0002092
#
# 0	1_3_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.935452, p-value : 0.337208
#
# True
# 1_3_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0001982
#
# 0	1_3_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 3.495293, p-value : 0.066268
#
# True
# 1_3_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0036348
#
# 0	3_6_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.621947, p-value : 0.207575
#
# True
# 3_6_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 4 , pvalue : 0.0000076
#
# 0	3_6_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 6.115179, p-value : 0.016158
#
# False
# 3_6_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 5 , pvalue : 0.0000036
#
# 0	3_6_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 4.290334, p-value : 0.042498
#
# False
# 3_6_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 5 , pvalue : 0.0000019
#
# 0	3_6_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.144937, p-value : 0.288760
#
# True
# 3_6_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.4090411
#
# 0	3_6_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 3_6_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	3_6_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 7.423964, p-value : 0.008353
#
# False
# 3_6_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0070759
#
# 0	3_6_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 6.064355, p-value : 0.016586
#
# False
# 3_6_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0064048
#
# 0	3_6_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 13.399485, p-value : 0.000522
#
# False
# 3_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 1 , pvalue : 0.0695038
#
# 0	end_1_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.814549, p-value : 0.182867
#
# True
# end_1_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0046173
#
# 0	end_1_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.039039, p-value : 0.844018
#
# True
# end_1_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0023358
#
# 0	end_1_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.392240, p-value : 0.533423
#
# True
# end_1_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0011587
#
# 0	end_1_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.357367, p-value : 0.248457
#
# True
# end_1_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0002092
#
# 0	end_1_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 7.423964, p-value : 0.008353
#
# False
# end_1_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0070759
#
# 0	end_1_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_1_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	end_1_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.065816, p-value : 0.798378
#
# True
# end_1_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 0 , pvalue : 0.9240413
#
# 0	end_1_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.019701, p-value : 0.316515
#
# True
# end_1_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -1 , pvalue : 0.1294105
#
# 0	end_3_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.212802, p-value : 0.275035
#
# True
# end_3_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 2 , pvalue : 0.0066936
#
# 0	end_3_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.002694, p-value : 0.958771
#
# True
# end_3_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0037951
#
# 0	end_3_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.138216, p-value : 0.711328
#
# True
# end_3_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 3 , pvalue : 0.0018936
#
# 0	end_3_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.935452, p-value : 0.337208
#
# True
# end_3_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0001982
#
# 0	end_3_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 6.064355, p-value : 0.016586
#
# False
# end_3_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -2 , pvalue : 0.0064048
#
# 0	end_3_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.065816, p-value : 0.798378
#
# True
# end_3_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 0 , pvalue : 0.9240413
#
# 0	end_3_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_3_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	end_3_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.564095, p-value : 0.215766
#
# True
# end_3_모델 평가.csv end_6_모델 평가.csv
#
# statistic : -1 , pvalue : 0.1153851
#
# 0	end_6_모델 평가.csv & 0_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 5.051032, p-value : 0.028179
#
# False
# end_6_모델 평가.csv 0_1_모델 평가.csv
#
# statistic : 4 , pvalue : 0.0000540
#
# 0	end_6_모델 평가.csv & 0_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.343778, p-value : 0.250814
#
# True
# end_6_모델 평가.csv 0_3_모델 평가.csv
#
# statistic : 4 , pvalue : 0.0000055
#
# 0	end_6_모델 평가.csv & 0_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 2.534321, p-value : 0.116481
#
# True
# end_6_모델 평가.csv 0_6_모델 평가.csv
#
# statistic : 5 , pvalue : 0.0000032
#
# 0	end_6_모델 평가.csv & 1_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 3.495293, p-value : 0.066268
#
# True
# end_6_모델 평가.csv 1_3_모델 평가.csv
#
# statistic : -3 , pvalue : 0.0036348
#
# 0	end_6_모델 평가.csv & 3_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 13.399485, p-value : 0.000522
#
# False
# end_6_모델 평가.csv 3_6_모델 평가.csv
#
# statistic : -1 , pvalue : 0.0695038
#
# 0	end_6_모델 평가.csv & end_1_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.019701, p-value : 0.316515
#
# True
# end_6_모델 평가.csv end_1_모델 평가.csv
#
# statistic : 1 , pvalue : 0.1294105
#
# 0	end_6_모델 평가.csv & end_3_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 1.564095, p-value : 0.215766
#
# True
# end_6_모델 평가.csv end_3_모델 평가.csv
#
# statistic : 1 , pvalue : 0.1153851
#
# 0	end_6_모델 평가.csv & end_6_모델 평가.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_6_모델 평가.csv end_6_모델 평가.csv
#
# statistic : 0 , pvalue : 1.0000000

# %%
path_dir = 'Result/랜덤포레스트/종속변수 수익률' 
file_list = os.listdir(path_dir)
print(file_list)
# Out:
# ['0_1_수익률.csv', '0_3_수익률.csv', '0_6_수익률.csv', '1_3_수익률.csv', '3_6_수익률.csv', 'end_1_수익률.csv', 'end_3_수익률.csv', 'end_6_수익률.csv']

# %%
indexes = ['buy_sell수익률','buy수익률', 'all수익률']
for index in indexes:
    Total_Stat = np.array([])
    for left in file_list:
        for right in file_list:   
            left_df = pd.read_csv(path_dir + "//" + left, encoding = 'cp949',index_col = 0)
            right_df = pd.read_csv(path_dir + "//" + right, encoding = 'cp949',index_col = 0)
            left_value = left_df.loc[index,:].drop('mean')
            right_value = right_df.loc[index,:].drop('mean')
            stat, pval = Ttest(left_value,right_value,leftstr = left , rightstr = right)

            left_mean = np.mean(left_value)
            right_mean = np.mean(right_value)

            star = sign(pval)

            Statstr = str(np.round(left_mean - right_mean,2)) + "(" + str(np.round(stat,2)) + star +  ")"
            Total_Stat = np.append(Total_Stat, Statstr)
            statistics = np.append(statistics, stat)
            pvalues = np.append(pvalues, pval)


    Total_df = pd.DataFrame(Total_Stat.reshape(8,8), index = file_list, columns = file_list)

    Total_df.to_csv(path_dir+ '//' + index + '.csv', encoding = 'euc-kr')
# Out:
# 0	0_1_수익률.csv & 0_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_1_수익률.csv 0_1_수익률.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_1_수익률.csv & 0_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.181932, p-value : 0.671196
#
# True
# 0_1_수익률.csv 0_3_수익률.csv
#
# statistic : 0 , pvalue : 0.5310922
#
# 0	0_1_수익률.csv & 0_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.401738, p-value : 0.528524
#
# True
# 0_1_수익률.csv 0_6_수익률.csv
#
# statistic : 0 , pvalue : 0.6010645
#
# 0	0_1_수익률.csv & 1_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 32.233091, p-value : 0.000000
#
# False
# 0_1_수익률.csv 1_3_수익률.csv
#
# statistic : 5 , pvalue : 0.0000032
#
# 0	0_1_수익률.csv & 3_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 26.138725, p-value : 0.000003
#
# False
# 0_1_수익률.csv 3_6_수익률.csv
#
# statistic : 4 , pvalue : 0.0001718
#
# 0	0_1_수익률.csv & end_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 18.770899, p-value : 0.000055
#
# False
# 0_1_수익률.csv end_1_수익률.csv
#
# statistic : 5 , pvalue : 0.0000046
#
# 0	0_1_수익률.csv & end_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 17.127699, p-value : 0.000107
#
# False
# 0_1_수익률.csv end_3_수익률.csv
#
# statistic : 5 , pvalue : 0.0000066
#
# 0	0_1_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 12.708451, p-value : 0.000708
#
# False
# 0_1_수익률.csv end_6_수익률.csv
#
# statistic : 3 , pvalue : 0.0002575
#
# 0	0_3_수익률.csv & 0_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.181932, p-value : 0.671196
#
# True
# 0_3_수익률.csv 0_1_수익률.csv
#
# statistic : 0 , pvalue : 0.5310922
#
# 0	0_3_수익률.csv & 0_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_3_수익률.csv 0_3_수익률.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_3_수익률.csv & 0_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.075827, p-value : 0.783950
#
# True
# 0_3_수익률.csv 0_6_수익률.csv
#
# statistic : -1 , pvalue : 0.2811331
#
# 0	0_3_수익률.csv & 1_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 43.662436, p-value : 0.000000
#
# False
# 0_3_수익률.csv 1_3_수익률.csv
#
# statistic : 4 , pvalue : 0.0000937
#
# 0	0_3_수익률.csv & 3_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 35.902208, p-value : 0.000000
#
# False
# 0_3_수익률.csv 3_6_수익률.csv
#
# statistic : 3 , pvalue : 0.0032603
#
# 0	0_3_수익률.csv & end_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 26.763184, p-value : 0.000003
#
# False
# 0_3_수익률.csv end_1_수익률.csv
#
# statistic : 4 , pvalue : 0.0001313
#
# 0	0_3_수익률.csv & end_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 24.453708, p-value : 0.000006
#
# False
# 0_3_수익률.csv end_3_수익률.csv
#
# statistic : 4 , pvalue : 0.0001825
#
# 0	0_3_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 18.436635, p-value : 0.000063
#
# False
# 0_3_수익률.csv end_6_수익률.csv
#
# statistic : 3 , pvalue : 0.0042711
#
# 0	0_6_수익률.csv & 0_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.401738, p-value : 0.528524
#
# True
# 0_6_수익률.csv 0_1_수익률.csv
#
# statistic : 0 , pvalue : 0.6010645
#
# 0	0_6_수익률.csv & 0_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.075827, p-value : 0.783950
#
# True
# 0_6_수익률.csv 0_3_수익률.csv
#
# statistic : 1 , pvalue : 0.2811331
#
# 0	0_6_수익률.csv & 0_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_6_수익률.csv 0_6_수익률.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_6_수익률.csv & 1_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 29.003947, p-value : 0.000001
#
# False
# 0_6_수익률.csv 1_3_수익률.csv
#
# statistic : 5 , pvalue : 0.0000067
#
# 0	0_6_수익률.csv & 3_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 24.407318, p-value : 0.000006
#
# False
# 0_6_수익률.csv 3_6_수익률.csv
#
# statistic : 4 , pvalue : 0.0001756
#
# 0	0_6_수익률.csv & end_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 18.509938, p-value : 0.000061
#
# False
# 0_6_수익률.csv end_1_수익률.csv
#
# statistic : 5 , pvalue : 0.0000085
#
# 0	0_6_수익률.csv & end_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 17.280874, p-value : 0.000101
#
# False
# 0_6_수익률.csv end_3_수익률.csv
#
# statistic : 5 , pvalue : 0.0000114
#
# 0	0_6_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 13.742700, p-value : 0.000449
#
# False
# 0_6_수익률.csv end_6_수익률.csv
#
# statistic : 4 , pvalue : 0.0002250
#
# 0	1_3_수익률.csv & 0_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 32.233091, p-value : 0.000000
#
# False
# 1_3_수익률.csv 0_1_수익률.csv
#
# statistic : -5 , pvalue : 0.0000032
#
# 0	1_3_수익률.csv & 0_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 43.662436, p-value : 0.000000
#
# False
# 1_3_수익률.csv 0_3_수익률.csv
#
# statistic : -4 , pvalue : 0.0000937
#
# 0	1_3_수익률.csv & 0_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 29.003947, p-value : 0.000001
#
# False
# 1_3_수익률.csv 0_6_수익률.csv
#
# statistic : -5 , pvalue : 0.0000067
#
# 0	1_3_수익률.csv & 1_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 1_3_수익률.csv 1_3_수익률.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	1_3_수익률.csv & 3_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 1.301689, p-value : 0.258293
#
# True
# 1_3_수익률.csv 3_6_수익률.csv
#
# statistic : -3 , pvalue : 0.0012574
#
# 0	1_3_수익률.csv & end_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 9.645514, p-value : 0.002861
#
# False
# 1_3_수익률.csv end_1_수익률.csv
#
# statistic : 0 , pvalue : 0.9414660
#
# 0	1_3_수익률.csv & end_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 9.238968, p-value : 0.003467
#
# False
# 1_3_수익률.csv end_3_수익률.csv
#
# statistic : 0 , pvalue : 0.7694708
#
# 0	1_3_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 10.766227, p-value : 0.001700
#
# False
# 1_3_수익률.csv end_6_수익률.csv
#
# statistic : -2 , pvalue : 0.0241285
#
# 0	3_6_수익률.csv & 0_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 26.138725, p-value : 0.000003
#
# False
# 3_6_수익률.csv 0_1_수익률.csv
#
# statistic : -4 , pvalue : 0.0001718
#
# 0	3_6_수익률.csv & 0_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 35.902208, p-value : 0.000000
#
# False
# 3_6_수익률.csv 0_3_수익률.csv
#
# statistic : -3 , pvalue : 0.0032603
#
# 0	3_6_수익률.csv & 0_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 24.407318, p-value : 0.000006
#
# False
# 3_6_수익률.csv 0_6_수익률.csv
#
# statistic : -4 , pvalue : 0.0001756
#
# 0	3_6_수익률.csv & 1_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 1.301689, p-value : 0.258293
#
# True
# 3_6_수익률.csv 1_3_수익률.csv
#
# statistic : 3 , pvalue : 0.0012574
#
# 0	3_6_수익률.csv & 3_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 3_6_수익률.csv 3_6_수익률.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	3_6_수익률.csv & end_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 3.230358, p-value : 0.077155
#
# True
# 3_6_수익률.csv end_1_수익률.csv
#
# statistic : 2 , pvalue : 0.0098751
#
# 0	3_6_수익률.csv & end_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 3.485874, p-value : 0.066624
#
# True
# 3_6_수익률.csv end_3_수익률.csv
#
# statistic : 2 , pvalue : 0.0208725
#
# 0	3_6_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 5.304391, p-value : 0.024639
#
# False
# 3_6_수익률.csv end_6_수익률.csv
#
# statistic : 0 , pvalue : 0.9381166
#
# 0	end_1_수익률.csv & 0_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 18.770899, p-value : 0.000055
#
# False
# end_1_수익률.csv 0_1_수익률.csv
#
# statistic : -5 , pvalue : 0.0000046
#
# 0	end_1_수익률.csv & 0_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 26.763184, p-value : 0.000003
#
# False
# end_1_수익률.csv 0_3_수익률.csv
#
# statistic : -4 , pvalue : 0.0001313
#
# 0	end_1_수익률.csv & 0_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 18.509938, p-value : 0.000061
#
# False
# end_1_수익률.csv 0_6_수익률.csv
#
# statistic : -5 , pvalue : 0.0000085
#
# 0	end_1_수익률.csv & 1_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 9.645514, p-value : 0.002861
#
# False
# end_1_수익률.csv 1_3_수익률.csv
#
# statistic : 0 , pvalue : 0.9414660
#
# 0	end_1_수익률.csv & 3_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 3.230358, p-value : 0.077155
#
# True
# end_1_수익률.csv 3_6_수익률.csv
#
# statistic : -2 , pvalue : 0.0098751
#
# 0	end_1_수익률.csv & end_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_1_수익률.csv end_1_수익률.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	end_1_수익률.csv & end_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.053569, p-value : 0.817728
#
# True
# end_1_수익률.csv end_3_수익률.csv
#
# statistic : 0 , pvalue : 0.8498493
#
# 0	end_1_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.864566, p-value : 0.356070
#
# True
# end_1_수익률.csv end_6_수익률.csv
#
# statistic : -2 , pvalue : 0.0481552
#
# 0	end_3_수익률.csv & 0_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 17.127699, p-value : 0.000107
#
# False
# end_3_수익률.csv 0_1_수익률.csv
#
# statistic : -5 , pvalue : 0.0000066
#
# 0	end_3_수익률.csv & 0_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 24.453708, p-value : 0.000006
#
# False
# end_3_수익률.csv 0_3_수익률.csv
#
# statistic : -4 , pvalue : 0.0001825
#
# 0	end_3_수익률.csv & 0_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 17.280874, p-value : 0.000101
#
# False
# end_3_수익률.csv 0_6_수익률.csv
#
# statistic : -5 , pvalue : 0.0000114
#
# 0	end_3_수익률.csv & 1_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 9.238968, p-value : 0.003467
#
# False
# end_3_수익률.csv 1_3_수익률.csv
#
# statistic : 0 , pvalue : 0.7694708
#
# 0	end_3_수익률.csv & 3_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 3.485874, p-value : 0.066624
#
# True
# end_3_수익률.csv 3_6_수익률.csv
#
# statistic : -2 , pvalue : 0.0208725
#
# 0	end_3_수익률.csv & end_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.053569, p-value : 0.817728
#
# True
# end_3_수익률.csv end_1_수익률.csv
#
# statistic : 0 , pvalue : 0.8498493
#
# 0	end_3_수익률.csv & end_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_3_수익률.csv end_3_수익률.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	end_3_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.481365, p-value : 0.490396
#
# True
# end_3_수익률.csv end_6_수익률.csv
#
# statistic : -1 , pvalue : 0.0748923
#
# 0	end_6_수익률.csv & 0_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 12.708451, p-value : 0.000708
#
# False
# end_6_수익률.csv 0_1_수익률.csv
#
# statistic : -3 , pvalue : 0.0002575
#
# 0	end_6_수익률.csv & 0_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 18.436635, p-value : 0.000063
#
# False
# end_6_수익률.csv 0_3_수익률.csv
#
# statistic : -3 , pvalue : 0.0042711
#
# 0	end_6_수익률.csv & 0_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 13.742700, p-value : 0.000449
#
# False
# end_6_수익률.csv 0_6_수익률.csv
#
# statistic : -4 , pvalue : 0.0002250
#
# 0	end_6_수익률.csv & 1_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 10.766227, p-value : 0.001700
#
# False
# end_6_수익률.csv 1_3_수익률.csv
#
# statistic : 2 , pvalue : 0.0241285
#
# 0	end_6_수익률.csv & 3_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 5.304391, p-value : 0.024639
#
# False
# end_6_수익률.csv 3_6_수익률.csv
#
# statistic : 0 , pvalue : 0.9381166
#
# 0	end_6_수익률.csv & end_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.864566, p-value : 0.356070
#
# True
# end_6_수익률.csv end_1_수익률.csv
#
# statistic : 2 , pvalue : 0.0481552
#
# 0	end_6_수익률.csv & end_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.481365, p-value : 0.490396
#
# True
# end_6_수익률.csv end_3_수익률.csv
#
# statistic : 1 , pvalue : 0.0748923
#
# 0	end_6_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_6_수익률.csv end_6_수익률.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_1_수익률.csv & 0_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_1_수익률.csv 0_1_수익률.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_1_수익률.csv & 0_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.006863, p-value : 0.934245
#
# True
# 0_1_수익률.csv 0_3_수익률.csv
#
# statistic : 0 , pvalue : 0.9552632
#
# 0	0_1_수익률.csv & 0_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 3.982443, p-value : 0.050375
#
# True
# 0_1_수익률.csv 0_6_수익률.csv
#
# statistic : -1 , pvalue : 0.2082293
# 0	0_1_수익률.csv & 1_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 22.027958, p-value : 0.000015
#
# False
# 0_1_수익률.csv 1_3_수익률.csv
#
# statistic : 8 , pvalue : 0.0000000
#
# 0	0_1_수익률.csv & 3_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 12.835457, p-value : 0.000669
#
# False
# 0_1_수익률.csv 3_6_수익률.csv
#
# statistic : 6 , pvalue : 0.0000000
#
# 0	0_1_수익률.csv & end_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 5.451170, p-value : 0.022808
#
# False
# 0_1_수익률.csv end_1_수익률.csv
#
# statistic : 8 , pvalue : 0.0000000
#
# 0	0_1_수익률.csv & end_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 5.581530, p-value : 0.021303
#
# False
# 0_1_수익률.csv end_3_수익률.csv
#
# statistic : 8 , pvalue : 0.0000000
#
# 0	0_1_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.010836, p-value : 0.917428
#
# True
# 0_1_수익률.csv end_6_수익률.csv
#
# statistic : 4 , pvalue : 0.0000216
#
# 0	0_3_수익률.csv & 0_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.006863, p-value : 0.934245
#
# True
# 0_3_수익률.csv 0_1_수익률.csv
#
# statistic : 0 , pvalue : 0.9552632
#
# 0	0_3_수익률.csv & 0_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_3_수익률.csv 0_3_수익률.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_3_수익률.csv & 0_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 3.518994, p-value : 0.065379
#
# True
# 0_3_수익률.csv 0_6_수익률.csv
#
# statistic : -1 , pvalue : 0.2261562
#
# 0	0_3_수익률.csv & 1_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 20.455920, p-value : 0.000028
#
# False
# 0_3_수익률.csv 1_3_수익률.csv
#
# statistic : 8 , pvalue : 0.0000000
#
# 0	0_3_수익률.csv & 3_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 12.309213, p-value : 0.000845
#
# False
# 0_3_수익률.csv 3_6_수익률.csv
#
# statistic : 6 , pvalue : 0.0000000
#
# 0	0_3_수익률.csv & end_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 5.415839, p-value : 0.023235
#
# False
# 0_3_수익률.csv end_1_수익률.csv
#
# statistic : 8 , pvalue : 0.0000000
#
# 0	0_3_수익률.csv & end_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 5.500075, p-value : 0.022231
#
# False
# 0_3_수익률.csv end_3_수익률.csv
#
# statistic : 8 , pvalue : 0.0000000
#
# 0	0_3_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.001336, p-value : 0.970960
#
# True
# 0_3_수익률.csv end_6_수익률.csv
#
# statistic : 4 , pvalue : 0.0000188
#
# 0	0_6_수익률.csv & 0_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 3.982443, p-value : 0.050375
#
# True
# 0_6_수익률.csv 0_1_수익률.csv
#
# statistic : 1 , pvalue : 0.2082293
#
# 0	0_6_수익률.csv & 0_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 3.518994, p-value : 0.065379
#
# True
# 0_6_수익률.csv 0_3_수익률.csv
#
# statistic : 1 , pvalue : 0.2261562
#
# 0	0_6_수익률.csv & 0_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_6_수익률.csv 0_6_수익률.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_6_수익률.csv & 1_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 35.003523, p-value : 0.000000
#
# False
# 0_6_수익률.csv 1_3_수익률.csv
#
# statistic : 7 , pvalue : 0.0000000
#
# 0	0_6_수익률.csv & 3_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 25.483161, p-value : 0.000004
#
# False
# 0_6_수익률.csv 3_6_수익률.csv
#
# statistic : 6 , pvalue : 0.0000001
#
# 0	0_6_수익률.csv & end_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 16.095080, p-value : 0.000165
#
# False
# 0_6_수익률.csv end_1_수익률.csv
#
# statistic : 8 , pvalue : 0.0000000
#
# 0	0_6_수익률.csv & end_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 16.712582, p-value : 0.000127
#
# False
# 0_6_수익률.csv end_3_수익률.csv
#
# statistic : 8 , pvalue : 0.0000000
#
# 0	0_6_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 2.436516, p-value : 0.123630
#
# True
# 0_6_수익률.csv end_6_수익률.csv
#
# statistic : 5 , pvalue : 0.0000038
#
# 0	1_3_수익률.csv & 0_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 22.027958, p-value : 0.000015
#
# False
# 1_3_수익률.csv 0_1_수익률.csv
#
# statistic : -8 , pvalue : 0.0000000
#
# 0	1_3_수익률.csv & 0_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 20.455920, p-value : 0.000028
#
# False
# 1_3_수익률.csv 0_3_수익률.csv
#
# statistic : -8 , pvalue : 0.0000000
#
# 0	1_3_수익률.csv & 0_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 35.003523, p-value : 0.000000
#
# False
# 1_3_수익률.csv 0_6_수익률.csv
#
# statistic : -7 , pvalue : 0.0000000
#
# 0	1_3_수익률.csv & 1_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 1_3_수익률.csv 1_3_수익률.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	1_3_수익률.csv & 3_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.815727, p-value : 0.369928
#
# True
# 1_3_수익률.csv 3_6_수익률.csv
#
# statistic : -2 , pvalue : 0.0124485
#
# 0	1_3_수익률.csv & end_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 4.920524, p-value : 0.030211
#
# False
# 1_3_수익률.csv end_1_수익률.csv
#
# statistic : 1 , pvalue : 0.0944442
#
# 0	1_3_수익률.csv & end_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 8.215170, p-value : 0.005667
#
# False
# 1_3_수익률.csv end_3_수익률.csv
#
# statistic : 1 , pvalue : 0.0733054
#
# 0	1_3_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 11.092205, p-value : 0.001464
#
# False
# 1_3_수익률.csv end_6_수익률.csv
#
# statistic : -1 , pvalue : 0.0733560
#
# 0	3_6_수익률.csv & 0_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 12.835457, p-value : 0.000669
#
# False
# 3_6_수익률.csv 0_1_수익률.csv
#
# statistic : -6 , pvalue : 0.0000000
#
# 0	3_6_수익률.csv & 0_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 12.309213, p-value : 0.000845
#
# False
# 3_6_수익률.csv 0_3_수익률.csv
#
# statistic : -6 , pvalue : 0.0000000
#
# 0	3_6_수익률.csv & 0_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 25.483161, p-value : 0.000004
#
# False
# 3_6_수익률.csv 0_6_수익률.csv
#
# statistic : -6 , pvalue : 0.0000001
#
# 0	3_6_수익률.csv & 1_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.815727, p-value : 0.369928
#
# True
# 3_6_수익률.csv 1_3_수익률.csv
#
# statistic : 2 , pvalue : 0.0124485
#
# 0	3_6_수익률.csv & 3_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 3_6_수익률.csv 3_6_수익률.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	3_6_수익률.csv & end_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 1.510048, p-value : 0.223776
#
# True
# 3_6_수익률.csv end_1_수익률.csv
#
# statistic : 3 , pvalue : 0.0008138
#
# 0	3_6_수익률.csv & end_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 2.488731, p-value : 0.119753
#
# True
# 3_6_수익률.csv end_3_수익률.csv
#
# statistic : 3 , pvalue : 0.0005481
#
# 0	3_6_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 7.368678, p-value : 0.008585
#
# False
# 3_6_수익률.csv end_6_수익률.csv
#
# statistic : 0 , pvalue : 0.6790248
#
# 0	end_1_수익률.csv & 0_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 5.451170, p-value : 0.022808
#
# False
# end_1_수익률.csv 0_1_수익률.csv
#
# statistic : -8 , pvalue : 0.0000000
#
# 0	end_1_수익률.csv & 0_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 5.415839, p-value : 0.023235
#
# False
# end_1_수익률.csv 0_3_수익률.csv
#
# statistic : -8 , pvalue : 0.0000000
#
# 0	end_1_수익률.csv & 0_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 16.095080, p-value : 0.000165
#
# False
# end_1_수익률.csv 0_6_수익률.csv
#
# statistic : -8 , pvalue : 0.0000000
#
# 0	end_1_수익률.csv & 1_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 4.920524, p-value : 0.030211
#
# False
# end_1_수익률.csv 1_3_수익률.csv
#
# statistic : -1 , pvalue : 0.0944442
#
# 0	end_1_수익률.csv & 3_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 1.510048, p-value : 0.223776
#
# True
# end_1_수익률.csv 3_6_수익률.csv
#
# statistic : -3 , pvalue : 0.0008138
#
# 0	end_1_수익률.csv & end_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_1_수익률.csv end_1_수익률.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	end_1_수익률.csv & end_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.031494, p-value : 0.859722
#
# True
# end_1_수익률.csv end_3_수익률.csv
#
# statistic : 0 , pvalue : 0.9322433
#
# 0	end_1_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 3.451940, p-value : 0.067927
#
# True
# end_1_수익률.csv end_6_수익률.csv
#
# statistic : -2 , pvalue : 0.0099415
#
# 0	end_3_수익률.csv & 0_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 5.581530, p-value : 0.021303
#
# False
# end_3_수익률.csv 0_1_수익률.csv
#
# statistic : -8 , pvalue : 0.0000000
#
# 0	end_3_수익률.csv & 0_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 5.500075, p-value : 0.022231
#
# False
# end_3_수익률.csv 0_3_수익률.csv
#
# statistic : -8 , pvalue : 0.0000000
#
# 0	end_3_수익률.csv & 0_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 16.712582, p-value : 0.000127
#
# False
# end_3_수익률.csv 0_6_수익률.csv
#
# statistic : -8 , pvalue : 0.0000000
#
# 0	end_3_수익률.csv & 1_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 8.215170, p-value : 0.005667
#
# False
# end_3_수익률.csv 1_3_수익률.csv
#
# statistic : -1 , pvalue : 0.0733054
#
# 0	end_3_수익률.csv & 3_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 2.488731, p-value : 0.119753
#
# True
# end_3_수익률.csv 3_6_수익률.csv
#
# statistic : -3 , pvalue : 0.0005481
#
# 0	end_3_수익률.csv & end_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.031494, p-value : 0.859722
#
# True
# end_3_수익률.csv end_1_수익률.csv
#
# statistic : 0 , pvalue : 0.9322433
#
# 0	end_3_수익률.csv & end_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_3_수익률.csv end_3_수익률.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	end_3_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 3.323124, p-value : 0.073134
#
# True
# end_3_수익률.csv end_6_수익률.csv
#
# statistic : -2 , pvalue : 0.0082578
#
# 0	end_6_수익률.csv & 0_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.010836, p-value : 0.917428
#
# True
# end_6_수익률.csv 0_1_수익률.csv
#
# statistic : -4 , pvalue : 0.0000216
#
# 0	end_6_수익률.csv & 0_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.001336, p-value : 0.970960
#
# True
# end_6_수익률.csv 0_3_수익률.csv
#
# statistic : -4 , pvalue : 0.0000188
#
# 0	end_6_수익률.csv & 0_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 2.436516, p-value : 0.123630
#
# True
# end_6_수익률.csv 0_6_수익률.csv
#
# statistic : -5 , pvalue : 0.0000038
# 0	end_6_수익률.csv & 1_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 11.092205, p-value : 0.001464
#
# False
# end_6_수익률.csv 1_3_수익률.csv
#
# statistic : 1 , pvalue : 0.0733560
#
# 0	end_6_수익률.csv & 3_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 7.368678, p-value : 0.008585
#
# False
# end_6_수익률.csv 3_6_수익률.csv
#
# statistic : 0 , pvalue : 0.6790248
#
# 0	end_6_수익률.csv & end_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 3.451940, p-value : 0.067927
#
# True
# end_6_수익률.csv end_1_수익률.csv
#
# statistic : 2 , pvalue : 0.0099415
#
# 0	end_6_수익률.csv & end_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 3.323124, p-value : 0.073134
#
# True
# end_6_수익률.csv end_3_수익률.csv
#
# statistic : 2 , pvalue : 0.0082578
#
# 0	end_6_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_6_수익률.csv end_6_수익률.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_1_수익률.csv & 0_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_1_수익률.csv 0_1_수익률.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_1_수익률.csv & 0_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.757377, p-value : 0.387508
#
# True
# 0_1_수익률.csv 0_3_수익률.csv
#
# statistic : 0 , pvalue : 0.8033709
#
# 0	0_1_수익률.csv & 0_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 2.917954, p-value : 0.092602
#
# True
# 0_1_수익률.csv 0_6_수익률.csv
#
# statistic : -1 , pvalue : 0.0839127
#
# 0	0_1_수익률.csv & 1_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 24.301795, p-value : 0.000006
#
# False
# 0_1_수익률.csv 1_3_수익률.csv
#
# statistic : 8 , pvalue : 0.0000000
#
# 0	0_1_수익률.csv & 3_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 19.665017, p-value : 0.000038
#
# False
# 0_1_수익률.csv 3_6_수익률.csv
#
# statistic : 7 , pvalue : 0.0000000
#
# 0	0_1_수익률.csv & end_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 19.493921, p-value : 0.000041
#
# False
# 0_1_수익률.csv end_1_수익률.csv
#
# statistic : 9 , pvalue : 0.0000000
#
# 0	0_1_수익률.csv & end_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 8.569149, p-value : 0.004775
#
# False
# 0_1_수익률.csv end_3_수익률.csv
#
# statistic : 8 , pvalue : 0.0000000
#
# 0	0_1_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 1.631159, p-value : 0.206305
#
# True
# 0_1_수익률.csv end_6_수익률.csv
#
# statistic : 5 , pvalue : 0.0000008
#
# 0	0_3_수익률.csv & 0_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.757377, p-value : 0.387508
#
# True
# 0_3_수익률.csv 0_1_수익률.csv
#
# statistic : 0 , pvalue : 0.8033709
#
# 0	0_3_수익률.csv & 0_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_3_수익률.csv 0_3_수익률.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_3_수익률.csv & 0_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 6.249237, p-value : 0.015085
#
# False
# 0_3_수익률.csv 0_6_수익률.csv
#
# statistic : -1 , pvalue : 0.1051742
#
# 0	0_3_수익률.csv & 1_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 19.764572, p-value : 0.000037
#
# False
# 0_3_수익률.csv 1_3_수익률.csv
#
# statistic : 10 , pvalue : 0.0000000
#
# 0	0_3_수익률.csv & 3_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 15.034536, p-value : 0.000258
#
# False
# 0_3_수익률.csv 3_6_수익률.csv
#
# statistic : 8 , pvalue : 0.0000000
#
# 0	0_3_수익률.csv & end_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 14.852690, p-value : 0.000278
#
# False
# 0_3_수익률.csv end_1_수익률.csv
#
# statistic : 11 , pvalue : 0.0000000
#
# 0	0_3_수익률.csv & end_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 4.888025, p-value : 0.030741
#
# False
# 0_3_수익률.csv end_3_수익률.csv
#
# statistic : 9 , pvalue : 0.0000000
#
# 0	0_3_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.346986, p-value : 0.557964
#
# True
# 0_3_수익률.csv end_6_수익률.csv
#
# statistic : 6 , pvalue : 0.0000000
#
# 0	0_6_수익률.csv & 0_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 2.917954, p-value : 0.092602
#
# True
# 0_6_수익률.csv 0_1_수익률.csv
#
# statistic : 1 , pvalue : 0.0839127
#
# 0	0_6_수익률.csv & 0_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 6.249237, p-value : 0.015085
#
# False
# 0_6_수익률.csv 0_3_수익률.csv
#
# statistic : 1 , pvalue : 0.1051742
#
# 0	0_6_수익률.csv & 0_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 0_6_수익률.csv 0_6_수익률.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	0_6_수익률.csv & 1_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 32.570489, p-value : 0.000000
#
# False
# 0_6_수익률.csv 1_3_수익률.csv
#
# statistic : 8 , pvalue : 0.0000000
#
# 0	0_6_수익률.csv & 3_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 28.702715, p-value : 0.000001
#
# False
# 0_6_수익률.csv 3_6_수익률.csv
#
# statistic : 7 , pvalue : 0.0000000
#
# 0	0_6_수익률.csv & end_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 28.454203, p-value : 0.000001
#
# False
# 0_6_수익률.csv end_1_수익률.csv
#
# statistic : 9 , pvalue : 0.0000000
#
# 0	0_6_수익률.csv & end_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 17.512385, p-value : 0.000092
#
# False
# 0_6_수익률.csv end_3_수익률.csv
#
# statistic : 8 , pvalue : 0.0000000
#
# 0	0_6_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 7.136410, p-value : 0.009636
#
# False
# 0_6_수익률.csv end_6_수익률.csv
#
# statistic : 6 , pvalue : 0.0000000
#
# 0	1_3_수익률.csv & 0_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 24.301795, p-value : 0.000006
#
# False
# 1_3_수익률.csv 0_1_수익률.csv
#
# statistic : -8 , pvalue : 0.0000000
#
# 0	1_3_수익률.csv & 0_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 19.764572, p-value : 0.000037
#
# False
# 1_3_수익률.csv 0_3_수익률.csv
#
# statistic : -10 , pvalue : 0.0000000
#
# 0	1_3_수익률.csv & 0_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 32.570489, p-value : 0.000000
#
# False
# 1_3_수익률.csv 0_6_수익률.csv
#
# statistic : -8 , pvalue : 0.0000000
#
# 0	1_3_수익률.csv & 1_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 1_3_수익률.csv 1_3_수익률.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	1_3_수익률.csv & 3_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.089865, p-value : 0.765352
#
# True
# 1_3_수익률.csv 3_6_수익률.csv
#
# statistic : -2 , pvalue : 0.0251913
#
# 0	1_3_수익률.csv & end_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.391274, p-value : 0.533926
#
# True
# 1_3_수익률.csv end_1_수익률.csv
#
# statistic : 2 , pvalue : 0.0136056
#
# 0	1_3_수익률.csv & end_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 4.599913, p-value : 0.035900
#
# False
# 1_3_수익률.csv end_3_수익률.csv
#
# statistic : 0 , pvalue : 0.4710957
#
# 0	1_3_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 6.463105, p-value : 0.013526
#
# False
# 1_3_수익률.csv end_6_수익률.csv
#
# statistic : -1 , pvalue : 0.0840594
#
# 0	3_6_수익률.csv & 0_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 19.665017, p-value : 0.000038
#
# False
# 3_6_수익률.csv 0_1_수익률.csv
#
# statistic : -7 , pvalue : 0.0000000
#
# 0	3_6_수익률.csv & 0_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 15.034536, p-value : 0.000258
#
# False
# 3_6_수익률.csv 0_3_수익률.csv
#
# statistic : -8 , pvalue : 0.0000000
#
# 0	3_6_수익률.csv & 0_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 28.702715, p-value : 0.000001
#
# False
# 3_6_수익률.csv 0_6_수익률.csv
#
# statistic : -7 , pvalue : 0.0000000
#
# 0	3_6_수익률.csv & 1_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.089865, p-value : 0.765352
#
# True
# 3_6_수익률.csv 1_3_수익률.csv
#
# statistic : 2 , pvalue : 0.0251913
#
# 0	3_6_수익률.csv & 3_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# 3_6_수익률.csv 3_6_수익률.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	3_6_수익률.csv & end_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.060546, p-value : 0.806448
#
# True
# 3_6_수익률.csv end_1_수익률.csv
#
# statistic : 4 , pvalue : 0.0000330
#
# 0	3_6_수익률.csv & end_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 2.840019, p-value : 0.096971
#
# True
# 3_6_수익률.csv end_3_수익률.csv
#
# statistic : 2 , pvalue : 0.0200282
#
# 0	3_6_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 5.170478, p-value : 0.026447
#
# False
# 3_6_수익률.csv end_6_수익률.csv
#
# statistic : 0 , pvalue : 0.6380401
#
# 0	end_1_수익률.csv & 0_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 19.493921, p-value : 0.000041
#
# False
# end_1_수익률.csv 0_1_수익률.csv
#
# statistic : -9 , pvalue : 0.0000000
#
# 0	end_1_수익률.csv & 0_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 14.852690, p-value : 0.000278
#
# False
# end_1_수익률.csv 0_3_수익률.csv
#
# statistic : -11 , pvalue : 0.0000000
#
# 0	end_1_수익률.csv & 0_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 28.454203, p-value : 0.000001
#
# False
# end_1_수익률.csv 0_6_수익률.csv
#
# statistic : -9 , pvalue : 0.0000000
#
# 0	end_1_수익률.csv & 1_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.391274, p-value : 0.533926
#
# True
# end_1_수익률.csv 1_3_수익률.csv
#
# statistic : -2 , pvalue : 0.0136056
#
# 0	end_1_수익률.csv & 3_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.060546, p-value : 0.806448
#
# True
# end_1_수익률.csv 3_6_수익률.csv
#
# statistic : -4 , pvalue : 0.0000330
#
# 0	end_1_수익률.csv & end_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_1_수익률.csv end_1_수익률.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	end_1_수익률.csv & end_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 2.447581, p-value : 0.122796
#
# True
# end_1_수익률.csv end_3_수익률.csv
#
# statistic : -1 , pvalue : 0.2383497
#
# 0	end_1_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 4.792126, p-value : 0.032364
#
# False
# end_1_수익률.csv end_6_수익률.csv
#
# statistic : -3 , pvalue : 0.0031804
#
# 0	end_3_수익률.csv & 0_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 8.569149, p-value : 0.004775
#
# False
# end_3_수익률.csv 0_1_수익률.csv
#
# statistic : -8 , pvalue : 0.0000000
#
# 0	end_3_수익률.csv & 0_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 4.888025, p-value : 0.030741
#
# False
# end_3_수익률.csv 0_3_수익률.csv
#
# statistic : -9 , pvalue : 0.0000000
#
# 0	end_3_수익률.csv & 0_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 17.512385, p-value : 0.000092
#
# False
# end_3_수익률.csv 0_6_수익률.csv
#
# statistic : -8 , pvalue : 0.0000000
#
# 0	end_3_수익률.csv & 1_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 4.599913, p-value : 0.035900
#
# False
# end_3_수익률.csv 1_3_수익률.csv
#
# statistic : 0 , pvalue : 0.4710957
#
# 0	end_3_수익률.csv & 3_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 2.840019, p-value : 0.096971
#
# True
# end_3_수익률.csv 3_6_수익률.csv
#
# statistic : -2 , pvalue : 0.0200282
#
# 0	end_3_수익률.csv & end_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 2.447581, p-value : 0.122796
#
# True
# end_3_수익률.csv end_1_수익률.csv
#
# statistic : 1 , pvalue : 0.2383497
#
# 0	end_3_수익률.csv & end_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_3_수익률.csv end_3_수익률.csv
#
# statistic : 0 , pvalue : 1.0000000
#
# 0	end_3_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 1.213592, p-value : 0.274880
#
# True
# end_3_수익률.csv end_6_수익률.csv
#
# statistic : -2 , pvalue : 0.0450339
#
# 0	end_6_수익률.csv & 0_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 1.631159, p-value : 0.206305
#
# True
# end_6_수익률.csv 0_1_수익률.csv
#
# statistic : -5 , pvalue : 0.0000008
#
# 0	end_6_수익률.csv & 0_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.346986, p-value : 0.557964
#
# True
# end_6_수익률.csv 0_3_수익률.csv
#
# statistic : -6 , pvalue : 0.0000000
#
# 0	end_6_수익률.csv & 0_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 7.136410, p-value : 0.009636
#
# False
# end_6_수익률.csv 0_6_수익률.csv
#
# statistic : -6 , pvalue : 0.0000000
#
# 0	end_6_수익률.csv & 1_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 6.463105, p-value : 0.013526
#
# False
# end_6_수익률.csv 1_3_수익률.csv
#
# statistic : 1 , pvalue : 0.0840594
#
# 0	end_6_수익률.csv & 3_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 5.170478, p-value : 0.026447
#
# False
# end_6_수익률.csv 3_6_수익률.csv
#
# statistic : 0 , pvalue : 0.6380401
#
# 0	end_6_수익률.csv & end_1_수익률.csv	Measure :
#
# LeveneResult -- stat : 4.792126, p-value : 0.032364
#
# False
# end_6_수익률.csv end_1_수익률.csv
#
# statistic : 3 , pvalue : 0.0031804
#
# 0	end_6_수익률.csv & end_3_수익률.csv	Measure :
#
# LeveneResult -- stat : 1.213592, p-value : 0.274880
#
# True
# end_6_수익률.csv end_3_수익률.csv
#
# statistic : 2 , pvalue : 0.0450339
#
# 0	end_6_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 1.000000
#
# True
# end_6_수익률.csv end_6_수익률.csv
#
# statistic : 0 , pvalue : 1.0000000

# %%
indexes = ['buy_sell수익률','buy수익률']
Total_Stat = np.array([])
for file in file_list:
    for index in indexes:
        
        df = pd.read_csv(path_dir + "//" + file, encoding = 'cp949',index_col = 0)
        left_value = df.loc[index,:].drop('mean').fillna(0)
        right_value = df.loc['all수익률',:].drop('mean').fillna(0)
        print(left_value)
        print(right_value)
        
        stat, pval = Ttest(left_value,right_value,leftstr = left , rightstr = right)

        left_mean = np.mean(left_value)
        right_mean = np.mean(right_value)

        star = sign(pval)

        Statstr = str(np.round(left_mean - right_mean,2)) + "(" + str(np.round(stat,2)) + star +  ")"
        Total_Stat = np.append(Total_Stat, Statstr)
        

Total_df = pd.DataFrame(Total_Stat.reshape(8,2), columns = indexes, index = file_list)

Total_df.to_csv(path_dir+ '//' + 'Ret.csv', encoding = 'euc-kr')
# Out:
# model_set_0    -0.269118
# model_set_1    -0.112042
# model_set_2     0.191958
# model_set_3     0.044822
# model_set_4     0.381327
# model_set_5     0.406423
# model_set_6     0.430767
# model_set_7     0.461195
# model_set_8     0.388095
# model_set_9     0.292819
# model_set_10    0.281675
# model_set_11    0.301206
# model_set_12    0.332942
# model_set_13    0.182298
# model_set_14    0.032292
# model_set_15    0.107449
# model_set_16   -0.057585
# model_set_17    0.006033
# model_set_18    0.134127
# model_set_19    0.205396
# model_set_20    0.126474
# model_set_21    0.240249
# model_set_22    0.138939
# model_set_23    0.147610
# model_set_24    0.123649
# model_set_25    0.095304
# model_set_26    0.106920
# model_set_27    0.127570
# model_set_28    0.033515
# model_set_29   -0.079740
# model_set_30    0.453914
# model_set_31    0.469218
# model_set_32    0.349435
# model_set_33    0.551039
# Name: buy_sell수익률, dtype: float64
# model_set_0     0.322682
# model_set_1     0.255484
# model_set_2     0.333938
# model_set_3     0.355410
# model_set_4     0.302705
# model_set_5     0.415107
# model_set_6     0.393396
# model_set_7     0.465738
# model_set_8     0.422596
# model_set_9     0.419229
# model_set_10    0.436708
# model_set_11    0.339181
# model_set_12    0.327297
# model_set_13    0.245523
# model_set_14    0.252993
# model_set_15    0.152411
# model_set_16    0.145769
# model_set_17    0.173877
# model_set_18    0.217067
# model_set_19    0.312831
# model_set_20    0.281894
# model_set_21    0.263739
# model_set_22    0.309060
# model_set_23    0.276587
# model_set_24    0.188610
# model_set_25    0.128893
# model_set_26    0.089077
# model_set_27    0.100428
# model_set_28    0.162668
# model_set_29    0.307665
# model_set_30    0.416894
# model_set_31    0.538526
# model_set_32    0.611981
# model_set_33    0.613520
# Name: all수익률, dtype: float64
# 0	end_6_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 4.397698, p-value : 0.039823
#
# False
# end_6_수익률.csv end_6_수익률.csv
#
# statistic : -2 , pvalue : 0.0049960
#
# model_set_0     0.311742
# model_set_1     0.424677
# model_set_2     0.488224
# model_set_3     0.612686
# model_set_4     0.411452
# model_set_5     0.426675
# model_set_6     0.435519
# model_set_7     0.461195
# model_set_8     0.414892
# model_set_9     0.354209
# model_set_10    0.524024
# model_set_11    0.301206
# model_set_12    0.337553
# model_set_13    0.218043
# model_set_14    0.188482
# model_set_15    0.187716
# model_set_16    0.061459
# model_set_17    0.178970
# model_set_18    0.286171
# model_set_19    0.319386
# model_set_20    0.254847
# model_set_21    0.358387
# model_set_22    0.299667
# model_set_23    0.274935
# model_set_24    0.242414
# model_set_25    0.198610
# model_set_26    0.147332
# model_set_27    0.193099
# model_set_28    0.085367
# model_set_29    0.161446
# model_set_30    0.531261
# model_set_31    0.494381
# model_set_32    0.690649
# model_set_33    0.610995
# Name: buy수익률, dtype: float64
# model_set_0     0.322682
# model_set_1     0.255484
# model_set_2     0.333938
# model_set_3     0.355410
# model_set_4     0.302705
# model_set_5     0.415107
# model_set_6     0.393396
# model_set_7     0.465738
# model_set_8     0.422596
# model_set_9     0.419229
# model_set_10    0.436708
# model_set_11    0.339181
# model_set_12    0.327297
# model_set_13    0.245523
# model_set_14    0.252993
# model_set_15    0.152411
# model_set_16    0.145769
# model_set_17    0.173877
# model_set_18    0.217067
# model_set_19    0.312831
# model_set_20    0.281894
# model_set_21    0.263739
# model_set_22    0.309060
# model_set_23    0.276587
# model_set_24    0.188610
# model_set_25    0.128893
# model_set_26    0.089077
# model_set_27    0.100428
# model_set_28    0.162668
# model_set_29    0.307665
# model_set_30    0.416894
# model_set_31    0.538526
# model_set_32    0.611981
# model_set_33    0.613520
# Name: all수익률, dtype: float64
# 0	end_6_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 1.271430, p-value : 0.263581
#
# True
# end_6_수익률.csv end_6_수익률.csv
#
# statistic : 0 , pvalue : 0.4512680
#
# model_set_0     0.023361
# model_set_1    -0.135146
# model_set_2    -0.339869
# model_set_3     0.126471
# model_set_4     0.140174
# model_set_5     0.431001
# model_set_6     0.567253
# model_set_7     0.541248
# model_set_8     0.406018
# model_set_9     0.453472
# model_set_10    0.368447
# model_set_11    0.292564
# model_set_12    0.263480
# model_set_13    0.207381
# model_set_14    0.130524
# model_set_15    0.183276
# model_set_16   -0.128520
# model_set_17   -0.127556
# model_set_18   -0.012305
# model_set_19    0.132918
# model_set_20    0.135330
# model_set_21    0.207583
# model_set_22    0.158591
# model_set_23    0.123502
# model_set_24    0.081690
# model_set_25   -0.013784
# model_set_26    0.017619
# model_set_27    0.199722
# model_set_28   -0.064177
# model_set_29    0.183370
# model_set_30    0.203531
# model_set_31    0.104980
# model_set_32    0.343795
# model_set_33    0.433999
# Name: buy_sell수익률, dtype: float64
# model_set_0     0.372412
# model_set_1     0.398758
# model_set_2     0.466532
# model_set_3     0.474508
# model_set_4     0.457155
# model_set_5     0.576488
# model_set_6     0.567253
# model_set_7     0.514802
# model_set_8     0.448837
# model_set_9     0.439307
# model_set_10    0.434289
# model_set_11    0.286077
# model_set_12    0.268924
# model_set_13    0.238774
# model_set_14    0.254310
# model_set_15    0.173828
# model_set_16    0.219187
# model_set_17    0.219889
# model_set_18    0.266925
# model_set_19    0.346872
# model_set_20    0.283542
# model_set_21    0.275847
# model_set_22    0.272233
# model_set_23    0.255377
# model_set_24    0.171877
# model_set_25    0.130206
# model_set_26    0.164372
# model_set_27    0.171197
# model_set_28    0.184083
# model_set_29    0.281437
# model_set_30    0.365391
# model_set_31    0.460041
# model_set_32    0.462576
# model_set_33    0.453515
# Name: all수익률, dtype: float64
# 0	end_6_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 2.959338, p-value : 0.090069
#
# True
# end_6_수익률.csv end_6_수익률.csv
#
# statistic : -4 , pvalue : 0.0001280
#
# model_set_0     0.322135
# model_set_1     0.350404
# model_set_2     0.277378
# model_set_3     0.488804
# model_set_4     0.476991
# model_set_5     0.601875
# model_set_6     0.567253
# model_set_7     0.566967
# model_set_8     0.478840
# model_set_9     0.505768
# model_set_10    0.469673
# model_set_11    0.292564
# model_set_12    0.274772
# model_set_13    0.213684
# model_set_14    0.223640
# model_set_15    0.183276
# model_set_16    0.285025
# model_set_17    0.195689
# model_set_18    0.344186
# model_set_19    0.353992
# model_set_20    0.227290
# model_set_21    0.275066
# model_set_22    0.231067
# model_set_23    0.238703
# model_set_24    0.198552
# model_set_25    0.086495
# model_set_26    0.175222
# model_set_27    0.410112
# model_set_28    0.130817
# model_set_29    0.336045
# model_set_30    0.422061
# model_set_31    0.467165
# model_set_32    0.458272
# model_set_33    0.459285
# Name: buy수익률, dtype: float64
# model_set_0     0.372412
# model_set_1     0.398758
# model_set_2     0.466532
# model_set_3     0.474508
# model_set_4     0.457155
# model_set_5     0.576488
# model_set_6     0.567253
# model_set_7     0.514802
# model_set_8     0.448837
# model_set_9     0.439307
# model_set_10    0.434289
# model_set_11    0.286077
# model_set_12    0.268924
# model_set_13    0.238774
# model_set_14    0.254310
# model_set_15    0.173828
# model_set_16    0.219187
# model_set_17    0.219889
# model_set_18    0.266925
# model_set_19    0.346872
# model_set_20    0.283542
# model_set_21    0.275847
# model_set_22    0.272233
# model_set_23    0.255377
# model_set_24    0.171877
# model_set_25    0.130206
# model_set_26    0.164372
# model_set_27    0.171197
# model_set_28    0.184083
# model_set_29    0.281437
# model_set_30    0.365391
# model_set_31    0.460041
# model_set_32    0.462576
# model_set_33    0.453515
# Name: all수익률, dtype: float64
# 0	end_6_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.140459, p-value : 0.709027
#
# True
# end_6_수익률.csv end_6_수익률.csv
#
# statistic : 0 , pvalue : 0.8312847
#
# model_set_0    -0.380922
# model_set_1     0.000000
# model_set_2     0.390386
# model_set_3     0.097639
# model_set_4     0.152082
# model_set_5     0.455363
# model_set_6     0.385692
# model_set_7     0.356899
# model_set_8     0.621523
# model_set_9     0.439955
# model_set_10    0.522343
# model_set_11    0.314243
# model_set_12    0.313916
# model_set_13    0.013601
# model_set_14    0.129903
# model_set_15    0.102966
# model_set_16    0.252990
# model_set_17    0.322865
# model_set_18    0.328171
# model_set_19    0.211454
# model_set_20    0.116972
# model_set_21    0.274624
# model_set_22    0.125908
# model_set_23    0.059828
# model_set_24    0.128716
# model_set_25   -0.000916
# model_set_26    0.039134
# model_set_27    0.100529
# model_set_28    0.018183
# model_set_29   -0.049633
# model_set_30    0.026789
# model_set_31    0.084696
# model_set_32    0.254480
# model_set_33   -0.508561
# Name: buy_sell수익률, dtype: float64
# model_set_0     0.375804
# model_set_1     0.464938
# model_set_2     0.509746
# model_set_3     0.516268
# model_set_4     0.591144
# model_set_5     0.804370
# model_set_6     0.799280
# model_set_7     0.709621
# model_set_8     0.612394
# model_set_9     0.580919
# model_set_10    0.566863
# model_set_11    0.341960
# model_set_12    0.315478
# model_set_13    0.269836
# model_set_14    0.274175
# model_set_15    0.151774
# model_set_16    0.237710
# model_set_17    0.257378
# model_set_18    0.319504
# model_set_19    0.389572
# model_set_20    0.339112
# model_set_21    0.356451
# model_set_22    0.276161
# model_set_23    0.234829
# model_set_24    0.131922
# model_set_25    0.130338
# model_set_26    0.174473
# model_set_27    0.145916
# model_set_28    0.238298
# model_set_29    0.316327
# model_set_30    0.483096
# model_set_31    0.610050
# model_set_32    0.616031
# model_set_33    0.613779
# Name: all수익률, dtype: float64
# 0	end_6_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.071981, p-value : 0.789310
#
# True
# end_6_수익률.csv end_6_수익률.csv
#
# statistic : -4 , pvalue : 0.0000189
#
# model_set_0     0.009478
# model_set_1     0.000000
# model_set_2     0.554114
# model_set_3     0.431704
# model_set_4     0.681312
# model_set_5     0.712472
# model_set_6     0.658501
# model_set_7     0.605320
# model_set_8     0.621523
# model_set_9     0.605015
# model_set_10    0.580023
# model_set_11    0.322313
# model_set_12    0.313916
# model_set_13    0.162720
# model_set_14    0.179455
# model_set_15    0.122464
# model_set_16    0.252990
# model_set_17    0.322865
# model_set_18    0.386500
# model_set_19    0.405947
# model_set_20    0.262719
# model_set_21    0.321705
# model_set_22    0.262667
# model_set_23    0.175645
# model_set_24    0.132440
# model_set_25    0.116013
# model_set_26    0.223521
# model_set_27    0.144208
# model_set_28    0.162619
# model_set_29    0.167559
# model_set_30    0.448980
# model_set_31    0.393989
# model_set_32    0.574010
# model_set_33    0.182226
# Name: buy수익률, dtype: float64
# model_set_0     0.375804
# model_set_1     0.464938
# model_set_2     0.509746
# model_set_3     0.516268
# model_set_4     0.591144
# model_set_5     0.804370
# model_set_6     0.799280
# model_set_7     0.709621
# model_set_8     0.612394
# model_set_9     0.580919
# model_set_10    0.566863
# model_set_11    0.341960
# model_set_12    0.315478
# model_set_13    0.269836
# model_set_14    0.274175
# model_set_15    0.151774
# model_set_16    0.237710
# model_set_17    0.257378
# model_set_18    0.319504
# model_set_19    0.389572
# model_set_20    0.339112
# model_set_21    0.356451
# model_set_22    0.276161
# model_set_23    0.234829
# model_set_24    0.131922
# model_set_25    0.130338
# model_set_26    0.174473
# model_set_27    0.145916
# model_set_28    0.238298
# model_set_29    0.316327
# model_set_30    0.483096
# model_set_31    0.610050
# model_set_32    0.616031
# model_set_33    0.613779
# Name: all수익률, dtype: float64
# 0	end_6_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.106508, p-value : 0.745188
#
# True
# end_6_수익률.csv end_6_수익률.csv
#
# statistic : -1 , pvalue : 0.1728047
#
# model_set_0     0.059285
# model_set_1     0.059695
# model_set_2     0.049190
# model_set_3     0.033449
# model_set_4     0.179204
# model_set_5     0.060667
# model_set_6     0.106517
# model_set_7     0.011722
# model_set_8     0.030097
# model_set_9     0.113952
# model_set_10    0.029072
# model_set_11    0.001389
# model_set_12   -0.002528
# model_set_13   -0.012550
# model_set_14   -0.015711
# model_set_15   -0.037736
# model_set_16   -0.005830
# model_set_17    0.030213
# model_set_18    0.011990
# model_set_19    0.082819
# model_set_20    0.116925
# model_set_21    0.056840
# model_set_22    0.059201
# model_set_23    0.029826
# model_set_24    0.007700
# model_set_25    0.000883
# model_set_26    0.014620
# model_set_27   -0.069539
# model_set_28   -0.034019
# model_set_29    0.001115
# model_set_30    0.009519
# model_set_31   -0.026447
# model_set_32   -0.068063
# model_set_33   -0.049439
# Name: buy_sell수익률, dtype: float64
# model_set_0     0.052394
# model_set_1     0.132236
# model_set_2     0.118429
# model_set_3     0.108547
# model_set_4     0.116536
# model_set_5     0.127129
# model_set_6     0.135289
# model_set_7     0.040319
# model_set_8     0.025275
# model_set_9     0.029036
# model_set_10    0.021347
# model_set_11   -0.015392
# model_set_12   -0.019102
# model_set_13    0.010198
# model_set_14    0.017707
# model_set_15    0.021406
# model_set_16    0.052348
# model_set_17    0.035018
# model_set_18    0.045741
# model_set_19    0.047616
# model_set_20    0.022319
# model_set_21    0.038460
# model_set_22    0.016880
# model_set_23    0.022571
# model_set_24    0.016247
# model_set_25    0.022049
# model_set_26    0.094762
# model_set_27    0.091801
# model_set_28    0.049994
# model_set_29    0.023845
# model_set_30    0.010220
# model_set_31    0.000109
# model_set_32   -0.072826
# model_set_33   -0.080481
# Name: all수익률, dtype: float64
# 0	end_6_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.141724, p-value : 0.707781
#
# True
# end_6_수익률.csv end_6_수익률.csv
#
# statistic : -1 , pvalue : 0.2361908
#
# model_set_0     0.138448
# model_set_1     0.112448
# model_set_2     0.096665
# model_set_3     0.047326
# model_set_4     0.221655
# model_set_5     0.121026
# model_set_6     0.171904
# model_set_7     0.043870
# model_set_8     0.056900
# model_set_9     0.165475
# model_set_10    0.070844
# model_set_11   -0.022760
# model_set_12   -0.021330
# model_set_13   -0.023415
# model_set_14   -0.019650
# model_set_15   -0.004495
# model_set_16    0.041237
# model_set_17    0.058646
# model_set_18    0.027426
# model_set_19    0.080362
# model_set_20    0.114537
# model_set_21    0.103697
# model_set_22    0.091696
# model_set_23    0.107561
# model_set_24    0.021300
# model_set_25   -0.007716
# model_set_26    0.099043
# model_set_27    0.037909
# model_set_28    0.017648
# model_set_29    0.015296
# model_set_30   -0.008831
# model_set_31   -0.036750
# model_set_32   -0.071480
# model_set_33   -0.066246
# Name: buy수익률, dtype: float64
# model_set_0     0.052394
# model_set_1     0.132236
# model_set_2     0.118429
# model_set_3     0.108547
# model_set_4     0.116536
# model_set_5     0.127129
# model_set_6     0.135289
# model_set_7     0.040319
# model_set_8     0.025275
# model_set_9     0.029036
# model_set_10    0.021347
# model_set_11   -0.015392
# model_set_12   -0.019102
# model_set_13    0.010198
# model_set_14    0.017707
# model_set_15    0.021406
# model_set_16    0.052348
# model_set_17    0.035018
# model_set_18    0.045741
# model_set_19    0.047616
# model_set_20    0.022319
# model_set_21    0.038460
# model_set_22    0.016880
# model_set_23    0.022571
# model_set_24    0.016247
# model_set_25    0.022049
# model_set_26    0.094762
# model_set_27    0.091801
# model_set_28    0.049994
# model_set_29    0.023845
# model_set_30    0.010220
# model_set_31    0.000109
# model_set_32   -0.072826
# model_set_33   -0.080481
# Name: all수익률, dtype: float64
# 0	end_6_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 4.236293, p-value : 0.043521
#
# False
# end_6_수익률.csv end_6_수익률.csv
#
# statistic : 0 , pvalue : 0.4101205
#
# model_set_0     0.002416
# model_set_1    -0.031836
# model_set_2    -0.035398
# model_set_3     0.098589
# model_set_4     0.020068
# model_set_5    -0.015410
# model_set_6    -0.228803
# model_set_7    -0.037749
# model_set_8    -0.313032
# model_set_9    -0.122007
# model_set_10    0.146902
# model_set_11    0.061526
# model_set_12    0.077164
# model_set_13    0.001285
# model_set_14    0.014746
# model_set_15    0.030145
# model_set_16    0.028864
# model_set_17    0.002368
# model_set_18    0.033174
# model_set_19    0.051720
# model_set_20    0.039750
# model_set_21    0.055970
# model_set_22    0.015782
# model_set_23    0.067463
# model_set_24    0.055951
# model_set_25   -0.012240
# model_set_26   -0.006514
# model_set_27    0.010123
# model_set_28   -0.046262
# model_set_29    0.025880
# model_set_30    0.150776
# model_set_31    0.115797
# model_set_32    0.141011
# model_set_33    0.046987
# Name: buy_sell수익률, dtype: float64
# model_set_0    -0.004527
# model_set_1     0.064490
# model_set_2     0.052628
# model_set_3     0.053302
# model_set_4     0.110703
# model_set_5     0.165549
# model_set_6     0.171509
# model_set_7     0.127830
# model_set_8     0.100349
# model_set_9     0.083592
# model_set_10    0.085840
# model_set_11    0.032587
# model_set_12    0.025826
# model_set_13    0.024353
# model_set_14    0.024101
# model_set_15    0.005566
# model_set_16    0.008116
# model_set_17    0.026050
# model_set_18    0.037282
# model_set_19    0.020336
# model_set_20    0.029218
# model_set_21    0.065147
# model_set_22    0.031085
# model_set_23    0.014464
# model_set_24   -0.008275
# model_set_25    0.036777
# model_set_26    0.041768
# model_set_27    0.004398
# model_set_28    0.045510
# model_set_29    0.036811
# model_set_30    0.111255
# model_set_31    0.115620
# model_set_32    0.123232
# model_set_33    0.130758
# Name: all수익률, dtype: float64
# 0	end_6_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 2.293450, p-value : 0.134695
#
# True
# end_6_수익률.csv end_6_수익률.csv
#
# statistic : -2 , pvalue : 0.0138372
#
# model_set_0     0.015247
# model_set_1     0.023382
# model_set_2     0.002375
# model_set_3     0.093923
# model_set_4    -0.074925
# model_set_5     0.410092
# model_set_6     0.067682
# model_set_7     0.165198
# model_set_8     0.000000
# model_set_9    -0.049881
# model_set_10    0.146902
# model_set_11    0.049201
# model_set_12    0.074981
# model_set_13    0.002571
# model_set_14    0.012290
# model_set_15    0.008001
# model_set_16    0.003895
# model_set_17    0.011308
# model_set_18    0.089675
# model_set_19    0.034791
# model_set_20    0.061667
# model_set_21    0.126507
# model_set_22    0.028198
# model_set_23    0.069201
# model_set_24    0.021796
# model_set_25    0.022055
# model_set_26    0.020360
# model_set_27   -0.024059
# model_set_28    0.052787
# model_set_29    0.089994
# model_set_30    0.209405
# model_set_31    0.119763
# model_set_32    0.192943
# model_set_33    0.076182
# Name: buy수익률, dtype: float64
# model_set_0    -0.004527
# model_set_1     0.064490
# model_set_2     0.052628
# model_set_3     0.053302
# model_set_4     0.110703
# model_set_5     0.165549
# model_set_6     0.171509
# model_set_7     0.127830
# model_set_8     0.100349
# model_set_9     0.083592
# model_set_10    0.085840
# model_set_11    0.032587
# model_set_12    0.025826
# model_set_13    0.024353
# model_set_14    0.024101
# model_set_15    0.005566
# model_set_16    0.008116
# model_set_17    0.026050
# model_set_18    0.037282
# model_set_19    0.020336
# model_set_20    0.029218
# model_set_21    0.065147
# model_set_22    0.031085
# model_set_23    0.014464
# model_set_24   -0.008275
# model_set_25    0.036777
# model_set_26    0.041768
# model_set_27    0.004398
# model_set_28    0.045510
# model_set_29    0.036811
# model_set_30    0.111255
# model_set_31    0.115620
# model_set_32    0.123232
# model_set_33    0.130758
# Name: all수익률, dtype: float64
# 0	end_6_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 2.682900, p-value : 0.106190
#
# True
# end_6_수익률.csv end_6_수익률.csv
#
# statistic : 0 , pvalue : 0.7871806
#
# model_set_0     0.014879
# model_set_1     0.065508
# model_set_2     0.019715
# model_set_3     0.045721
# model_set_4     0.084839
# model_set_5     0.021958
# model_set_6     0.046674
# model_set_7     0.057306
# model_set_8     0.013287
# model_set_9    -0.085270
# model_set_10    0.080154
# model_set_11    0.054185
# model_set_12    0.035693
# model_set_13    0.043449
# model_set_14   -0.044255
# model_set_15    0.037941
# model_set_16    0.020800
# model_set_17    0.007449
# model_set_18    0.001087
# model_set_19    0.065277
# model_set_20   -0.035351
# model_set_21   -0.044896
# model_set_22   -0.119074
# model_set_23    0.004799
# model_set_24   -0.000871
# model_set_25    0.022448
# model_set_26    0.042447
# model_set_27    0.146815
# model_set_28    0.023478
# model_set_29    0.044084
# model_set_30    0.041158
# model_set_31    0.072108
# model_set_32    0.091219
# model_set_33    0.013810
# Name: buy_sell수익률, dtype: float64
# model_set_0    -0.031978
# model_set_1    -0.030462
# model_set_2    -0.031026
# model_set_3    -0.012033
# model_set_4    -0.048549
# model_set_5     0.085861
# model_set_6     0.094446
# model_set_7     0.110794
# model_set_8     0.059404
# model_set_9     0.098068
# model_set_10    0.103416
# model_set_11    0.028318
# model_set_12    0.020424
# model_set_13    0.027209
# model_set_14    0.058814
# model_set_15   -0.006909
# model_set_16   -0.012695
# model_set_17   -0.010981
# model_set_18   -0.003535
# model_set_19   -0.024118
# model_set_20   -0.028156
# model_set_21   -0.047131
# model_set_22   -0.035984
# model_set_23   -0.056143
# model_set_24   -0.081835
# model_set_25   -0.087146
# model_set_26   -0.109732
# model_set_27   -0.125603
# model_set_28   -0.107573
# model_set_29   -0.057747
# model_set_30   -0.052151
# model_set_31   -0.036090
# model_set_32   -0.017920
# model_set_33   -0.007069
# Name: all수익률, dtype: float64
# 0	end_6_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 1.492124, p-value : 0.226232
#
# True
# end_6_수익률.csv end_6_수익률.csv
#
# statistic : 2 , pvalue : 0.0088439
#
# model_set_0     0.014879
# model_set_1     0.057374
# model_set_2    -0.054618
# model_set_3     0.050547
# model_set_4     0.038160
# model_set_5     0.027525
# model_set_6     0.034192
# model_set_7     0.065016
# model_set_8     0.017199
# model_set_9    -0.007771
# model_set_10    0.079044
# model_set_11    0.054291
# model_set_12    0.030340
# model_set_13    0.073800
# model_set_14    0.047510
# model_set_15    0.023573
# model_set_16    0.000000
# model_set_17    0.009499
# model_set_18   -0.003443
# model_set_19    0.050648
# model_set_20   -0.054758
# model_set_21   -0.087919
# model_set_22   -0.110434
# model_set_23   -0.049038
# model_set_24   -0.119335
# model_set_25   -0.108141
# model_set_26   -0.086763
# model_set_27    0.053404
# model_set_28   -0.117641
# model_set_29   -0.025501
# model_set_30    0.003300
# model_set_31   -0.233114
# model_set_32    0.122756
# model_set_33   -0.095851
# Name: buy수익률, dtype: float64
# model_set_0    -0.031978
# model_set_1    -0.030462
# model_set_2    -0.031026
# model_set_3    -0.012033
# model_set_4    -0.048549
# model_set_5     0.085861
# model_set_6     0.094446
# model_set_7     0.110794
# model_set_8     0.059404
# model_set_9     0.098068
# model_set_10    0.103416
# model_set_11    0.028318
# model_set_12    0.020424
# model_set_13    0.027209
# model_set_14    0.058814
# model_set_15   -0.006909
# model_set_16   -0.012695
# model_set_17   -0.010981
# model_set_18   -0.003535
# model_set_19   -0.024118
# model_set_20   -0.028156
# model_set_21   -0.047131
# model_set_22   -0.035984
# model_set_23   -0.056143
# model_set_24   -0.081835
# model_set_25   -0.087146
# model_set_26   -0.109732
# model_set_27   -0.125603
# model_set_28   -0.107573
# model_set_29   -0.057747
# model_set_30   -0.052151
# model_set_31   -0.036090
# model_set_32   -0.017920
# model_set_33   -0.007069
# Name: all수익률, dtype: float64
# 0	end_6_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.933689, p-value : 0.337434
#
# True
# end_6_수익률.csv end_6_수익률.csv
#
# statistic : 0 , pvalue : 0.8969439
#
# model_set_0    -0.118774
# model_set_1     0.002941
# model_set_2    -0.033409
# model_set_3     0.010343
# model_set_4     0.005555
# model_set_5     0.148834
# model_set_6     0.027196
# model_set_7     0.080363
# model_set_8     0.139122
# model_set_9    -0.003256
# model_set_10    0.134130
# model_set_11   -0.034486
# model_set_12    0.005194
# model_set_13   -0.034547
# model_set_14   -0.094227
# model_set_15   -0.029704
# model_set_16    0.019480
# model_set_17   -0.061753
# model_set_18   -0.008234
# model_set_19    0.014786
# model_set_20   -0.026327
# model_set_21   -0.074533
# model_set_22   -0.057555
# model_set_23   -0.092657
# model_set_24   -0.017120
# model_set_25   -0.013483
# model_set_26    0.070397
# model_set_27    0.050522
# model_set_28    0.013350
# model_set_29    0.050139
# model_set_30    0.068727
# model_set_31    0.069458
# model_set_32   -0.005092
# model_set_33    0.132203
# Name: buy_sell수익률, dtype: float64
# model_set_0     0.015030
# model_set_1     0.099703
# model_set_2     0.090865
# model_set_3     0.100255
# model_set_4     0.098564
# model_set_5     0.239958
# model_set_6     0.257767
# model_set_7     0.177111
# model_set_8     0.102761
# model_set_9     0.137138
# model_set_10    0.121356
# model_set_11    0.002094
# model_set_12   -0.009358
# model_set_13    0.028628
# model_set_14    0.067687
# model_set_15    0.007911
# model_set_16    0.035564
# model_set_17    0.019561
# model_set_18    0.039788
# model_set_19    0.016134
# model_set_20   -0.013623
# model_set_21   -0.022984
# model_set_22   -0.033814
# model_set_23   -0.043987
# model_set_24   -0.078658
# model_set_25   -0.068179
# model_set_26   -0.030460
# model_set_27   -0.046543
# model_set_28   -0.069761
# model_set_29   -0.049828
# model_set_30   -0.060840
# model_set_31   -0.066933
# model_set_32   -0.103761
# model_set_33   -0.099842
# Name: all수익률, dtype: float64
# 0	end_6_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 2.689298, p-value : 0.105782
#
# True
# end_6_수익률.csv end_6_수익률.csv
#
# statistic : 0 , pvalue : 0.4360692
#
# model_set_0     0.000000
# model_set_1     0.090404
# model_set_2     0.065648
# model_set_3    -0.057143
# model_set_4     0.018063
# model_set_5     0.259148
# model_set_6     0.239265
# model_set_7     0.162179
# model_set_8     0.134079
# model_set_9     0.075155
# model_set_10    0.165554
# model_set_11   -0.011376
# model_set_12    0.005194
# model_set_13    0.001887
# model_set_14   -0.005467
# model_set_15   -0.016919
# model_set_16    0.145566
# model_set_17   -0.096492
# model_set_18    0.043894
# model_set_19    0.015372
# model_set_20   -0.040717
# model_set_21   -0.075073
# model_set_22   -0.065871
# model_set_23   -0.130489
# model_set_24   -0.051052
# model_set_25   -0.064237
# model_set_26    0.019519
# model_set_27    0.019997
# model_set_28   -0.109195
# model_set_29   -0.020248
# model_set_30   -0.017763
# model_set_31   -0.128629
# model_set_32   -0.080203
# model_set_33   -0.004779
# Name: buy수익률, dtype: float64
# model_set_0     0.015030
# model_set_1     0.099703
# model_set_2     0.090865
# model_set_3     0.100255
# model_set_4     0.098564
# model_set_5     0.239958
# model_set_6     0.257767
# model_set_7     0.177111
# model_set_8     0.102761
# model_set_9     0.137138
# model_set_10    0.121356
# model_set_11    0.002094
# model_set_12   -0.009358
# model_set_13    0.028628
# model_set_14    0.067687
# model_set_15    0.007911
# model_set_16    0.035564
# model_set_17    0.019561
# model_set_18    0.039788
# model_set_19    0.016134
# model_set_20   -0.013623
# model_set_21   -0.022984
# model_set_22   -0.033814
# model_set_23   -0.043987
# model_set_24   -0.078658
# model_set_25   -0.068179
# model_set_26   -0.030460
# model_set_27   -0.046543
# model_set_28   -0.069761
# model_set_29   -0.049828
# model_set_30   -0.060840
# model_set_31   -0.066933
# model_set_32   -0.103761
# model_set_33   -0.099842
# Name: all수익률, dtype: float64
# 0	end_6_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.000000, p-value : 0.999783
#
# True
# end_6_수익률.csv end_6_수익률.csv
#
# statistic : 0 , pvalue : 0.6343869
#
# model_set_0     0.039900
# model_set_1    -0.126620
# model_set_2     0.166951
# model_set_3    -0.089846
# model_set_4     0.149048
# model_set_5     0.222955
# model_set_6     0.034130
# model_set_7    -0.184434
# model_set_8     0.158804
# model_set_9    -0.125157
# model_set_10    0.078650
# model_set_11    0.041583
# model_set_12   -0.025226
# model_set_13   -0.071384
# model_set_14   -0.103307
# model_set_15   -0.039456
# model_set_16   -0.011970
# model_set_17   -0.131075
# model_set_18   -0.010878
# model_set_19    0.089809
# model_set_20    0.018898
# model_set_21   -0.054631
# model_set_22    0.007073
# model_set_23    0.110478
# model_set_24    0.089010
# model_set_25    0.018648
# model_set_26    0.102435
# model_set_27    0.000267
# model_set_28   -0.042004
# model_set_29    0.045582
# model_set_30    0.027132
# model_set_31    0.029563
# model_set_32    0.044753
# model_set_33   -0.040217
# Name: buy_sell수익률, dtype: float64
# model_set_0     0.014879
# model_set_1     0.151697
# model_set_2     0.125952
# model_set_3     0.135450
# model_set_4     0.211784
# model_set_5     0.442133
# model_set_6     0.466580
# model_set_7     0.353741
# model_set_8     0.246330
# model_set_9     0.256964
# model_set_10    0.234295
# model_set_11    0.041583
# model_set_12    0.021691
# model_set_13    0.052821
# model_set_14    0.088812
# model_set_15    0.000112
# model_set_16    0.045933
# model_set_17    0.040795
# model_set_18    0.078254
# model_set_19    0.051073
# model_set_20    0.031024
# model_set_21    0.052960
# model_set_22   -0.002675
# model_set_23   -0.024205
# model_set_24   -0.084160
# model_set_25   -0.054058
# model_set_26   -0.011438
# model_set_27   -0.068425
# model_set_28   -0.042968
# model_set_29   -0.034358
# model_set_30    0.015272
# model_set_31    0.029931
# model_set_32   -0.004299
# model_set_33    0.005086
# Name: all수익률, dtype: float64
# 0	end_6_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 1.013956, p-value : 0.317634
#
# True
# end_6_수익률.csv end_6_수익률.csv
#
# statistic : -2 , pvalue : 0.0143348
#
# model_set_0     0.072595
# model_set_1    -0.052864
# model_set_2     0.218969
# model_set_3     0.002841
# model_set_4     0.322997
# model_set_5     0.412355
# model_set_6     0.384024
# model_set_7     0.131525
# model_set_8     0.332818
# model_set_9     0.178674
# model_set_10    0.324808
# model_set_11    0.041583
# model_set_12   -0.003416
# model_set_13   -0.023420
# model_set_14    0.000000
# model_set_15   -0.031956
# model_set_16    0.016300
# model_set_17   -0.069097
# model_set_18    0.123394
# model_set_19    0.128894
# model_set_20    0.019321
# model_set_21   -0.001406
# model_set_22   -0.016488
# model_set_23    0.068004
# model_set_24    0.017181
# model_set_25   -0.049907
# model_set_26    0.112441
# model_set_27   -0.142300
# model_set_28   -0.188192
# model_set_29    0.014020
# model_set_30    0.055877
# model_set_31    0.093318
# model_set_32    0.108056
# model_set_33   -0.080733
# Name: buy수익률, dtype: float64
# model_set_0     0.014879
# model_set_1     0.151697
# model_set_2     0.125952
# model_set_3     0.135450
# model_set_4     0.211784
# model_set_5     0.442133
# model_set_6     0.466580
# model_set_7     0.353741
# model_set_8     0.246330
# model_set_9     0.256964
# model_set_10    0.234295
# model_set_11    0.041583
# model_set_12    0.021691
# model_set_13    0.052821
# model_set_14    0.088812
# model_set_15    0.000112
# model_set_16    0.045933
# model_set_17    0.040795
# model_set_18    0.078254
# model_set_19    0.051073
# model_set_20    0.031024
# model_set_21    0.052960
# model_set_22   -0.002675
# model_set_23   -0.024205
# model_set_24   -0.084160
# model_set_25   -0.054058
# model_set_26   -0.011438
# model_set_27   -0.068425
# model_set_28   -0.042968
# model_set_29   -0.034358
# model_set_30    0.015272
# model_set_31    0.029931
# model_set_32   -0.004299
# model_set_33    0.005086
# Name: all수익률, dtype: float64
# 0	end_6_수익률.csv & end_6_수익률.csv	Measure :
#
# LeveneResult -- stat : 0.316292, p-value : 0.575750
#
# True
# end_6_수익률.csv end_6_수익률.csv
#
# statistic : 0 , pvalue : 0.7671516

# %%
pd.DataFrame(Total_Stat.reshape(8,8))
# Out:
#                                             0  \
# 0                                    0.0(0.0)
# 1    0.010791006569172978(1.2307739411138343)
# 2    0.009636617085292287(0.9886032508940178)
# 3  0.08740641545178351(10.673787529438743***)
# 4   0.07812182827731029(7.963908622840538***)
# 5     0.043181035123114(4.507254772107314***)
# 6   0.019623804476501583(2.149010723209109**)
# 7    0.009243238396958398(1.0121738120414685)
#
#                                               1  \
# 0    -0.010791006569172978(-1.2307739411138343)
# 1                                      0.0(0.0)
# 2  -0.0011543894838806912(-0.14032345663910045)
# 3    0.07661540888261054(12.156968845267894***)
# 4     0.06733082170813731(8.112405983114682***)
# 5     0.03239002855394102(4.034827004389541***)
# 6      0.008832797907328604(1.1798594071764854)
# 7  -0.0015477681722145809(-0.20672905884918047)
#
#                                                2  \
# 0     -0.009636617085292287(-0.9886032508940178)
# 1     0.0011543894838806912(0.14032345663910045)
# 2                                       0.0(0.0)
# 3     0.07776979836649123(10.223715670741734***)
# 4        0.068485211192018(7.341052601698767***)
# 5     0.03354441803782171(3.6911384352553793***)
# 6       0.009987187391209296(1.1594924587268494)
# 7  -0.00039337868833388967(-0.04566759046834486)
#
#                                               3  \
# 0  -0.08740641545178351(-10.673787529438743***)
# 1  -0.07661540888261054(-12.156968845267894***)
# 2  -0.07776979836649123(-10.223715670741734***)
# 3                                      0.0(0.0)
# 4     -0.009284587174473224(-1.208017634982015)
# 5   -0.04422538032866952(-5.983588827655985***)
# 6   -0.06778261097528193(-9.969014221960535***)
# 7  -0.07816317705482512(-11.494552279659166***)
#
#                                               4  \
# 0   -0.07812182827731029(-7.963908622840538***)
# 1   -0.06733082170813731(-8.112405983114682***)
# 2     -0.068485211192018(-7.341052601698767***)
# 3       0.009284587174473224(1.208017634982015)
# 4                                      0.0(0.0)
# 5  -0.03494079315419629(-3.8169753690540396***)
# 6  -0.05849802380080871(-6.7368732605803014***)
# 7  -0.06887858988035189(-7.9318484890559136***)
#
#                                                5  \
# 0      -0.043181035123114(-4.507254772107314***)
# 1    -0.03239002855394102(-4.034827004389541***)
# 2   -0.03354441803782171(-3.6911384352553793***)
# 3      0.04422538032866952(5.983588827655985***)
# 4     0.03494079315419629(3.8169753690540396***)
# 5                                       0.0(0.0)
# 6  -0.023557230646612415(-2.7965962085031517***)
# 7     -0.0339377967261556(-4.028658575140418***)
#
#                                              6  \
# 0  -0.019623804476501583(-2.149010723209109**)
# 1   -0.008832797907328604(-1.1798594071764854)
# 2   -0.009987187391209296(-1.1594924587268494)
# 3    0.06778261097528193(9.969014221960535***)
# 4   0.05849802380080871(6.7368732605803014***)
# 5  0.023557230646612415(2.7965962085031517***)
# 6                                     0.0(0.0)
# 7   -0.010380566079543185(-1.3123389021500662)
#
#                                              7
# 0   -0.009243238396958398(-1.0121738120414685)
# 1   0.0015477681722145809(0.20672905884918047)
# 2  0.00039337868833388967(0.04566759046834486)
# 3   0.07816317705482512(11.494552279659166***)
# 4   0.06887858988035189(7.9318484890559136***)
# 5     0.0339377967261556(4.028658575140418***)
# 6     0.010380566079543185(1.3123389021500662)
# 7                                     0.0(0.0)

# %%
test
# Out:
# (0.0, 1.0)

# %%
left_df
# Out:
#           model_set_0  model_set_1  model_set_2  model_set_3  model_set_4  \
# 정확도          0.864706     0.855634     0.818841     0.799242     0.854839
# 정밀도          0.866765     0.854042     0.822041     0.797850     0.856130
# 재현율          0.864706     0.855634     0.818841     0.799242     0.854839
# f1_score     0.860458     0.852950     0.814641     0.796872     0.853223
# 정확도          0.466667     0.300000     0.333333     0.282609     0.333333
# 정밀도          0.606349     0.635317     0.483333     0.321183     0.419088
# 재현율          0.466667     0.300000     0.333333     0.282609     0.333333
# f1_score     0.481616     0.332189     0.366595     0.298259     0.325605
#
#           model_set_5  model_set_6  model_set_7  model_set_8  model_set_9  \
# 정확도          0.847656     0.837719     0.762931     0.839286     0.801587
# 정밀도          0.853950     0.840809     0.771382     0.841527     0.816622
# 재현율          0.847656     0.837719     0.762931     0.839286     0.801587
# f1_score     0.844036     0.836183     0.760002     0.837426     0.796973
# 정확도          0.303571     0.491803     0.380282     0.363636     0.447761
# 정밀도          0.314829     0.495380     0.275855     0.379939     0.304822
# 재현율          0.303571     0.491803     0.380282     0.363636     0.447761
# f1_score     0.293204     0.469425     0.307227     0.362812     0.354436
#
#           ...  model_set_22  model_set_23  model_set_24  model_set_25  \
# 정확도       ...      0.772727      0.752174      0.788793      0.784404
# 정밀도       ...      0.773984      0.760964      0.790324      0.790041
# 재현율       ...      0.772727      0.752174      0.788793      0.784404
# f1_score  ...      0.769118      0.750370      0.784401      0.780355
# 정확도       ...      0.483871      0.467742      0.333333      0.366667
# 정밀도       ...      0.459677      0.530615      0.455010      0.409325
# 재현율       ...      0.483871      0.467742      0.333333      0.366667
# f1_score  ...      0.468328      0.489128      0.376024      0.386603
#
#           model_set_26  model_set_27  model_set_28  model_set_29  \
# 정확도           0.802273      0.780374      0.785377      0.842233
# 정밀도           0.804480      0.781046      0.786668      0.847213
# 재현율           0.802273      0.780374      0.785377      0.842233
# f1_score      0.801198      0.775633      0.780440      0.838663
# 정확도           0.359375      0.396552      0.405797      0.400000
# 정밀도           0.422984      0.408348      0.373360      0.476320
# 재현율           0.359375      0.396552      0.405797      0.400000
# f1_score      0.349655      0.369540      0.386825      0.321385
#
#           model_set_30  model_set_31
# 정확도           0.803879      0.794393
# 정밀도           0.816929      0.796811
# 재현율           0.803879      0.794393
# f1_score      0.801365      0.789971
# 정확도           0.425000      0.473684
# 정밀도           0.520994      0.447368
# 재현율           0.425000      0.473684
# f1_score      0.427354      0.456140
#
# [8 rows x 32 columns]

# %%
right_df
# Out:
#           model_set_0  model_set_1  model_set_2  model_set_3  model_set_4  \
# 정확도          0.864706     0.855634     0.818841     0.799242     0.854839
# 정밀도          0.866765     0.854042     0.822041     0.797850     0.856130
# 재현율          0.864706     0.855634     0.818841     0.799242     0.854839
# f1_score     0.860458     0.852950     0.814641     0.796872     0.853223
# 정확도          0.466667     0.300000     0.333333     0.282609     0.333333
# 정밀도          0.606349     0.635317     0.483333     0.321183     0.419088
# 재현율          0.466667     0.300000     0.333333     0.282609     0.333333
# f1_score     0.481616     0.332189     0.366595     0.298259     0.325605
#
#           model_set_5  model_set_6  model_set_7  model_set_8  model_set_9  \
# 정확도          0.847656     0.837719     0.762931     0.839286     0.801587
# 정밀도          0.853950     0.840809     0.771382     0.841527     0.816622
# 재현율          0.847656     0.837719     0.762931     0.839286     0.801587
# f1_score     0.844036     0.836183     0.760002     0.837426     0.796973
# 정확도          0.303571     0.491803     0.380282     0.363636     0.447761
# 정밀도          0.314829     0.495380     0.275855     0.379939     0.304822
# 재현율          0.303571     0.491803     0.380282     0.363636     0.447761
# f1_score     0.293204     0.469425     0.307227     0.362812     0.354436
#
#           ...  model_set_22  model_set_23  model_set_24  model_set_25  \
# 정확도       ...      0.772727      0.752174      0.788793      0.784404
# 정밀도       ...      0.773984      0.760964      0.790324      0.790041
# 재현율       ...      0.772727      0.752174      0.788793      0.784404
# f1_score  ...      0.769118      0.750370      0.784401      0.780355
# 정확도       ...      0.483871      0.467742      0.333333      0.366667
# 정밀도       ...      0.459677      0.530615      0.455010      0.409325
# 재현율       ...      0.483871      0.467742      0.333333      0.366667
# f1_score  ...      0.468328      0.489128      0.376024      0.386603
#
#           model_set_26  model_set_27  model_set_28  model_set_29  \
# 정확도           0.802273      0.780374      0.785377      0.842233
# 정밀도           0.804480      0.781046      0.786668      0.847213
# 재현율           0.802273      0.780374      0.785377      0.842233
# f1_score      0.801198      0.775633      0.780440      0.838663
# 정확도           0.359375      0.396552      0.405797      0.400000
# 정밀도           0.422984      0.408348      0.373360      0.476320
# 재현율           0.359375      0.396552      0.405797      0.400000
# f1_score      0.349655      0.369540      0.386825      0.321385
#
#           model_set_30  model_set_31
# 정확도           0.803879      0.794393
# 정밀도           0.816929      0.796811
# 재현율           0.803879      0.794393
# f1_score      0.801365      0.789971
# 정확도           0.425000      0.473684
# 정밀도           0.520994      0.447368
# 재현율           0.425000      0.473684
# f1_score      0.427354      0.456140
#
# [8 rows x 32 columns]

# %%
F_i["mean"] = F_i.mean(axis= 1)

# %%
F_i
# Out:
#                    model_set_0  model_set_1  model_set_2  model_set_3  \
# 매출총이익률                0.083784     0.063814     0.108366     0.092609
# 유동비율                  0.105243     0.107054     0.112385     0.051177
# 부채비율                  0.095120     0.074542     0.095081     0.061685
# 매출액증가율                0.096825     0.145078     0.047978     0.048728
# 1년전 대비 시장 회전율         0.094516     0.069101     0.080665     0.096350
# 1년 전 대비 시장수익률         0.104246     0.103223     0.116473     0.103593
# 1년 전 대비 고객예탁금 증감률     0.059671     0.051465     0.070746     0.113364
# 상장일 기준 국고3년시장금리       0.083622     0.084755     0.091866     0.138877
# 종가_PER                0.083803     0.070526     0.067379     0.028440
# 종가_PBR                0.107870     0.118501     0.088282     0.120071
# 종가_EV/EBITDA          0.085300     0.111940     0.120779     0.145105
#
#                    model_set_4  model_set_5  model_set_6  model_set_7  \
# 매출총이익률                0.095093     0.092658     0.060096     0.063055
# 유동비율                  0.109414     0.098937     0.097972     0.046919
# 부채비율                  0.066899     0.058715     0.105421     0.089333
# 매출액증가율                0.045571     0.055600     0.022475     0.043719
# 1년전 대비 시장 회전율         0.063649     0.095723     0.108295     0.118412
# 1년 전 대비 시장수익률         0.060536     0.123669     0.088457     0.136923
# 1년 전 대비 고객예탁금 증감률     0.128827     0.136191     0.153354     0.087707
# 상장일 기준 국고3년시장금리       0.100074     0.061795     0.079162     0.180345
# 종가_PER                0.084782     0.048382     0.064071     0.061204
# 종가_PBR                0.086174     0.121194     0.089112     0.092817
# 종가_EV/EBITDA          0.158982     0.107135     0.131586     0.079566
#
#                    model_set_8  model_set_9  ...  model_set_23  model_set_24  \
# 매출총이익률                0.076665     0.048831  ...      0.047094      0.045974
# 유동비율                  0.053948     0.048662  ...      0.140382      0.093836
# 부채비율                  0.025866     0.061288  ...      0.090920      0.100941
# 매출액증가율                0.071776     0.078115  ...      0.045347      0.046665
# 1년전 대비 시장 회전율         0.174252     0.147434  ...      0.120070      0.107801
# 1년 전 대비 시장수익률         0.108737     0.143499  ...      0.059473      0.051673
# 1년 전 대비 고객예탁금 증감률     0.159936     0.163508  ...      0.040090      0.052863
# 상장일 기준 국고3년시장금리       0.182052     0.160446  ...      0.066245      0.063180
# 종가_PER                0.045887     0.036851  ...      0.131490      0.165462
# 종가_PBR                0.046728     0.047249  ...      0.198950      0.185416
# 종가_EV/EBITDA          0.054154     0.064116  ...      0.059939      0.086188
#
#                    model_set_25  model_set_26  model_set_27  model_set_28  \
# 매출총이익률                 0.065678      0.056625      0.039664      0.099494
# 유동비율                   0.117687      0.133512      0.142538      0.082124
# 부채비율                   0.098252      0.093307      0.076348      0.072729
# 매출액증가율                 0.039442      0.047498      0.054713      0.073697
# 1년전 대비 시장 회전율          0.109243      0.108139      0.106017      0.150336
# 1년 전 대비 시장수익률          0.086917      0.046401      0.064269      0.095308
# 1년 전 대비 고객예탁금 증감률      0.049035      0.075448      0.045290      0.040513
# 상장일 기준 국고3년시장금리        0.083876      0.072751      0.088075      0.046230
# 종가_PER                 0.115416      0.133471      0.123537      0.098302
# 종가_PBR                 0.148873      0.149778      0.107255      0.093692
# 종가_EV/EBITDA           0.085581      0.083071      0.152294      0.147575
#
#                    model_set_29  model_set_30  model_set_31      mean
# 매출총이익률                 0.090737      0.070216      0.063212  0.066239
# 유동비율                   0.080130      0.084488      0.135674  0.083703
# 부채비율                   0.073118      0.097414      0.092259  0.084325
# 매출액증가율                 0.043503      0.035436      0.078202  0.056784
# 1년전 대비 시장 회전율          0.177633      0.167234      0.148292  0.129858
# 1년 전 대비 시장수익률          0.060244      0.097977      0.045756  0.104136
# 1년 전 대비 고객예탁금 증감률      0.087829      0.057046      0.050092  0.090126
# 상장일 기준 국고3년시장금리        0.052103      0.053050      0.044499  0.096410
# 종가_PER                 0.150123      0.163368      0.137140  0.086217
# 종가_PBR                 0.070611      0.049955      0.050523  0.101591
# 종가_EV/EBITDA           0.113969      0.123815      0.154351  0.100612
#
# [11 rows x 33 columns]

# %%
from scipy import stats
def Ttest(x,y, Number = 0 , leftstr = "", rightstr= "", Measure = ""):
    print(str(Number)+"\t"+leftstr + " & " + rightstr + "\tMeasure : " + Measure + "\n")
    _stat,_pvalue = stats.levene(x,y)
    print("LeveneResult -- stat : %3f, p-value : %3f \n" %(_stat, _pvalue))
    if _pvalue < 0.05:
        equal_Var = False
    else :
        equal_Var = True
    print(equal_Var)
    statistic , pvalue = stats.ttest_ind(x,y, equal_var= equal_Var)
    print(left,right)
    print("\nstatistic : %d , pvalue : %.7f\n" % (statistic, pvalue))
    return (statistic, pvalue)
