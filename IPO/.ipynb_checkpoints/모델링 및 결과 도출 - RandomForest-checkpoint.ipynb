# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
from dateutil.relativedelta import relativedelta
from datetime import datetime
from dateutil.parser import parse
import copy

from imblearn.over_sampling import SMOTE
#시각화
import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import *
from sklearn.metrics import accuracy_score, confusion_matrix, log_loss

##알고리즘 
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %%
# 다양한 오차 측정 지표를 확인하기 위한 함수 정의

from sklearn.metrics import *

def get_clf_eval(y_test, pred=None, pred_proba=None): 
    confusion = confusion_matrix(y_test, pred) 
    accuracy = accuracy_score(y_test, pred) 
    precision = precision_score(y_test, pred , average= 'weighted') 
    recall = recall_score(y_test, pred , average= 'weighted') 
    f1 = f1_score(y_test, pred , average= 'weighted') 
    
#     print('정확도(accuracy): {0:.4f}, 정밀도(precision): {1:.4f}, 재현율(recall): {2:.4f}, f1_score: {3:.4f}'.format(accuracy, precision, recall, f1))
    
#     confusion = confusion_matrix(y_test, pred) 
#     accuracy = accuracy_score(y_test, pred) 
#     precision = precision_score(y_test, pred , average= 'macro') 
#     recall = recall_score(y_test, pred , average= 'macro') 
#     f1 = f1_score(y_test, pred , average= 'macro') 
    
#     print('정확도(accuracy): {0:.4f}, 정밀도(precision): {1:.4f}, 재현율(recall): {2:.4f}, f1_score: {3:.4f}'.format(accuracy, precision, recall, f1))
    
    return [accuracy, precision, recall, f1]

# %%
def Cut(Series , cuts):
    "구분할 iter가능한 변수와 구분 기준을 입력받으면 구분 기준 앞에서 부터 1로 구분해서 return 함"
    Cuts = copy.deepcopy(cuts)
    Cuts.append(np.inf)
    Cuts.insert(0,-1*np.inf)
    R = len(Cuts)
    label = range(1,R)
    return pd.cut(Series, Cuts, labels = label)

# %% [markdown]
# # 데이터 불러오기

# %%
df_1_3 = pd.read_csv("d:/공모전/IPO/IPO/CleanData/X_train_After_IPO_1.csv")
df_3_6 = pd.read_csv("d:/공모전/IPO/IPO/CleanData/X_train_After_IPO_3.csv")
df_0 = pd.read_csv("d:/공모전/IPO/IPO/CleanData/X_train_Before_IPO.csv")
df_end = pd.read_csv("d:/공모전/IPO/IPO/CleanData/X_train_EndPrice_IPO.csv")

# %%
df_end.isnull().sum()
# Out:
# 종목명                  0
# 상장일                  0
# 공모 시가총액              0
# 매출총이익률               0
# 유동비율                 0
# 부채비율                 0
# 매출액증가율               0
# 1년전 대비 시장 회전율        0
# 1년 전 대비 시장수익률        0
# 1년 전 대비 고객예탁금 증감률    0
# 상장일 기준 국고3년시장금리      0
# 종가_PER               0
# 종가_PBR               0
# 종가_EV/EBITDA         0
# 종가 대비 1개월 수익률        0
# 종가 대비 3개월 수익률        0
# 종가 대비 6개월 수익률        0
# NullCount            0
# dtype: int64

# %%
df_0_1 = df_0.drop(['공모가 대비 3개월 수익률','공모가 대비 6개월 수익률'],axis =1)
df_0_3 = df_0.drop(['공모가 대비 1개월 수익률','공모가 대비 6개월 수익률'],axis =1)
df_0_6 = df_0.drop(['공모가 대비 1개월 수익률','공모가 대비 3개월 수익률'],axis =1)

# %%
df_end_1 = df_end.drop(['종가 대비 3개월 수익률','종가 대비 6개월 수익률','NullCount'],axis =1)
df_end_3 = df_end.drop(['종가 대비 1개월 수익률','종가 대비 6개월 수익률','NullCount'],axis =1)
df_end_6 = df_end.drop(['종가 대비 1개월 수익률','종가 대비 3개월 수익률','NullCount'],axis =1)

# %% [markdown]
# # 공통 전처리 및 랜덤포레스트

# %%
pred_value = pd.Series(test_pred,index = y_test.index)
pred_value
# Out:
# 상장일
# 2012-05-04    2
# 2012-07-06    4
# 2012-07-13    4
# 2012-07-19    4
# 2012-07-25    4
# 2012-07-26    4
# 2012-08-02    4
# 2012-09-25    2
# 2012-09-27    2
# 2012-11-06    2
# 2012-11-16    2
# 2012-11-22    2
# 2012-11-27    1
# 2012-12-17    4
# 2013-01-29    2
# 2013-01-30    5
# 2013-02-05    2
# 2013-02-07    2
# 2013-02-13    5
# 2013-02-19    4
# 2013-03-05    5
# 2013-03-07    4
# dtype: int64

# %%
per = test_list[0]["공모가 대비 1개월 수익률"]
per
# Out:
# 상장일
# 2012-05-04   -0.122642
# 2012-07-06   -0.179412
# 2012-07-13   -0.026087
# 2012-07-19   -0.032222
# 2012-07-25   -0.333333
# 2012-07-26   -0.034545
# 2012-08-02    0.578571
# 2012-09-25    0.450000
# 2012-09-27   -0.017333
# 2012-11-06    0.825397
# 2012-11-16   -0.101429
# 2012-11-22   -0.022222
# 2012-11-27   -0.323301
# 2012-12-17    0.112500
# 2013-01-29    0.294872
# 2013-01-30    0.486842
# 2013-02-05    0.157143
# 2013-02-07    0.135556
# 2013-02-13    0.400000
# 2013-02-19    0.674699
# 2013-03-05    0.231250
# 2013-03-07   -0.058750
# Name: 공모가 대비 1개월 수익률, dtype: float64

# %%
y_testdata = pd.concat([per,y_test,pred_value] , axis = 1)

# %%
y_testdata.columns = ['실제 y 수익률','실제 y라벨링','예측 y 라벨링']

# %%
per = test_list[i]["공모가 대비 1개월 수익률"]
y_testdata = pd.concat([per,y_test,pred_value] , axis = 1)
y_testdata.columns = ['실제 y 수익률','실제 y라벨링','예측 y 라벨링']

# %%
def process_final(df,y_name):
    
    ## 기본 전처리
    df['상장일'] = pd.to_datetime(df['상장일'])
    df = df.set_index(['상장일'])
    df = df.drop(['종목명','공모 시가총액'],axis = 1) ## 나중에 카테고리 진행할려면 남겨줄 것
    if y_name == '공모가 대비 6개월 수익률' or "종가 대비 6개월 수익률":
        df['Cat'] = Cut(df[y_name],[-0.4, -0.2, 0.2, 0.4])
       
        
    else :
        df['Cat'] = Cut(df[y_name],[-0.2, -0.1, 0.1, 0.2])
       
    
    ## train 3년 test 1년으로 총 기간을 3개월 이동으로 36개 구간분할
    train_list = []
    test_list = []
    train_start_date = '2009-04-01' ## 기한은 나중에 변경할수도
    test_start_date = parse(str(train_start_date)).date() + relativedelta(years =4)
    train_end_date = parse(str(test_start_date)).date() - relativedelta(days =1)
    test_end_date = parse(str(train_end_date)).date() + relativedelta(years =1)

    while True:

        train_list.append(df[train_start_date : train_end_date])
        test_list.append(df[test_start_date : test_end_date])

        train_start_date = parse(str(train_start_date)).date() + relativedelta(months=3)
        test_start_date = parse(str(test_start_date)).date() + relativedelta(months=3)
        train_end_date = parse(str(train_end_date)).date() + relativedelta(months=3)
        test_end_date = parse(str(test_end_date)).date() + relativedelta(months=3)

        if str(train_start_date) == '2017-04-01':
            break
            
    y_data = []
    score_list = []
    feature_list = []

    for i in range(0,len(train_list)):
        X_train_sm = train_list[i].drop([y_name,'Cat'],axis =1)
        y_train_sm = train_list[i]['Cat']
        X_test = test_list[i].drop([y_name,'Cat'],axis =1)
        y_test = test_list[i]['Cat']
        ## 오버샘플링
        smote = SMOTE(sampling_strategy='auto', random_state=0)
        X_train ,y_train = smote.fit_resample(X_train_sm,y_train_sm)
        

            # 랜덤 포레스트 학습 및 별도의 테스트 셋으로 예측 성능 평가
                # 모델 학습
        clf = RandomForestClassifier(random_state=0 , max_depth = 5 , min_samples_leaf = 3 , min_samples_split =  2 , n_estimators = 400)

        

        clf.fit(X_train , y_train)
        train_pred = clf.predict(X_train)
        test_pred = clf.predict(X_test)

        # 성과 평가
        train_res = get_clf_eval(y_train, train_pred)
        test_res = get_clf_eval(y_test,test_pred)
        res = train_res + test_res


        #feature_importance
        feature_importance = clf.feature_importances_


        pred_value = pd.Series(test_pred,index = y_test.index)
        per = test_list[i][y_name]
        y_testdata = pd.concat([per,y_test,pred_value] , axis = 1)
        y_testdata.columns = ['실제 y 수익률','실제 y라벨링','예측 y 라벨링']

        score_list.append(res)
        feature_list.append(feature_importance)
        y_data.append(y_testdata)   
    df_score = pd.DataFrame(score_list,columns = ["정확도","정밀도","재현율","f1_score"]*2).T 
    df_score.rename(columns = lambda x : "model_set_"+ str(x),inplace = True)

    df_feature = pd.DataFrame(feature_list,columns = X_train.columns).T 
    df_feature.rename(columns = lambda x : "model_set_"+ str(x),inplace = True)
        
    return df_score , df_feature , y_data

# %%
df_score_0_1,df_feature_0_1,y_data_0_1 = process_final(df_0_1,'공모가 대비 1개월 수익률')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-167-af2ea86c27a6> in <module>
# ----> 1 df_score_0_1,df_feature_0_1,y_data_0_1 = process_final(df_0_1,'공모가 대비 1개월 수익률')
#
# <ipython-input-166-729722cdc835> in process_final(df, y_name)
#      45         ## 오버샘플링
#      46         smote = SMOTE(sampling_strategy='auto', random_state=0)
# ---> 47         X_train ,y_train = smote.fit_resample(X_train_sm,y_train_sm)
#      48
#      49
#
# C:\ProgramData\Anaconda3\envs\textmining\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#      81         )
#      82
# ---> 83         output = self._fit_resample(X, y)
#      84
#      85         y_ = label_binarize(output[1], np.unique(y)) if binarize_y else output[1]
#
# C:\ProgramData\Anaconda3\envs\textmining\lib\site-packages\imblearn\over_sampling\_smote\base.py in _fit_resample(self, X, y)
#     307
#     308             self.nn_k_.fit(X_class)
# --> 309             nns = self.nn_k_.kneighbors(X_class, return_distance=False)[:, 1:]
#     310             X_new, y_new = self._make_samples(
#     311                 X_class, y.dtype, class_sample, X_class, nns, n_samples, 1.0
#
# C:\ProgramData\Anaconda3\envs\textmining\lib\site-packages\sklearn\neighbors\_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     681                 "Expected n_neighbors <= n_samples, "
#     682                 " but n_samples = %d, n_neighbors = %d" %
# --> 683                 (n_samples_fit, n_neighbors)
#     684             )
#     685
#
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 3, n_neighbors = 6

# %%
df_score_0_1
# Out:
#           model_set_0  model_set_1  model_set_2  model_set_3  model_set_4  \
# 정확도          0.922619     0.896104     0.913333     0.931250     0.946309
# 정밀도          0.912167     0.892024     0.904507     0.921294     0.931826
# 재현율          0.922619     0.896104     0.913333     0.931250     0.946309
# f1_score     0.914544     0.887038     0.904150     0.922715     0.936963
# 정확도          0.366667     0.366667     0.388889     0.456522     0.377778
# 정밀도          0.339167     0.260000     0.284056     0.367955     0.286700
# 재현율          0.366667     0.366667     0.388889     0.456522     0.377778
# f1_score     0.334918     0.301316     0.324725     0.402174     0.304418
#
#           model_set_5  model_set_6  model_set_7  model_set_8  model_set_9  \
# 정확도          0.937063     0.942446     0.973154     0.956835     0.952055
# 정밀도          0.922387     0.933101     0.967548     0.952796     0.948253
# 재현율          0.937063     0.942446     0.973154     0.956835     0.952055
# f1_score     0.927394     0.935040     0.969667     0.953005     0.947283
# 정확도          0.357143     0.344262     0.338028     0.376623     0.507463
# 정밀도          0.268908     0.266676     0.306361     0.344535     0.486122
# 재현율          0.357143     0.344262     0.338028     0.376623     0.507463
# f1_score     0.287642     0.300305     0.274930     0.327221     0.482712
#
#           ...  model_set_22  model_set_23  model_set_24  model_set_25  \
# 정확도       ...      0.917695      0.892562      0.890688      0.882845
# 정밀도       ...      0.929127      0.900024      0.898445      0.890409
# 재현율       ...      0.917695      0.892562      0.890688      0.882845
# f1_score  ...      0.915244      0.885075      0.882967      0.874098
# 정확도       ...      0.435484      0.532258      0.523810      0.466667
# 정밀도       ...      0.293548      0.283299      0.274376      0.221469
# 재현율       ...      0.435484      0.532258      0.523810      0.466667
# f1_score  ...      0.288246      0.369779      0.360119      0.300383
#
#           model_set_26  model_set_27  model_set_28  model_set_29  \
# 정확도           0.877049      0.849785      0.888412      0.853448
# 정밀도           0.879034      0.857189      0.877570      0.854359
# 재현율           0.877049      0.849785      0.888412      0.853448
# f1_score      0.865176      0.831359      0.871916      0.833711
# 정확도           0.453125      0.241379      0.188406      0.492308
# 정밀도           0.384814      0.064655      0.046377      0.337029
# 재현율           0.453125      0.241379      0.188406      0.492308
# f1_score      0.348201      0.101991      0.074432      0.382418
#
#           model_set_30  model_set_31
# 정확도           0.870968      0.879167
# 정밀도           0.864892      0.868111
# 재현율           0.870968      0.879167
# f1_score      0.851554      0.862520
# 정확도           0.375000      0.526316
# 정밀도           0.356203      0.277008
# 재현율           0.375000      0.526316
# f1_score      0.354021      0.362976
#
# [8 rows x 32 columns]

# %%
y_data_0_1
# Out:
# [            실제 y 수익률 실제 y라벨링  예측 y 라벨링
#  상장일
#  2013-04-03  0.948718       5         5
#  2013-04-30  0.942308       5         3
#  2013-05-10  0.016129       3         2
#  2013-05-30  1.244444       5         5
#  2013-07-17  0.284091       4         3
#  2013-07-24  0.275000       4         3
#  2013-08-01  0.109524       3         2
#  2013-08-02  1.161290       5         3
#  2013-09-12  1.424000       5         3
#  2013-10-02  0.203333       4         3
#  2013-10-08  0.046341       3         3
#  2013-10-18 -0.174138       3         5
#  2013-10-22 -0.288889       2         3
#  2013-10-31  1.205000       5         5
#  2013-11-06 -0.124242       3         3
#  2013-11-08 -0.116049       3         5
#  2021-01-27  0.778261       5         5
#  2021-01-28  0.492857       5         5
#  2021-01-28 -0.360938       2         5
#  2021-01-29  0.812500       5         5
#  2021-02-03  1.380000       5         5
#  2021-02-03  0.606250       5         5
#  2021-02-05  0.377273       4         5
#  2021-02-16 -0.222222       2         5
#  2021-02-24  0.122857       3         5
#  2021-02-24  1.359524       5         5
#  2021-02-25  0.359375       4         5
#  2021-02-26  0.278571       4         5
#  2021-03-09 -0.100000       3         5
#  2021-03-11  0.857895       5         5
#  2021-03-17  1.536667       5         5
#  2021-03-23  0.020000       3         5
#  2021-03-24  3.290909       5         5
#  2021-03-24  0.563889       5         5]

# %%
df_score_0_3,df_feature_0_3,y_data_0_3 = process_final(df_0_3,'공모가 대비 3개월 수익률')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-168-2c1f9da5fa72> in <module>
# ----> 1 df_score_0_3,df_feature_0_3,y_data_0_3 = process_final(df_0_3,'공모가 대비 3개월 수익률')
#
# <ipython-input-166-729722cdc835> in process_final(df, y_name)
#      45         ## 오버샘플링
#      46         smote = SMOTE(sampling_strategy='auto', random_state=0)
# ---> 47         X_train ,y_train = smote.fit_resample(X_train_sm,y_train_sm)
#      48
#      49
#
# C:\ProgramData\Anaconda3\envs\textmining\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#      81         )
#      82
# ---> 83         output = self._fit_resample(X, y)
#      84
#      85         y_ = label_binarize(output[1], np.unique(y)) if binarize_y else output[1]
#
# C:\ProgramData\Anaconda3\envs\textmining\lib\site-packages\imblearn\over_sampling\_smote\base.py in _fit_resample(self, X, y)
#     307
#     308             self.nn_k_.fit(X_class)
# --> 309             nns = self.nn_k_.kneighbors(X_class, return_distance=False)[:, 1:]
#     310             X_new, y_new = self._make_samples(
#     311                 X_class, y.dtype, class_sample, X_class, nns, n_samples, 1.0
#
# C:\ProgramData\Anaconda3\envs\textmining\lib\site-packages\sklearn\neighbors\_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     681                 "Expected n_neighbors <= n_samples, "
#     682                 " but n_samples = %d, n_neighbors = %d" %
# --> 683                 (n_samples_fit, n_neighbors)
#     684             )
#     685
#
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 5, n_neighbors = 6

# %%
df_score_0_6,df_feature_0_6,y_data_0_6 = process_final(df_0_6,'공모가 대비 6개월 수익률')

# %%
df_score_1_3,df_feature_1_3,y_data_1_3 = process_final(df_1_3,'1_3_수익률')

# %%
df_score_3_6,df_feature_3_6,y_data_3_6 = process_final(df_3_6,'3_6_수익률')

# %%
df_score_end_1,df_feature_end_1,y_data_end_1 = process_final(df_end_1,'종가 대비 1개월 수익률')
df_score_end_3,df_feature_end_3,y_data_end_3 = process_final(df_end_3,'종가 대비 3개월 수익률')
df_score_end_6,df_feature_end_6,y_data_end_1 = process_final(df_end_6,'종가 대비 6개월 수익률')

# %%
df_score_0_1.to_csv("0_1_모델 평가.csv",encoding = 'euc-kr')
df_score_0_3.to_csv("0_3_모델 평가.csv",encoding = 'euc-kr')
df_score_0_6.to_csv("0_6_모델 평가.csv",encoding = 'euc-kr')
df_score_1_3.to_csv("1_3_모델 평가.csv",encoding = 'euc-kr')
df_score_3_6.to_csv("3_6_모델 평가.csv",encoding = 'euc-kr')

# %%
df_feature_0_1.to_csv("0_1_feature별 값.csv",encoding = 'euc-kr')
df_feature_0_3.to_csv("0_3_feature별 값.csv",encoding = 'euc-kr')
df_feature_0_6.to_csv("0_6_feature별 값.csv",encoding = 'euc-kr')
df_feature_1_3.to_csv("1_3_feature별 값.csv",encoding = 'euc-kr')
df_feature_3_6.to_csv("3_6_feature별 값.csv",encoding = 'euc-kr')

# %%
def buy_sell(y_data):
    portfolio = []
    for i in range(0,32):
        buy = y_data[i][y_data[i]['예측 y 라벨링'] > 3]['실제 y 수익률']
        sell = y_data[i][y_data[i]['예측 y 라벨링'] < 3]['실제 y 수익률']
        sum_1 = buy.sum() - sell.sum()
        sum_2 = len(buy)+len(sell)
        value = sum_1/sum_2
        portfolio.append(value)
    data = pd.DataFrame(portfolio).T
    data.rename(index = {0 : "buy_sell수익률"},columns = lambda x : "model_set_"+ str(x),inplace = True )
    data['mean'] = data.mean(axis=1)[0]
                         
    return data

# %%
def buy(y_data):
    portfolio = []
    for i in range(0,32):
        buy = y_data[i][y_data[i]['예측 y 라벨링'] > 3]['실제 y 수익률']
        sum_1 = buy.sum()
        sum_2 = len(buy)
        value = sum_1/sum_2
        portfolio.append(value)
    data = pd.DataFrame(portfolio).T
    data.rename(index = {0 : "buy수익률"},columns = lambda x : "model_set_"+ str(x),inplace = True )
    data['mean'] = data.mean(axis=1)[0]
                         
    return data

# %%
def mean(y_data):
    portfolio = []
    for i in range(0,32):
        buy = y_data[i]['실제 y 수익률']
        sum_1 = buy.sum()
        sum_2 = len(buy)
        value = sum_1/sum_2
        portfolio.append(value)
    data = pd.DataFrame(portfolio).T
    data.rename(index = {0 : "all수익률"},columns = lambda x : "model_set_"+ str(x),inplace = True )
    data['mean'] = data.mean(axis=1)[0]
    return data

# %%
def frame(y_data):
    buy_frame = buy(y_data)
    buy_sell_frame = buy_sell(y_data)
    mean_frame = mean(y_data)
    value = pd.concat([buy_sell_frame,buy_frame,mean_frame])
    return value

# %%
buy(y_data_0_1)
# Out:
#         model_set_0  model_set_1  model_set_2  model_set_3  model_set_4  \
# buy수익률     0.598574     0.439646     0.254224     0.552556     0.425164
#
#         model_set_5  model_set_6  model_set_7  model_set_8  model_set_9  ...  \
# buy수익률     0.431276     0.406014      0.31198     0.315688     0.275361  ...
#
#         model_set_23  model_set_24  model_set_25  model_set_26  model_set_27  \
# buy수익률           NaN           NaN           NaN      0.349455      1.162108
#
#         model_set_28  model_set_29  model_set_30  model_set_31      mean
# buy수익률     -0.140816      0.606523      0.727008      0.652271  0.360599
#
# [1 rows x 33 columns]

# %%
expect_rate = frame(y_data_0_1)

# %%
expect_rate
# Out:
#              model_set_0  model_set_1  model_set_2  model_set_3  model_set_4  \
# buy_sell수익률     0.466294     0.439646     0.254224     0.552556     0.425164
# buy수익률          0.598574     0.439646     0.254224     0.552556     0.425164
# all수익률          0.384893     0.315134     0.200451     0.503997     0.462730
#
#              model_set_5  model_set_6  model_set_7  model_set_8  model_set_9  \
# buy_sell수익률     0.431276     0.406014     0.311980     0.315688     0.275361
# buy수익률          0.431276     0.406014     0.311980     0.315688     0.275361
# all수익률          0.452607     0.492498     0.379251     0.363375     0.333337
#
#              ...  model_set_23  model_set_24  model_set_25  model_set_26  \
# buy_sell수익률  ...           NaN           NaN     -0.304167      0.180730
# buy수익률       ...           NaN           NaN           NaN      0.349455
# all수익률       ...      0.094258      0.038416      0.085447      0.213681
#
#              model_set_27  model_set_28  model_set_29  model_set_30  \
# buy_sell수익률      1.162108     -0.660758      0.539737      0.727008
# buy수익률           1.162108     -0.140816      0.606523      0.727008
# all수익률           0.501264      0.611981      0.613520      0.742035
#
#              model_set_31      mean
# buy_sell수익률      0.652271  0.308849
# buy수익률           0.652271  0.360599
# all수익률           0.652271  0.324157
#
# [3 rows x 33 columns]

# %%
buy_sell_0_1
# Out:
#      model_set_0  model_set_1  model_set_2  model_set_3  model_set_4  \
# 수익률     0.443503     0.298035     0.197257     0.430732     0.447742
#
#      model_set_5  model_set_6  model_set_7  model_set_8  model_set_9  ...  \
# 수익률     0.358916     0.346033     0.357189     0.267228     0.296771  ...
#
#      model_set_23  model_set_24  model_set_25  model_set_26  model_set_27  \
# 수익률      0.229553     -0.038008     -0.054807      0.176253      0.493241
#
#      model_set_28  model_set_29  model_set_30  model_set_31      mean
# 수익률      0.419408      0.532175       0.08444      0.652271  0.264912
#
# [1 rows x 33 columns]

# %%
df = y_data_0_1[0]
df[df['예측 y 라벨링'] == 4 | 5]
# Out:
#             실제 y 수익률 실제 y라벨링  예측 y 라벨링
# 상장일
# 2013-04-03  0.948718       5         5
# 2013-04-30  0.942308       5         5
# 2013-05-10  0.016129       3         5
# 2013-05-30  1.244444       5         5
# 2013-07-17  0.284091       5         5
# 2013-08-01  0.109524       4         5
# 2013-09-12  1.424000       5         5
# 2013-10-08  0.046341       3         5
# 2013-10-18 -0.174138       2         5
# 2013-10-31  1.205000       5         5
# 2013-11-08 -0.116049       2         5
# 2013-11-13  0.010000       3         5
# 2013-11-19  0.416000       5         5
# 2013-11-26 -0.179825       2         5
# 2013-12-06  0.060000       3         5
# 2013-12-19  0.252727       5         5
# 2013-12-19  0.250000       5         5
# 2013-12-27  0.681818       5         5
# 2013-12-27  0.164583       4         5
# 2014-02-04  1.444444       5         5
# 2014-02-27  0.700000       5         5

# %%
new_df = df[df['예측 y 라벨링'] == 4 | 5]
new_df
# Out:
#             실제 y 수익률 실제 y라벨링  예측 y 라벨링
# 상장일
# 2013-04-03  0.948718       5         5
# 2013-04-30  0.942308       5         5
# 2013-05-10  0.016129       3         5
# 2013-05-30  1.244444       5         5
# 2013-07-17  0.284091       5         5
# 2013-08-01  0.109524       4         5
# 2013-09-12  1.424000       5         5
# 2013-10-08  0.046341       3         5
# 2013-10-18 -0.174138       2         5
# 2013-10-31  1.205000       5         5
# 2013-11-08 -0.116049       2         5
# 2013-11-13  0.010000       3         5
# 2013-11-19  0.416000       5         5
# 2013-11-26 -0.179825       2         5
# 2013-12-06  0.060000       3         5
# 2013-12-19  0.252727       5         5
# 2013-12-19  0.250000       5         5
# 2013-12-27  0.681818       5         5
# 2013-12-27  0.164583       4         5
# 2014-02-04  1.444444       5         5
# 2014-02-27  0.700000       5         5

# %%
len(new_df[new_df['실제 y라벨링'] == 4 | 5])/len(new_df)
# Out:
# 0.5714285714285714

# %%
def precision(df):
    precision_list = []
    for i in range(0,32):
        new_df = df[i][df[i]['예측 y 라벨링'] == 4 | 5]
        next_df = new_df[new_df['실제 y라벨링']== 4 | 5]
        first_num = len(new_df)
        second_num = len(next_df)
        precision_list.append(second_num/first_num)
    return precision_list

# %%
fram = precision(y_data_0_1)

# %%
fram
# Out:
# [0.5714285714285714,
#  0.47619047619047616,
#  0.4444444444444444,
#  0.5555555555555556,
#  0.5454545454545454,
#  0.5094339622641509,
#  0.52,
#  0.45161290322580644,
#  0.417910447761194,
#  0.36363636363636365,
#  0.37254901960784315,
#  0.2553191489361702,
#  0.23404255319148937,
#  0.34375,
#  0.3617021276595745,
#  0.34545454545454546,
#  0.3888888888888889,
#  0.38181818181818183,
#  0.391304347826087,
#  0.37735849056603776,
#  0.375,
#  0.37037037037037035,
#  0.3333333333333333,
#  0.7,
#  0.25,
#  0.21428571428571427,
#  0.48,
#  0.75,
#  0.6666666666666666,
#  0.7454545454545455,
#  0.6923076923076923,
#  0.7368421052631579]

# %%
a = []
b = []
for i in range(0,32):
    c = y_data_0_1[i][y_data_0_1[i]['예측 y 라벨링'] == 3]['실제 y 수익률'].mean()
    if np.isnan(c):
        c = 0
    a.append(c)

# %%
sum(a)/len(a)
# Out:
# 0.5161067459735941

# %%
y_data_0_1[0]['실제 y 수익률'].mean()
# Out:
# 0.14070695563636362

# %%
sum(new)/len(new)
# Out:
# 0.2632665884241705

# %%
buy = y_data_0_1[3][y_data_0_1[3]['예측 y 라벨링'] > 3]['실제 y 수익률']

# %%
sell = y_data_0_1[3][y_data_0_1[3]['예측 y 라벨링'] < 3]['실제 y 수익률']

# %%
sum_1 = buy.sum() - sell.sum()
sum_2 = len(buy)+len(sell)

# %%
sum_1/sum_2
# Out:
# -0.1261903816285714

# %%
performance = []
for i in range(0,36):
    buy = y_data_0_1[i][y_data_0_1[i]['예측 y 라벨링'] > 3]['실제 y 수익률'].mean()
    sell = y_data_0_1[i][y_data_0_1[i]['예측 y 라벨링'] < 3]['실제 y 수익률'].mean()
    if np.isnan(sell):
        sell = 0
    performance.append(buy-sell)

# %%
sum(performance)/len(performance)
# Out:
# 0.08540591549372804

# %%
performance = []
for i in range(0,36):
    buy = y_data_0_1[i][y_data_0_1[i]['예측 y 라벨링'] > 3]['실제 y 수익률'].mean()
    sell = y_data_0_1[i][y_data_0_1[i]['예측 y 라벨링'] < 3]['실제 y 수익률'].mean()
    if np.isnan(sell):
        sell = 0
    performance.append(buy-sell)

# %%
performance = []
for i in range(0,36):
    buy = y_data_0_1[i][y_data_0_1[i]['예측 y 라벨링'] > 3]['실제 y 수익률'].sum()
    sell = y_data_0_1[i][y_data_0_1[i]['예측 y 라벨링'] < 3]['실제 y 수익률'].sum()

    performance.append(buy-sell)

# %%
sum(performance)/len(performance)
# Out:
# 13.076028511750001
